# %% [markdown]
# # Importing packages

# %% [markdown]
# # box plots

# %%
plt.boxplot((df['atemp'], df['windspeed']), labels=['atemp', 'windspeed'])

# %% [markdown]
# # histogram

# %% [markdown]
# # bar plots

# %%
iris_groupby = iris_data.groupby(by=['species']).agg({'sepal_length':'mean', 'sepal_width':'mean'})
iris_groupby.plot(kind='bar')

# %% [markdown]
# # box plots
