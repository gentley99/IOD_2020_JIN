# %% [markdown]
# change the dropdown menu to 'Markdown'
# assigning a text ('hello world') to 'a'

# %%
# Code description
a = 'hello world'
print(a)
# Out:
# hello world

# %%
b = 2
c = 5

result = b + c
print(result)
# Out:
# 7

# %%
# install packages
# !pip install pandas
# !pip install numpy

# %%
# import packages
import numpy as np
import pandas as pd
