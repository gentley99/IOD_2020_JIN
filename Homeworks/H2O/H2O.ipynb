# %%
import h2o 

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-2119d509c984> in <module>
# ----> 1 import h2o
#
# ModuleNotFoundError: No module named 'h2o'

# %%
conda install -c anaconda h2o

# %%
h2o.init()

# %%
h2o.cluster_info()

# %%
df = h2o.import_file('')

# %%
# compute column means
colmeans = df.mean()

# print the results
colmeans

# %%
wine_train, wine_valid, wine_test = wine.split_frame(ratios=[0.6,0.2], seed = 1234)

# %%
wine_train, wine_test = wine.split_frame(ratios=[0.6], seed = 1234)

# %%
from h2o.automl import H2OAutoML

# %%
aml = H2OAutoML(max_model = 20, max_runtime_secs=100, seed=1)

# %%
aml.train(x=predictors, y='quality', training_frame=wine_train, validation_frame=wine_test)

# %%
print(aml.leaderboard)

# %%
aml.leader

# %%
h2o.shutdown() # make sure to do this or

# %%
h2o.cluster().shutdown() # make sure to do this or
