# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 9.7: Text Classification
# INSTRUCTIONS:
# - Run the cells
# - Observe and understand the results
# - Answer the questions

# %% [markdown]
# ## Import libraries

# %%
## Import Libraries
import numpy as np
import pandas as pd

import re

import string
import spacy

from collections import Counter

from sklearn.decomposition import LatentDirichletAllocation
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC

# import warnings
# warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load data

# %% [markdown]
# Sample:
#
#     __label__2 Stuning even for the non-gamer: This sound ...
#     __label__2 The best soundtrack ever to anything.: I'm ...
#     __label__2 Amazing!: This soundtrack is my favorite m ...
#     __label__2 Excellent Soundtrack: I truly like this so ...
#     __label__2 Remember, Pull Your Jaw Off The Floor Afte ...
#     __label__2 an absolute masterpiece: I am quite sure a ...
#     __label__1 Buyer beware: This is a self-published boo ...
#     . . .
#
# There are only two **labels**:
# - `__label__1`
# - `__label__2`

# %%
## Loading the data

trainDF = pd.read_fwf(
    filepath_or_buffer = '../../data/corpus.txt',
    colspecs = [(9, 10),   # label: get only the numbers 1 or 2
                (11, 9000) # text: makes the it big enought to get to the end of the line
               ], 
    header = 0,
    names = ['label', 'text'],
    lineterminator = '\n'
)

# convert label from [1, 2] to [0, 1]
trainDF['label'] = trainDF['label'] - 1

# %% [markdown]
# ## Inspect the data

# %%
# ANSWER
trainDF
# Out:
#       label                                               text
# 0         1  The best soundtrack ever to anything.: I'm rea...
# 1         1  Amazing!: This soundtrack is my favorite music...
# 2         1  Excellent Soundtrack: I truly like this soundt...
# 3         1  Remember, Pull Your Jaw Off The Floor After He...
# 4         1  an absolute masterpiece: I am quite sure any o...
# ...     ...                                                ...
# 9994      1  A revelation of life in small town America in ...
# 9995      1  Great biography of a very interesting journali...
# 9996      0  Interesting Subject; Poor Presentation: You'd ...
# 9997      0  Don't buy: The box looked used and it is obvio...
# 9998      1  Beautiful Pen and Fast Delivery.: The pen was ...
#
# [9999 rows x 2 columns]

# %%
trainDF.loc[1]['text']
# Out:
# 'Amazing!: This soundtrack is my favorite music of all time, hands down. The intense sadness of "Prisoners of Fate" (which means all the more if you\'ve played the game) and the hope in "A Distant Promise" and "Girl who Stole the Star" have been an important inspiration to me personally throughout my teen years. The higher energy tracks like "Chrono Cross ~ Time\'s Scar~", "Time of the Dreamwatch", and "Chronomantique" (indefinably remeniscent of Chrono Trigger) are all absolutely superb as well.This soundtrack is amazing music, probably the best of this composer\'s work (I haven\'t heard the Xenogears soundtrack, so I can\'t say for sure), and even if you\'ve never played the game, it would be worth twice the price to buy it.I wish I could give it 6 stars.'

# %%
print(trainDF.loc[1]['text'])
# Out:
# Amazing!: This soundtrack is my favorite music of all time, hands down. The intense sadness of "Prisoners of Fate" (which means all the more if you've played the game) and the hope in "A Distant Promise" and "Girl who Stole the Star" have been an important inspiration to me personally throughout my teen years. The higher energy tracks like "Chrono Cross ~ Time's Scar~", "Time of the Dreamwatch", and "Chronomantique" (indefinably remeniscent of Chrono Trigger) are all absolutely superb as well.This soundtrack is amazing music, probably the best of this composer's work (I haven't heard the Xenogears soundtrack, so I can't say for sure), and even if you've never played the game, it would be worth twice the price to buy it.I wish I could give it 6 stars.

# %%
trainDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   9999 non-null   int64
#  1   text    9999 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 156.4+ KB

# %% [markdown]
# ## Split the data into train and test

# %%
## ANSWER
## split the dataset
X_train, X_test, y_train, y_test = train_test_split(trainDF['text'],
                                                   trainDF['label'],
                                                   test_size=0.2,
                                                   random_state=1)

# %%
X_train
# Out:
# 4792    Slavery Still Exists: Excellent book. I've rea...
# 5757    Great job: I appreciate the books a great deal...
# 5526    Great Price, But......: I ordered these sheets...
# 5721    a new king: Steve Tene Bimbo was 25yrs old whe...
# 3990    If you buy this, good luck.: We purchased the ...
#                               ...
# 2895    SciFi Movie: Plenty of action and almost lives...
# 7813    Not Good: Too Expensive. 5- 1/2 cups are not t...
# 905     FT rules: Talk about a hokey plot and cheezy a...
# 5192    The odyssey: I thought that the Odyssey was a ...
# 235     Amazing!: LJ smith is a fantastic author who i...
# Name: text, Length: 7999, dtype: object

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Count Vectors as features

# %%
# create a count vectorizer object
count_vect = CountVectorizer(token_pattern = r'\w{1,}')

# Learn a vocabulary dictionary of all tokens in the raw documents
count_vect.fit(trainDF['text'])

# Transform documents to document-term matrix.
X_train_count = count_vect.transform(X_train)
X_test_count = count_vect.transform(X_test)

# %%
print(X_train_count)
# Out:
#   (0, 710)	4
#   (0, 1249)	1
#   (0, 1303)	1
#   (0, 1488)	1
#   (0, 1743)	1
#   (0, 2267)	1
#   (0, 3713)	1
#   (0, 3771)	3
#   (0, 4400)	1
#   (0, 4441)	1
#   (0, 5280)	1
#   (0, 7275)	1
#   (0, 7890)	1
#   (0, 10251)	1
#   (0, 10363)	1
#   (0, 10953)	2
#   (0, 12087)	1
#   (0, 12907)	1
#   (0, 13180)	1
#   (0, 13266)	1
#   (0, 13552)	1
#   (0, 14029)	5
#   (0, 14059)	1
#   (0, 14335)	2
#   (0, 16678)	1
#   :	:
#   (7998, 19238)	1
#   (7998, 19289)	1
#   (7998, 19523)	2
#   (7998, 19878)	1
#   (7998, 20584)	1
#   (7998, 21241)	1
#   (7998, 22374)	1
#   (7998, 23575)	1
#   (7998, 24364)	1
#   (7998, 25362)	1
#   (7998, 25876)	1
#   (7998, 26301)	1
#   (7998, 26886)	1
#   (7998, 27417)	1
#   (7998, 28071)	1
#   (7998, 28077)	1
#   (7998, 28101)	1
#   (7998, 28219)	1
#   (7998, 28412)	1
#   (7998, 28488)	2
#   (7998, 29043)	1
#   (7998, 30777)	1
#   (7998, 30860)	1
#   (7998, 30913)	1
#   (7998, 31285)	1

# %% [markdown]
# ### TF-IDF Vectors as features
# - Word level
# - N-Gram level
# - Character level

# %%
# %%time
# word level tf-idf
tfidf_vect = TfidfVectorizer(analyzer = 'word',
                             token_pattern = r'\w{1,}',
                             max_features = 5000)
print(tfidf_vect)

tfidf_vect.fit(trainDF['text'])
X_train_tfidf = tfidf_vect.transform(X_train)
X_test_tfidf  = tfidf_vect.transform(X_test)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=5000,
#                 min_df=1, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='\\w{1,}', tokenizer=None,
#                 use_idf=True, vocabulary=None)
# CPU times: user 613 ms, sys: 11.4 ms, total: 625 ms
# Wall time: 637 ms

# %%
# %%time
# ngram level tf-idf
tfidf_vect_ngram = TfidfVectorizer(analyzer = 'word',
                                   token_pattern = r'\w{1,}',
                                   ngram_range = (2, 3),
                                   max_features = 5000)
print(tfidf_vect_ngram)

tfidf_vect_ngram.fit(trainDF['text'])
X_train_tfidf_ngram = tfidf_vect_ngram.transform(X_train)
X_test_tfidf_ngram  = tfidf_vect_ngram.transform(X_test)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=5000,
#                 min_df=1, ngram_range=(2, 3), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='\\w{1,}', tokenizer=None,
#                 use_idf=True, vocabulary=None)
# CPU times: user 2.88 s, sys: 84 ms, total: 2.96 s
# Wall time: 3 s

# %%
# %%time
# characters level tf-idf
tfidf_vect_ngram_chars = TfidfVectorizer(analyzer = 'char',
                                         token_pattern = r'\w{1,}',
                                         ngram_range = (2, 3),
                                         max_features = 5000)
print(tfidf_vect_ngram_chars)

tfidf_vect_ngram_chars.fit(trainDF['text'])
X_train_tfidf_ngram_chars = tfidf_vect_ngram_chars.transform(X_train)
X_test_tfidf_ngram_chars  = tfidf_vect_ngram_chars.transform(X_test)
# Out:
# TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=5000,
#                 min_df=1, ngram_range=(2, 3), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='\\w{1,}', tokenizer=None,
#                 use_idf=True, vocabulary=None)
# /Users/jinyang/miniforge3/envs/test_opencv/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:524: UserWarning: The parameter 'token_pattern' will not be used since 'analyzer' != 'word'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# CPU times: user 4.46 s, sys: 65.7 ms, total: 4.53 s
# Wall time: 4.53 s

# %% [markdown]
# ### Text / NLP based features
#
# Create some other features.
#
# Char_Count = Number of Characters in Text
#
# Word Count = Number of Words in Text
#
# Word Density = Average Number of Char in Words
#
# Punctuation Count = Number of Punctuation in Text
#
# Title Word Count = Number of Words in Title
#
# Uppercase Word Count = Number of Upperwords in Text

# %%
from nltk.tokenize import word_tokenize

# %%
Char_count = []
Word_count = []
Word_density = []
Punctuation_count = []
Title_word_count = []
Uppercase_word_count = []

# %%
trainDF
# Out:
#       label                                               text
# 0         1  The best soundtrack ever to anything.: I'm rea...
# 1         1  Amazing!: This soundtrack is my favorite music...
# 2         1  Excellent Soundtrack: I truly like this soundt...
# 3         1  Remember, Pull Your Jaw Off The Floor After He...
# 4         1  an absolute masterpiece: I am quite sure any o...
# ...     ...                                                ...
# 9994      1  A revelation of life in small town America in ...
# 9995      1  Great biography of a very interesting journali...
# 9996      0  Interesting Subject; Poor Presentation: You'd ...
# 9997      0  Don't buy: The box looked used and it is obvio...
# 9998      1  Beautiful Pen and Fast Delivery.: The pen was ...
#
# [9999 rows x 2 columns]

# %%
for i in range(len(trainDF.text)):
    # Character count
    Char_count.append(len(trainDF.text[i]))
    
    # count of words
    Word_count.append(len(re.findall('[A-Za-z0-9]+', trainDF.text[i])))
    
    # word density
    Word_density.append(sum([len(x) for x in word_tokenize(trainDF.text[i])])/ Word_count[i])
    
    #upper case word count
    Uppercase_word_count.append(len(re.findall('[\bA-Z]+', trainDF.text[i])))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-0cb81fbabdb7> in <module>
# ----> 1 shape(Char_count)
#
# NameError: name 'shape' is not defined

# %%
trainDF['Char_count'] = Char_count
trainDF['Word_count'] = Word_count
trainDF['Word_density'] = Word_density
trainDF['Uppercase_word_count'] = Uppercase_word_count
trainDF
# Out:
#       label                                               text  Char_count  \
# 0         1  The best soundtrack ever to anything.: I'm rea...         509
# 1         1  Amazing!: This soundtrack is my favorite music...         760
# 2         1  Excellent Soundtrack: I truly like this soundt...         743
# 3         1  Remember, Pull Your Jaw Off The Floor After He...         481
# 4         1  an absolute masterpiece: I am quite sure any o...         825
# ...     ...                                                ...         ...
# 9994      1  A revelation of life in small town America in ...         867
# 9995      1  Great biography of a very interesting journali...         861
# 9996      0  Interesting Subject; Poor Presentation: You'd ...         650
# 9997      0  Don't buy: The box looked used and it is obvio...         135
# 9998      1  Beautiful Pen and Fast Delivery.: The pen was ...         536
#
#       Word_count  Word_density  Uppercase_word_count
# 0            102      4.049020                    12
# 1            136      4.735294                    27
# 2            122      5.131148                    59
# 3             90      4.388889                    31
# 4            148      4.621622                    20
# ...          ...           ...                   ...
# 9994         157      4.573248                    17
# 9995         143      5.041958                    16
# 9996         112      4.848214                    12
# 9997          29      3.758621                     4
# 9998         105      4.133333                    24
#
# [9999 rows x 6 columns]

# %%
# %%time
# ANSWER
# word count
print(Counter(word_tokenize(X_train[1])))
print(Counter(word_tokenize(X_train[1])).most_common(3))
# Out:
# Counter({'the': 9, ',': 7, 'of': 6, '``': 6, "''": 6, 'and': 4, 'soundtrack': 3, 'all': 3, '.': 3, '(': 3, ')': 3, 'I': 3, 'is': 2, 'my': 2, 'music': 2, 'The': 2, 'if': 2, 'you': 2, "'ve": 2, 'played': 2, 'game': 2, 'have': 2, 'to': 2, 'Chrono': 2, 'Time': 2, "'s": 2, "n't": 2, 'it': 2, 'Amazing': 1, '!': 1, ':': 1, 'This': 1, 'favorite': 1, 'time': 1, 'hands': 1, 'down': 1, 'intense': 1, 'sadness': 1, 'Prisoners': 1, 'Fate': 1, 'which': 1, 'means': 1, 'more': 1, 'hope': 1, 'in': 1, 'A': 1, 'Distant': 1, 'Promise': 1, 'Girl': 1, 'who': 1, 'Stole': 1, 'Star': 1, 'been': 1, 'an': 1, 'important': 1, 'inspiration': 1, 'me': 1, 'personally': 1, 'throughout': 1, 'teen': 1, 'years': 1, 'higher': 1, 'energy': 1, 'tracks': 1, 'like': 1, 'Cross': 1, '~': 1, 'Scar~': 1, 'Dreamwatch': 1, 'Chronomantique': 1, 'indefinably': 1, 'remeniscent': 1, 'Trigger': 1, 'are': 1, 'absolutely': 1, 'superb': 1, 'as': 1, 'well.This': 1, 'amazing': 1, 'probably': 1, 'best': 1, 'this': 1, 'composer': 1, 'work': 1, 'heard': 1, 'Xenogears': 1, 'so': 1, 'ca': 1, 'say': 1, 'for': 1, 'sure': 1, 'even': 1, 'never': 1, 'would': 1, 'be': 1, 'worth': 1, 'twice': 1, 'price': 1, 'buy': 1, 'it.I': 1, 'wish': 1, 'could': 1, 'give': 1, '6': 1, 'stars': 1})
# [('the', 9), (',', 7), ('of', 6)]
# CPU times: user 3.22 ms, sys: 100 µs, total: 3.32 ms
# Wall time: 3.33 ms

# %%
## load spaCy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Part of Speech in **SpaCy**
#
#     POS   DESCRIPTION               EXAMPLES
#     ----- ------------------------- ---------------------------------------------
#     ADJ   adjective                 big, old, green, incomprehensible, first
#     ADP   adposition                in, to, during
#     ADV   adverb                    very, tomorrow, down, where, there
#     AUX   auxiliary                 is, has (done), will (do), should (do)
#     CONJ  conjunction               and, or, but
#     CCONJ coordinating conjunction  and, or, but
#     DET   determiner                a, an, the
#     INTJ  interjection              psst, ouch, bravo, hello
#     NOUN  noun                      girl, cat, tree, air, beauty
#     NUM   numeral                   1, 2017, one, seventy-seven, IV, MMXIV
#     PART  particle                  's, not,
#     PRON  pronoun                   I, you, he, she, myself, themselves, somebody
#     PROPN proper noun               Mary, John, London, NATO, HBO
#     PUNCT punctuation               ., (, ), ?
#     SCONJ subordinating conjunction if, while, that
#     SYM   symbol                    $, %, §, ©, +, −, ×, ÷, =, :), 😝
#     VERB  verb                      run, runs, running, eat, ate, eating
#     X     other                     sfpksdpsxmsa
#     SPACE space
#
# Find out number of Adjective, Adverb, Noun, Numeric, Pronoun, Proposition, Verb.
#
#     Hint:
#     1. Convert text to spacy document
#     2. Use pos_
#     3. Use Counter

# %%
# Initialise some columns for feature's counts
trainDF['adj_count'] = 0
trainDF['adv_count'] = 0
trainDF['noun_count'] = 0
trainDF['num_count'] = 0
trainDF['pron_count'] = 0
trainDF['propn_count'] = 0
trainDF['verb_count'] = 0

# %%
for i in range(len(trainDF['text'])):
    doc = nlp(trainDF['text'][i])
    
    df = pd.DataFrame()
    df['text'] = [token.text for token in doc]
    df['lemma'] = [token.lemma_ for token in doc]
    df['is_punctuation'] = [token.is_punct for token in doc]
    df['is_space'] = [token.is_space for token in doc]
    df['shape'] = [token.shape_ for token in doc]
    df['part_of_speech'] = [token.pos_ for token in doc]
    df['pos_tag'] = [token.tag_ for token in doc]
    
    trainDF['adj_count'][i] = sum(df['part_of_speech']=='ADJ')
    trainDF['adv_count'][i] = sum(df['part_of_speech']=='ADV')
    trainDF['noun_count'][i] = sum(df['part_of_speech']=='NOUN')
    trainDF['num_count'][i] = sum(df['part_of_speech']=='NUM')
    trainDF['pron_count'][i] = sum(df['part_of_speech']=='PRON')
    trainDF['propn_count'][i] = sum(df['part_of_speech']=='PROPN')
    trainDF['verb_count'][i] = sum(df['part_of_speech']=='VERB')
# Out:
# <ipython-input-152-bd83b121b853>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trainDF['adj_count'][i] = sum(df['part_of_speech']=='ADJ')
# <ipython-input-152-bd83b121b853>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trainDF['adv_count'][i] = sum(df['part_of_speech']=='ADV')
# <ipython-input-152-bd83b121b853>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trainDF['noun_count'][i] = sum(df['part_of_speech']=='NOUN')
# <ipython-input-152-bd83b121b853>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trainDF['num_count'][i] = sum(df['part_of_speech']=='NUM')
# <ipython-input-152-bd83b121b853>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trainDF['pron_count'][i] = sum(df['part_of_speech']=='PRON')
# <ipython-input-152-bd83b121b853>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trainDF['propn_count'][i] = sum(df['part_of_speech']=='PROPN')
# <ipython-input-152-bd83b121b853>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trainDF['verb_count'][i] = sum(df['part_of_speech']=='VERB')

# %%
trainDF
# Out:
#       label                                               text  Char_count  \
# 0         1  The best soundtrack ever to anything.: I'm rea...         509
# 1         1  Amazing!: This soundtrack is my favorite music...         760
# 2         1  Excellent Soundtrack: I truly like this soundt...         743
# 3         1  Remember, Pull Your Jaw Off The Floor After He...         481
# 4         1  an absolute masterpiece: I am quite sure any o...         825
# ...     ...                                                ...         ...
# 9994      1  A revelation of life in small town America in ...         867
# 9995      1  Great biography of a very interesting journali...         861
# 9996      0  Interesting Subject; Poor Presentation: You'd ...         650
# 9997      0  Don't buy: The box looked used and it is obvio...         135
# 9998      1  Beautiful Pen and Fast Delivery.: The pen was ...         536
#
#       Word_count  Word_density  Uppercase_word_count  \
# 0            102      4.049020                    12
# 1            136      4.735294                    27
# 2            122      5.131148                    59
# 3             90      4.388889                    31
# 4            148      4.621622                    20
# ...          ...           ...                   ...
# 9994         157      4.573248                    17
# 9995         143      5.041958                    16
# 9996         112      4.848214                    12
# 9997          29      3.758621                     4
# 9998         105      4.133333                    24
#
#                                                 new_col  adj_count  adv_count  \
# 0     (The, best, soundtrack, ever, to, anything, .,...          8          4
# 1     (Amazing, !, :, This, soundtrack, is, my, favo...         13          7
# 2     (Excellent, Soundtrack, :, I, truly, like, thi...          5          4
# 3     (Remember, ,, Pull, Your, Jaw, Off, The, Floor...          6          3
# 4     (an, absolute, masterpiece, :, I, am, quite, s...         16         16
# ...                                                 ...        ...        ...
# 9994  (A, revelation, of, life, in, small, town, Ame...         17          7
# 9995  (Great, biography, of, a, very, interesting, j...         15          5
# 9996  (Interesting, Subject, ;, Poor, Presentation, ...         15          3
# 9997  (Do, n't, buy, :, The, box, looked, used, and,...          1          1
# 9998  (Beautiful, Pen, and, Fast, Delivery, ., :, Th...          9          4
#
#       noun_count  num_count  pron_count  propn_count  verb_count
# 0             17          1          11            2          14
# 1             22          1          13           13          12
# 2             17          4           7           40           6
# 3             13          0          10           15          11
# 4             18          3          10            9          16
# ...          ...        ...         ...          ...         ...
# 9994          35          0           6           10          20
# 9995          38          0           4           11          11
# 9996          26          0           9            2          14
# 9997           3          0           4            0           7
# 9998          15          0          15           12          11
#
# [9999 rows x 14 columns]

# %%
cols = [
    'Char_count', 'Word_count', 'Word_density', 'Uppercase_word_count',
    'adj_count', 'adv_count', 'noun_count', 'num_count', 
    'pron_count', 'propn_count', 'verb_count'
]

# cols = [
#     'char_count', 'word_count', 'word_density',
#     'punctuation_count', 'title_word_count',
#     'uppercase_word_count', 'adj_count',
#     'adv_count', 'noun_count', 'num_count',
#     'pron_count', 'propn_count', 'verb_count']

trainDF[cols].sample(5)
# Out:
#       Char_count  Word_count  Word_density  Uppercase_word_count  adj_count  \
# 968          776         147      4.353741                    33          9
# 160          891         163      4.533742                    29          8
# 2676         140          21      5.714286                     3          1
# 8187         514          99      4.232323                    14          7
# 2068         630         108      4.870370                    18          3
#
#       adv_count  noun_count  num_count  pron_count  propn_count  verb_count
# 968           9          21          5          17           22          21
# 160          12          33          1          15           18          23
# 2676          3           4          0           2            0           5
# 8187          6          26          1           5            6           8
# 2068          3          19          3          14           12          10

# %% [markdown]
# ### Topic Models as features

# %%
# %%time
# train a LDA Model
lda_model = LatentDirichletAllocation(n_components = 20, learning_method = 'online', max_iter = 20)

X_topics = lda_model.fit_transform(X_train_count)
topic_word = lda_model.components_ 
vocab = count_vect.get_feature_names()
# Out:
# CPU times: user 24.5 s, sys: 1.32 s, total: 25.9 s
# Wall time: 25.9 s

# %%
# view the topic models
n_top_words = 10
topic_summaries = []
print('Group Top Words')
print('-----', '-'*80)
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    top_words = ' '.join(topic_words)
    topic_summaries.append(top_words)
    print('  %3d %s' % (i, top_words))
# Out:
# Group Top Words
# ----- --------------------------------------------------------------------------------
#     0 de la y en el que con empire et farm
#     1 ground chinese redgrave rack speaker arts fraser youth spectacular mckellen
#     2 watched illustrations max cooking gammell artwork ignore emma italian realistic
#     3 battery charger charge instructions disk hill canon jones battle episodes
#     4 lola somehow mixed complicated victorian producer bloody ruin lunch indie
#     5 the cd music album and are songs they on great
#     6 dumb ahead haiku influence dish powers mystical napoleon embarrassed lemon
#     7 the i it to and a this is of was
#     8 bed camera power air apple light pump adapter sony letter
#     9 economics season science mystery twist fiction crime holmes community whom
#    10 christopher huppert tozer dumber gnostic 42 cc tricked luv manager
#    11 card software dog cable included computer games difference pc support
#    12 selections johnson ballet schure existent wagner bela backpacking kino fifty
#    13 the of a and book is to in this that
#    14 diary anne erotic fetched erotica interview pseudo trapped tism holocaust
#    15 cds television educational ann hopkins jewish redeeming bd trite projects
#    16 lens tag caps streets minority everyman dressed goods maddening synth
#    17 italy baseball chest tuscany larry wwi village fw bread whitney
#    18 cave bear clan ayla auel jean rod risk bears reread
#    19 dvd concert stargate german cat image allow tour un spanish

# %% [markdown]
# ## Modelling

# %%
## helper function

def train_model(classifier, feature_vector_train, label, feature_vector_valid):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)

    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)

    return accuracy_score(predictions, y_test)

# %%
# Keep the results in a dataframe
results = pd.DataFrame(columns = ['Count Vectors',
                                  'WordLevel TF-IDF',
                                  'N-Gram Vectors',
                                  'CharLevel Vectors'])

# %% [markdown]
# ### Naive Bayes Classifier

# %%
# %%time
# Naive Bayes on Count Vectors
accuracy1 = train_model(MultinomialNB(), X_train_count, y_train, X_test_count)
print('NB, Count Vectors    : %.4f\n' % accuracy1)
# Out:
# NB, Count Vectors    : 0.8335
#
# CPU times: user 10.9 ms, sys: 3.39 ms, total: 14.3 ms
# Wall time: 14.5 ms

# %%
# %%time
# Naive Bayes on Word Level TF IDF Vectors
accuracy2 = train_model(MultinomialNB(), X_train_tfidf, y_train, X_test_tfidf)
print('NB, WordLevel TF-IDF : %.4f\n' % accuracy2)
# Out:
# NB, WordLevel TF-IDF : 0.8355
#
# CPU times: user 10.9 ms, sys: 3.19 ms, total: 14.1 ms
# Wall time: 12.6 ms

# %%
# %%time
# Naive Bayes on Ngram Level TF IDF Vectors
accuracy3 = train_model(MultinomialNB(), X_train_tfidf_ngram, y_train, X_test_tfidf_ngram)
print('NB, N-Gram Vectors   : %.4f\n' % accuracy3)
# Out:
# NB, N-Gram Vectors   : 0.8365
#
# CPU times: user 8.88 ms, sys: 2.7 ms, total: 11.6 ms
# Wall time: 10.2 ms

# %%
# %%time
# # Naive Bayes on Character Level TF IDF Vectors
accuracy4 = train_model(MultinomialNB(), X_train_tfidf_ngram_chars, y_train, X_test_tfidf_ngram_chars)
print('NB, CharLevel Vectors: %.4f\n' % accuracy4)
# Out:
# NB, CharLevel Vectors: 0.8060
#
# CPU times: user 38.7 ms, sys: 22.9 ms, total: 61.6 ms
# Wall time: 62.5 ms

# %%
results.loc['Naïve Bayes'] = {
    'Count Vectors': accuracy1,
    'WordLevel TF-IDF': accuracy2,
    'N-Gram Vectors': accuracy3,
    'CharLevel Vectors': accuracy4}

# %% [markdown]
# ### Linear Classifier

# %%
# %%time
# Linear Classifier on Count Vectors
accuracy1 = train_model(LogisticRegression(solver = 'lbfgs', max_iter = 350), X_train_count, y_train, X_test_count)
print('LR, Count Vectors    : %.4f\n' % accuracy1)
# Out:
# LR, Count Vectors    : 0.8565
#
# CPU times: user 1.79 s, sys: 686 ms, total: 2.48 s
# Wall time: 1.17 s

# %%
# %%time
# Linear Classifier on Word Level TF IDF Vectors
accuracy2 = train_model(LogisticRegression(solver = 'lbfgs', max_iter = 100), X_train_tfidf, y_train, X_test_tfidf)
print('LR, WordLevel TF-IDF : %.4f\n' % accuracy2)
# Out:
# LR, WordLevel TF-IDF : 0.8750
#
# CPU times: user 94.1 ms, sys: 2.85 ms, total: 97 ms
# Wall time: 95.6 ms

# %%
# %%time
# Linear Classifier on Ngram Level TF IDF Vectors
accuracy3 = train_model(LogisticRegression(solver = 'lbfgs', max_iter = 100), X_train_tfidf_ngram, y_train, X_test_tfidf_ngram)
print('LR, N-Gram Vectors   : %.4f\n' % accuracy3)
# Out:
# LR, N-Gram Vectors   : 0.8515
#
# CPU times: user 63 ms, sys: 3.06 ms, total: 66.1 ms
# Wall time: 63.7 ms

# %%
# %%time
# Linear Classifier on Character Level TF IDF Vectors
accuracy4 = train_model(LogisticRegression(solver = 'lbfgs', max_iter = 100), X_train_tfidf_ngram_chars, y_train, X_test_tfidf_ngram_chars)
print('LR, CharLevel Vectors: %.4f\n' % accuracy4)
# Out:
# LR, CharLevel Vectors: 0.8455
#
# CPU times: user 209 ms, sys: 2.91 ms, total: 212 ms
# Wall time: 210 ms

# %%
results.loc['Logistic Regression'] = {
    'Count Vectors': accuracy1,
    'WordLevel TF-IDF': accuracy2,
    'N-Gram Vectors': accuracy3,
    'CharLevel Vectors': accuracy4}

# %% [markdown]
# ### Support Vector Machine

# %%
# %%time
# Support Vector Machine on Count Vectors
accuracy1 = train_model(LinearSVC(), X_train_count, y_train, X_test_count)
print('SVM, Count Vectors    : %.4f\n' % accuracy1)
# Out:
# SVM, Count Vectors    : 0.8430
#
# CPU times: user 337 ms, sys: 5.28 ms, total: 342 ms
# Wall time: 341 ms

# %%
# %%time
# Support Vector Machine on Word Level TF IDF Vectors
accuracy2 = train_model(LinearSVC(), X_train_tfidf, y_train, X_test_tfidf)
print('SVM, WordLevel TF-IDF : %.4f\n' % accuracy2)
# Out:
# SVM, WordLevel TF-IDF : 0.8615
#
# CPU times: user 65.7 ms, sys: 2.21 ms, total: 67.9 ms
# Wall time: 65.6 ms

# %%
# %%time
# Support Vector Machine on Ngram Level TF IDF Vectors
accuracy3 = train_model(LinearSVC(), X_train_tfidf_ngram, y_train, X_test_tfidf_ngram)
print('SVM, N-Gram Vectors   : %.4f\n' % accuracy3)
# Out:
# SVM, N-Gram Vectors   : 0.8305
#
# CPU times: user 51.5 ms, sys: 1.59 ms, total: 53.1 ms
# Wall time: 51.7 ms

# %%
# %%time
# Support Vector Machine on Character Level TF IDF Vectors
accuracy4 = train_model(LinearSVC(), X_train_tfidf_ngram_chars, y_train, X_test_tfidf_ngram_chars)
print('SVM, CharLevel Vectors: %.4f\n' % accuracy4)
# Out:
# SVM, CharLevel Vectors: 0.8495
#
# CPU times: user 275 ms, sys: 7.06 ms, total: 282 ms
# Wall time: 280 ms

# %%
results.loc['Support Vector Machine'] = {
    'Count Vectors': accuracy1,
    'WordLevel TF-IDF': accuracy2,
    'N-Gram Vectors': accuracy3,
    'CharLevel Vectors': accuracy4}

# %% [markdown]
# ### Bagging Models

# %%
# %%time
# Bagging (Random Forest) on Count Vectors
accuracy1 = train_model(RandomForestClassifier(n_estimators = 100), X_train_count, y_train, X_test_count)
print('RF, Count Vectors    : %.4f\n' % accuracy1)
# Out:
# RF, Count Vectors    : 0.8190
#
# CPU times: user 7.45 s, sys: 36.7 ms, total: 7.49 s
# Wall time: 7.49 s

# %%
# %%time
# Bagging (Random Forest) on Word Level TF IDF Vectors
accuracy2 = train_model(RandomForestClassifier(n_estimators = 100), X_train_tfidf, y_train, X_test_tfidf)
print('RF, WordLevel TF-IDF : %.4f\n' % accuracy2)
# Out:
# RF, WordLevel TF-IDF : 0.8325
#
# CPU times: user 1.98 s, sys: 12.4 ms, total: 1.99 s
# Wall time: 2 s

# %%
# %%time
# Bagging (Random Forest) on Ngram Level TF IDF Vectors
accuracy3 = train_model(RandomForestClassifier(n_estimators = 100), X_train_tfidf_ngram, y_train, X_test_tfidf_ngram)
print('RF, N-Gram Vectors   : %.4f\n' % accuracy3)
# Out:
# RF, N-Gram Vectors   : 0.7945
#
# CPU times: user 2.19 s, sys: 10.4 ms, total: 2.2 s
# Wall time: 2.2 s

# %%
# %%time
# Bagging (Random Forest) on Character Level TF IDF Vectors
accuracy4 = train_model(RandomForestClassifier(n_estimators = 100), X_train_tfidf_ngram_chars, y_train, X_test_tfidf_ngram_chars)
print('RF, CharLevel Vectors: %.4f\n' % accuracy4)
# Out:
# RF, CharLevel Vectors: 0.7955
#
# CPU times: user 6.87 s, sys: 30.2 ms, total: 6.9 s
# Wall time: 6.9 s

# %%
results.loc['Random Forest'] = {
    'Count Vectors': accuracy1,
    'WordLevel TF-IDF': accuracy2,
    'N-Gram Vectors': accuracy3,
    'CharLevel Vectors': accuracy4}

# %% [markdown]
# ### Boosting Models

# %%
# %%time
# Gradient Boosting on Count Vectors
accuracy1 = train_model(GradientBoostingClassifier(), X_train_count, y_train, X_test_count)
print('GB, Count Vectors    : %.4f\n' % accuracy1)
# Out:
# GB, Count Vectors    : 0.8040
#
# CPU times: user 23.7 s, sys: 78.6 ms, total: 23.8 s
# Wall time: 23.8 s

# %%
# %%time
# Gradient Boosting on Word Level TF IDF Vectors
accuracy2 = train_model(GradientBoostingClassifier(), X_train_tfidf, y_train, X_test_tfidf)
print('GB, WordLevel TF-IDF : %.4f\n' % accuracy2)
# Out:
# GB, WordLevel TF-IDF : 0.7965
#
# CPU times: user 7.27 s, sys: 30.7 ms, total: 7.3 s
# Wall time: 7.3 s

# %%
# %%time
# Gradient Boosting on Ngram Level TF IDF Vectors
accuracy3 = train_model(GradientBoostingClassifier(), X_train_tfidf_ngram, y_train, X_test_tfidf_ngram)
print('GB, N-Gram Vectors   : %.4f\n' % accuracy3)
# Out:
# GB, N-Gram Vectors   : 0.7435
#
# CPU times: user 4.05 s, sys: 7.77 ms, total: 4.06 s
# Wall time: 4.06 s

# %%
# %%time
# Gradient Boosting on Character Level TF IDF Vectors
accuracy4 = train_model(GradientBoostingClassifier(), X_train_tfidf_ngram_chars, y_train, X_test_tfidf_ngram_chars)
print('GB, CharLevel Vectors: %.4f\n' % accuracy4)
# Out:
# GB, CharLevel Vectors: 0.8120
#
# CPU times: user 1min 10s, sys: 365 ms, total: 1min 11s
# Wall time: 1min 11s

# %%
results.loc['Gradient Boosting'] = {
    'Count Vectors': accuracy1,
    'WordLevel TF-IDF': accuracy2,
    'N-Gram Vectors': accuracy3,
    'CharLevel Vectors': accuracy4}

# %%
results
# Out:
#                         Count Vectors  WordLevel TF-IDF  N-Gram Vectors  \
# Naïve Bayes                    0.8335            0.8355          0.8365
# Logistic Regression            0.8565            0.8750          0.8515
# Support Vector Machine         0.8430            0.8615          0.8305
# Random Forest                  0.8190            0.8325          0.7945
# Gradient Boosting              0.8040            0.7965          0.7435
#
#                         CharLevel Vectors
# Naïve Bayes                        0.8060
# Logistic Regression                0.8455
# Support Vector Machine             0.8495
# Random Forest                      0.7955
# Gradient Boosting                  0.8120

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
