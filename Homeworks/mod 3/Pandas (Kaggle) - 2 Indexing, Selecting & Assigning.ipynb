# %% [markdown]
# # Topic 2 - Indexing, Selecting & Assigning

# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
import os
os.chdir('/Users/jinyang/Desktop/Institute_of_Data/IOD_2020_JIN/data/')

# %%
df = pd.read_csv('winequality_merged.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine
# 0      9.4        5         1
# ...

# %%
df.shape
# Out:
# (6497, 13)

# %%
df.quality
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 6492    6
# 6493    5
# 6494    6
# 6495    7
# 6496    6
# Name: quality, Length: 6497, dtype: int64

# %%
df['quality']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 6492    6
# 6493    5
# 6494    6
# 6495    7
# 6496    6
# Name: quality, Length: 6497, dtype: int64

# %%
df['quality'][0]
# Out:
# 5

# %%
df.iloc[0]
# Out:
# fixed acidity            7.4000
# volatile acidity         0.7000
# citric acid              0.0000
# residual sugar           1.9000
# chlorides                0.0760
# free sulfur dioxide     11.0000
# total sulfur dioxide    34.0000
# density                  0.9978
# pH                       3.5100
# sulphates                0.5600
# alcohol                  9.4000
# quality                  5.0000
# red_wine                 1.0000
# Name: 0, dtype: float64

# %%
df.iloc[:, 0]
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 6492     6.2
# 6493     6.6
# 6494     6.5
# 6495     5.5
# 6496     6.0
# Name: fixed acidity, Length: 6497, dtype: float64

# %%
df.iloc[:3, 0]
# Out:
# 0    7.4
# 1    7.8
# 2    7.8
# Name: fixed acidity, dtype: float64

# %%
df.iloc[1:3, 0]
# Out:
# 1    7.8
# 2    7.8
# Name: fixed acidity, dtype: float64

# %%
df.iloc[[0,1,2],0]
# Out:
# 0    7.4
# 1    7.8
# 2    7.8
# Name: fixed acidity, dtype: float64

# %%
df.iloc[-5:]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  red_wine
# ...

# %%
df.loc[0, 'quality']
# Out:
# 5

# %%
df.loc[:, ['fixed acidity', 'chlorides', 'quality']]
# Out:
#       fixed acidity  chlorides  quality
# 0               7.4      0.076        5
# 1               7.8      0.098        5
# 2               7.8      0.092        5
# 3              11.2      0.075        6
# 4               7.4      0.076        5
# ...             ...        ...      ...
# 6492            6.2      0.039        6
# 6493            6.6      0.047        5
# 6494            6.5      0.041        6
# 6495            5.5      0.022        7
# 6496            6.0      0.020        6
#
# [6497 rows x 3 columns]

# %%
df.set_index("red_wine")
# Out:
#           fixed acidity  volatile acidity  citric acid  residual sugar  \
# red_wine
# 1                   7.4              0.70         0.00             1.9
# 1                   7.8              0.88         0.00             2.6
# 1                   7.8              0.76         0.04             2.3
# 1                  11.2              0.28         0.56             1.9
# 1                   7.4              0.70         0.00             1.9
# ...                 ...               ...          ...             ...
# 0                   6.2              0.21         0.29             1.6
# 0                   6.6              0.32         0.36             8.0
# 0                   6.5              0.24         0.19             1.2
# 0                   5.5              0.29         0.30             1.1
# 0                   6.0              0.21         0.38             0.8
#
#           chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# red_wine
# ...

# %%
df.quality == 5
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 6492    False
# 6493     True
# 6494    False
# 6495    False
# 6496    False
# Name: quality, Length: 6497, dtype: bool

# %%
df.loc[df.quality==5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 4               7.4              0.70         0.00             1.9      0.076
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 6481            5.5              0.32         0.13             1.3      0.037
# 6483            6.5              0.33         0.38             8.3      0.048
# 6487            6.8              0.22         0.36             1.2      0.052
# 6491            6.5              0.23         0.38             1.3      0.032
# 6493            6.6              0.32         0.36             8.0      0.047
#
# ...

# %%
df.loc[(df.red_wine == 1) & (df.quality > 7)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267             7.9              0.35         0.46             3.6      0.078
# 278            10.3              0.32         0.45             6.4      0.073
# 390             5.6              0.85         0.05             1.4      0.045
# 440            12.6              0.31         0.72             2.2      0.072
# 455            11.3              0.62         0.67             5.2      0.086
# 481             9.4              0.30         0.56             2.8      0.080
# 495            10.7              0.35         0.53             2.6      0.070
# 498            10.7              0.35         0.53             2.6      0.070
# 588             5.0              0.42         0.24             2.0      0.060
# 828             7.8              0.57         0.09             2.3      0.065
# 1061            9.1              0.40         0.50             1.8      0.071
# ...

# %%
df.loc[(df.red_wine == 1) | (df.quality >= 7)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6469            6.1              0.32         0.28             6.6      0.021
# 6475            6.2              0.38         0.42             2.5      0.038
# 6485            6.2              0.21         0.28             5.7      0.028
# 6486            6.2              0.41         0.22             1.9      0.023
# 6495            5.5              0.29         0.30             1.1      0.022
#
# ...

# %%
df.loc[df.quality.isin([6,7])]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 16              8.5              0.28         0.56             1.8      0.092
# 19              7.9              0.32         0.51             1.8      0.341
# ...             ...               ...          ...             ...        ...
# 6490            5.7              0.21         0.32             0.9      0.038
# 6492            6.2              0.21         0.29             1.6      0.039
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.loc[df.quality.notnull()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df['critic'] = 'everyone'
df['critic']
# Out:
# 0       everyone
# 1       everyone
# 2       everyone
# 3       everyone
# 4       everyone
#           ...
# 6492    everyone
# 6493    everyone
# 6494    everyone
# 6495    everyone
# 6496    everyone
# Name: critic, Length: 6497, dtype: object

# %%
df['index_backwards'] = range(len(df), 0, -1)
df['index_backwards']
# Out:
# 0       6497
# 1       6496
# 2       6495
# 3       6494
# 4       6493
#         ...
# 6492       5
# 6493       4
# 6494       3
# 6495       2
# 6496       1
# Name: index_backwards, Length: 6497, dtype: int64
