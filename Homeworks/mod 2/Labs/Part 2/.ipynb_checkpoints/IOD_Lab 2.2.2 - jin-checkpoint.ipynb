# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.2.2
# # *Mining Social Media with Twitter*

# %% [markdown]
# ## The Twitter API and Tweepy Package

# %% [markdown]
# The Twitter API provides access to tweets and comments, and allows an application to post tweets to the user's timeline.
#
# Twitter requires developers to create and authenticate an app before they can use the API. As of recent policy changes, however, new developers must be approved before they can create an app. There is no indication of the waiting period for approval.

# %% [markdown]
# ### 1. Apply for Developer Access
#
# Go to https://blog.twitter.com/developer/en_us/topics/tools/2018/new-developer-requirements-to-protect-our-platform.html
# and read the advice.
# ![image.png](attachment:image.png)

# %% [markdown]
# Apply at https://developer.twitter.com/en/apply-for-access.html
# ![image.png](attachment:image.png)

# %% [markdown]
# Then go to https://developer.twitter.com/en/review every day until you see whatever comes after this:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Create Your Twitter App
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Load Python Libraries

# %%
import tweepy
import json
import pprint

# %% [markdown]
# ### 4. Authenticate from your Python script

# %% [markdown]
# You could assign your authentication details explicitly, as follows:

# %%
my_consumer_key = ''      # your consumer key (string) goes in here
my_consumer_secret = ''   # your consumer secret key (string) goes in here
my_access_token = ''      # your access token (string goes in here
my_access_token_secret = ''  # your access token secret (string) goes in here

# %% [markdown]
# A better way would be to store these details externally, so they are not displayed in the notebook:
#
# - create a file called "auth_twitter.json" in your "notebooks" directory, and save your credentials there in JSON format:
#
# `{   "my_consumer_key": "your consumer key (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;` "my_consumer_secret": "your consumer secret key (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"your access token (string goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"my_access_token_secret": "your access token secret (string) goes in here"` <br>
# `}`
#
# (Nb. Parsers are very fussy. Make sure each key:value pair has a comma after it except the last one!)
#
# Use the following code to load the credentials:

# %%
pwd()  # make sure your working directory is where the file is

# %%
import json
import pprint
path_auth = 'auth_twitter.json'
auth = json.loads(open(path_auth).read())
pp = pprint.PrettyPrinter(indent=4)
# For debugging only:
#pp.pprint(auth)

my_consumer_key = auth['consumer_key']
my_consumer_secret = auth['consumer_secret']
my_access_token = auth['access_token']
my_access_token_secret = auth['access_token_secret']

# %% [markdown]
# Security considerations:
# - this method only keeps your credentials invisible as long as nobody accesses this notebook while it's running on your computer
# - if you wanted another user to have access to the executable notebook without divulging your credentials you should set up an OAuth 2.0 workflow to let them obtain and apply their own API tokens when using your app
# - if you just want to share your analyses, you could use a separate script (which you don't share) to fetch the data and save it locally, then use a second notebook (with no API access) to load and analyse the locally stored data

# %% [markdown]
# ### 5. Exploring the API

# %% [markdown]
# Here is how to connect to Twitter using the Tweepy library:

# %%
auth = tweepy.OAuthHandler(my_consumer_key, my_consumer_secret)
auth.set_access_token(my_access_token, my_access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# In the next cell, put the cursor after the '.' and hit the [tab] key to see the available members and methods in the response object:

# %%
api.

# %% [markdown]
# Consult the Tweept and Twitter API documentation. Print a few of the response members below:

# %% [markdown]
# This will fetch recent tweets from accounts you follow:

# %%
# Recent tweets from accounts you follow:
tweets = api.home_timeline()
for tweet in tweets:
    print(tweet.text)
# Out:
# ولدي شاطر بس مايدرس
# - ولدهم . https://t.co/BO4K3Znx9V
# Только что опубликовано видео @ Канонерка https://t.co/Ap751cJfJV
# Людвиг фон Мизес. Цитаты. №162 Об основной иллюзии классического либерализма
#  #минархизм #minarchism… https://t.co/JSBmGEhX2c
# مايضحكني الا انا وخويي كنا بنشغل اغنيه ونسينا اسمها وكلنا صلينا على النبي عشان نتذكرها
# Мюррей Ротбард. Цитаты. №118 Экстремальные ситуации не должны служить поводом для формирования этики обычной жизни… https://t.co/7Wjxb1ZHYP
# RT @Press_Focusnik: «Борьба с коррупцией - НЕТ!»
# Россия - это, когда женатый министр здравоохранения Омской области спокойно поехал на охот…
# Витебская Народная Республика
#
# Моваговоращая мразь aka Лука поздравил украинцев с Днём Победы. Вчитайтесь и поймит… https://t.co/K0nyBeEwuy
# RT @ia_panorama: ⚡️В Омске исчезла больница, в которой лечился Алексей Навальный https://t.co/ULhRE8l0tA
# RT @prof_preobr: Чулпан Хаматова подтвердила, что получила вид на жительство в Латвии.
#
# Любой россиянин, едва получив возможность, мчится о…
# https://t.co/lDUdHzI0mi
# День победы отгремел, пора вернуться в суровую реальность. Об эффективности на постсоветском пространстве "объединя… https://t.co/DEOoxEeeBS
# Покупаем сетевой кабель
# https://t.co/1kALmfH40A
# https://t.co/S5UTWyF3eP
# RT @Press_Focusnik: «Бумеранг за Навального?»
# Министр Омской области Александр Мураховский (экс-главврач больницы, который врал про состоян…
# RT @history_RF: 9 мая 1944, ровно за год до Победы, войска 4-го Украинского фронта (генерал армии Толбухин) при содействии Черноморского фл…
# RT @Voina_41_45: 9 мая 1943, за 2 года до Победы, при освобождении Крымской сержант Петр Таран руками вырвал три кола проволочного загражде…
# Россия в полуфинале ЧМ по керлингу https://t.co/IVLrNYALnk
# Два кавказца угрожая ножом отобрали у мимо проходящей девушки наушники, попутно вытолкнув её на проезжую часть. Дев… https://t.co/WbmkVAL4Pd
# В Петербурге полиция разыскивает среднеазиата, который прямо на улице ударил ножом 16-летнюю русскую девочку.
#
# Инци… https://t.co/6V7gvaHPD7
# Как получить российское гражданство... https://t.co/gXoQQdFDJX

# %% [markdown]
# The request to see your own recent tweets is similar, but uses the `user_timeline` endpoint. Try this below:

# %%
tweets = api.user_timeline()
for tweet in tweets:
    print(tweet.text)
# Out:
# What a beautiful day in sydney!!!

# %% [markdown]
# Now, instead of printing the text of each tweet, print the `created_at` and `id_str` methods:

# %%
for tweet in tweets:
    print(tweet.created_at)
    print(tweet.id_str)
# Out:
# 2012-04-05 23:15:10
# 188042123604525056

# %%
tweet
# Out:
# Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Thu Apr 05 23:15:10 +0000 2012', 'id': 188042123604525056, 'id_str': '188042123604525056', 'text': 'What a beautiful day in sydney!!!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 545828792, 'id_str': '545828792', 'name': 'jin', 'screen_name': 'gentley99', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 124, 'listed_count': 0, 'created_at': 'Thu Apr 05 09:22:04 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/2041328184/tiA87k39_normal', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2041328184/tiA87k39_normal', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2012, 4, 5, 23, 15, 10), id=188042123604525056, id_str='188042123604525056', text='What a beautiful day in sydney!!!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x104136460>, _json={'id': 545828792, 'id_str': '545828792', 'name': 'jin', 'screen_name': 'gentley99', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 124, 'listed_count': 0, 'created_at': 'Thu Apr 05 09:22:04 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/2041328184/tiA87k39_normal', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2041328184/tiA87k39_normal', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withhe ...

# %% [markdown]
# You can create a tweet as follows:

# %%
# create a tweet:
tweet = api.update_status('Test: Made with Tweepy')
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-19-cbd09fab22e5> in <module>
#       1 # create a tweet:
# ----> 2 tweet = api.update_status('Test: Made with Tweepy')
#
# ~/miniforge3/envs/test_opencv/lib/python3.8/site-packages/tweepy/api.py in update_status(self, *args, **kwargs)
#     203             kwargs['media_ids'] = list_to_csv(kwargs['media_ids'])
#     204
# --> 205         return bind_api(
#     206             api=self,
#     207             path='/statuses/update.json',
#
# ~/miniforge3/envs/test_opencv/lib/python3.8/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# ~/miniforge3/envs/test_opencv/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: Read-only application cannot POST.

# %% [markdown]
# (Nb. Don't abuse this feature! If you try to generate a zillion tweets in a loop, Twitter will ban youur account.)

# %% [markdown]
# Tweets can be deleted by reference to their `id_str` attribute:

# %%
# delete a tweet:
status = api.destroy_status(tweet.id_str)

# %% [markdown]
# You can follow a Tweeter:

# %%
# follow:
api.create_friendship('@YouTube')

# %% [markdown]
# or unfollow:

# %%
# unfollow:
api.destroy_friendship('@YouTube')

# %%
# Extracting tweets from the twitter user
#extract 100 tweets from the twitter user
posts = api.user_timeline(screen_name = "elonmusk", count = 100, lang = "en", tweet_mode="extended")

# %%
posts
# Out:
# [Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Thu May 13 09:54:35 +0000 2021', 'id': 1392780304138473473, 'id_str': '1392780304138473473', 'full_text': 'Energy usage trend over past few months is insane https://t.co/E6o9s87trw https://t.co/bmv9wotwKe', 'truncated': False, 'display_text_range': [0, 73], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/E6o9s87trw', 'expanded_url': 'https://cbeci.org', 'display_url': 'cbeci.org', 'indices': [50, 73]}], 'media': [{'id': 1392780299965140994, 'id_str': '1392780299965140994', 'indices': [74, 97], 'media_url': 'http://pbs.twimg.com/media/E1QmTbWVkAIjDXp.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E1QmTbWVkAIjDXp.jpg', 'url': 'https://t.co/bmv9wotwKe', 'display_url': 'pic.twitter.com/bmv9wotwKe', 'expanded_url': 'https://twitter.com/elonmusk/status/1392780304138473473/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1080, 'h': 1133, 'resize': 'fit'}, 'large': {'w': 1080, 'h': 1133, 'resize': 'fit'}, 'small': {'w': 648, 'h': 680, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 
, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_backg ...
#  Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Wed May 12 10:44:27 +0000 2021', 'id': 1392430463436812288, 'id_str': '1392430463436812288', 'full_text': '@Dreamweaver2oh @garyblack00 I think we’re maybe a month or two away from wide beta. But these things are hard to predict accurately. \n\nThe work we had to do for pure vision driving was needed for FSD, so much more progress has been made than it would seem.', 'truncated': False, 'display_text_range': [29, 257], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Dreamweaver2oh', 'name': 'Neural Net Neil 🧠', 'id': 360366929, 'id_str': '360366929', 'indices': [0, 15]}, {'screen_name': 'garyblack00', 'name': 'Gary Black', 'id': 1161703589942878208, 'id_str': '1161703589942878208', 'indices': [16, 28]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1392429392551464966, 'in_reply_to_status_id_str': '1392429392551464966', 'in_reply_to_user_id': 360366929, 'in_reply_to_user_id_str': '360366929', 'in_reply_to_screen_name': 'Dreamweaver2oh', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 266, 'favorite_count': 3285, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 12, 10, 44, 27), id=1392430463436812288, id_str='1392430463436812288', full_text='@Dreamweaver2oh @garyblack00 I think we’re maybe a month or two away from wide beta. But these things are hard to predict accurately. \n\nThe work we had to do for pure vision driving was needed for FSD, so much more progress has been made than it would seem.', truncated=False, display_text_range=[29, 257], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Dreamweaver2oh', 'name': 'Neural Net Neil 🧠', 'id': 360366929, 'id_str': '360366929', 'indices': [0, 15]}, {'screen_name': 'garyblack00', 'name': 'Gary Black', 'id': 1161703589942878208, 'id_str': '1161703589942878208', 'indices': [16, 28]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1392429392551464966, in_reply_to_status_id_str='1392429392551464966', in_reply_to_user_id=360366929, in_reply_to_user_id_str='360366929', in_reply_to_screen_name='Dreamweaver2oh', author=User(_api=<tweepy.api.API object at 0x104136460>, _json={'id': 441963 ...
#  Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Wed May 12 10:41:43 +0000 2021', 'id': 1392429777315790858, 'id_str': '1392429777315790858', 'full_text': '@flcnhvy @garyblack00 End of year, along with FSD, provided we get regulatory approval. Smart Summon is just a subset of FSD.', 'truncated': False, 'display_text_range': [22, 125], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'flcnhvy', 'name': 'Viv', 'id': 1060180551544528897, 'id_str': '1060180551544528897', 'indices': [0, 8]}, {'screen_name': 'garyblack00', 'name': 'Gary Black', 'id': 1161703589942878208, 'id_str': '1161703589942878208', 'indices': [9, 21]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1392429374545141761, 'in_reply_to_status_id_str': '1392429374545141761', 'in_reply_to_user_id': 1060180551544528897, 'in_reply_to_user_id_str': '1060180551544528897', 'in_reply_to_screen_name': 'flcnhvy', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 222, 'favorite_count': 3459, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 12, 10, 41, 43), id=1392429777315790858, id_str='1392429777315790858', full_text='@flcnhvy @garyblack00 End of year, along with FSD, provided we get regulatory approval. Smart Summon is just a subset of FSD.', truncated=False, display_text_range=[22, 125], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'flcnhvy', 'name': 'Viv', 'id': 1060180551544528897, 'id_str': '1060180551544528897', 'indices': [0, 8]}, {'screen_name': 'garyblack00', 'name': 'Gary Black', 'id': 1161703589942878208, 'id_str': '1161703589942878208', 'indices': [9, 21]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1392429374545141761, in_reply_to_status_id_str='1392429374545141761', in_reply_to_user_id=1060180551544528897, in_reply_to_user_id_str='1060180551544528897', in_reply_to_screen_name='flcnhvy', author=User(_api=<tweepy.api.API object at 0x104136460>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 5428 ...
#  Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Wed May 12 10:40:27 +0000 2021', 'id': 1392429457038667777, 'id_str': '1392429457038667777', 'full_text': '@Leo88Williams @garyblack00 Yes', 'truncated': False, 'display_text_range': [28, 31], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Leo88Williams', 'name': 'Leo Williams | 3 Motors ∆ No Problems', 'id': 1319260670748200960, 'id_str': '1319260670748200960', 'indices': [0, 14]}, {'screen_name': 'garyblack00', 'name': 'Gary Black', 'id': 1161703589942878208, 'id_str': '1161703589942878208', 'indices': [15, 27]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1392429344681693189, 'in_reply_to_status_id_str': '1392429344681693189', 'in_reply_to_user_id': 1319260670748200960, 'in_reply_to_user_id_str': '1319260670748200960', 'in_reply_to_screen_name': 'Leo88Williams', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 119, 'favorite_count': 2438, 'favorited': False, 'retweeted': False, 'lang': 'und'}, created_at=datetime.datetime(2021, 5, 12, 10, 40, 27), id=1392429457038667777, id_str='1392429457038667777', full_text='@Leo88Williams @garyblack00 Yes', truncated=False, display_text_range=[28, 31], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Leo88Williams', 'name': 'Leo Williams | 3 Motors ∆ No Problems', 'id': 1319260670748200960, 'id_str': '1319260670748200960', 'indices': [0, 14]}, {'screen_name': 'garyblack00', 'name': 'Gary Black', 'id': 1161703589942878208, 'id_str': '1161703589942878208', 'indices': [15, 27]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1392429344681693189, in_reply_to_status_id_str='1392429344681693189', in_reply_to_user_id=1319260670748200960, in_reply_to_user_id_str='1319260670748200960', in_reply_to_screen_name='Leo88Williams', author=User(_api=<tweepy.api.API object at 0x104136460>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2 ...
#  Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Wed May 12 10:38:34 +0000 2021', 'id': 1392428986001592321, 'id_str': '1392428986001592321', 'full_text': '@garyblack00 We had to focus on removing radar &amp; confirming safety. That release goes out next week to US production. Then a week or two to polish pure vision FSD &amp; v9 beta will release. Difference between v8 &amp; v9 is gigantic.', 'truncated': False, 'display_text_range': [13, 238], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'garyblack00', 'name': 'Gary Black', 'id': 1161703589942878208, 'id_str': '1161703589942878208', 'indices': [0, 12]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1392175578044850180, 'in_reply_to_status_id_str': '1392175578044850180', 'in_reply_to_user_id': 1161703589942878208, 'in_reply_to_user_id_str': '1161703589942878208', 'in_reply_to_screen_name': 'garyblack00', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 716, 'favorite_count': 10775, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 5, 12, 10, 38, 34), id=1392428986001592321, id_str='1392428986001592321', full_text='@garyblack00 We had to focus on removing radar &amp; confirming safety. That release goes out next week to US production. Then a week or two to polish pure vision FSD &amp; v9 beta will release. Difference between v8 &amp; v9 is gigantic.', truncated=False, display_text_range=[13, 238], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'garyblack00', 'name': 'Gary Black', 'id': 1161703589942878208, 'id_str': '1161703589942878208', 'indices': [0, 12]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1392175578044850180, in_reply_to_status_id_str='1392175578044850180', in_reply_to_user_id=1161703589942878208, in_reply_to_user_id_str='1161703589942878208', in_reply_to_screen_name='garyblack00', author=User(_api=<tweepy.api.API object at 0x104136460>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'fr ...
#  Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Wed May 12 07:57:30 +0000 2021', 'id': 1392388448384811008, 'id_str': '1392388448384811008', 'full_text': '@BoredElonMusk 👀', 'truncated': False, 'display_text_range': [15, 16], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BoredElonMusk', 'name': 'Bored Elon Musk', 'id': 1666038950, 'id_str': '1666038950', 'indices': [0, 14]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1392179134986481666, 'in_reply_to_status_id_str': '1392179134986481666', 'in_reply_to_user_id': 1666038950, 'in_reply_to_user_id_str': '1666038950', 'in_reply_to_screen_name': 'BoredElonMusk', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1447, 'favorite_count': 30172, 'favorited': False, 'retweeted': False, 'lang': 'und'}, created_at=datetime.datetime(2021, 5, 12, 7, 57, 30), id=1392388448384811008, id_str='1392388448384811008', full_text='@BoredElonMusk 👀', truncated=False, display_text_range=[15, 16], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BoredElonMusk', 'name': 'Bored Elon Musk', 'id': 1666038950, 'id_str': '1666038950', 'indices': [0, 14]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1392179134986481666, in_reply_to_status_id_str='1392179134986481666', in_reply_to_user_id=1666038950, in_reply_to_user_id_str='1666038950', in_reply_to_screen_name='BoredElonMusk', author=User(_api=<tweepy.api.API object at 0x104136460>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twim ...
#  Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Tue May 11 18:27:02 +0000 2021', 'id': 1392184489619517455, 'id_str': '1392184489619517455', 'full_text': '@Tesmanian_com 🇩🇪 🚘 ♥️ Geil! ♥️ 🚘 🇩🇪', 'truncated': False, 'display_text_range': [15, 36], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Tesmanian_com', 'name': 'Tesmanian.com', 'id': 1100520274200416256, 'id_str': '1100520274200416256', 'indices': [0, 14]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1392178385439256577, 'in_reply_to_status_id_str': '1392178385439256577', 'in_reply_to_user_id': 1100520274200416256, 'in_reply_to_user_id_str': '1100520274200416256', 'in_reply_to_screen_name': 'Tesmanian_com', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2008, 'favorite_count': 37679, 'favorited': False, 'retweeted': False, 'lang': 'cy'}, created_at=datetime.datetime(2021, 5, 11, 18, 27, 2), id=1392184489619517455, id_str='1392184489619517455', full_text='@Tesmanian_com 🇩🇪 🚘 ♥️ Geil! ♥️ 🚘 🇩🇪', truncated=False, display_text_range=[15, 36], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Tesmanian_com', 'name': 'Tesmanian.com', 'id': 1100520274200416256, 'id_str': '1100520274200416256', 'indices': [0, 14]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1392178385439256577, in_reply_to_status_id_str='1392178385439256577', in_reply_to_user_id=1100520274200416256, in_reply_to_user_id_str='1100520274200416256', in_reply_to_screen_name='Tesmanian_com', author=User(_api=<tweepy.api.API object at 0x104136460>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url':  ...
# ...
#  Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Wed Apr 28 21:55:33 +0000 2021', 'id': 1387525922463666179, 'id_str': '1387525922463666179', 'full_text': '@squawksquare Sorry 🤣🤣 \nhttps://t.co/v98BnxPXg6', 'truncated': False, 'display_text_range': [14, 47], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 
}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1387470002199175171, in_reply_to_status_id_str='1387470002199175171', in_reply_to_user_id=108365454, in_reply_to_user_id_str='108365454' ...
#  Status(_api=<tweepy.api.API object at 0x104136460>, _json={'created_at': 'Wed Apr 28 21:48:58 +0000 2021', 'id': 1387524266191687685, 'id_str': '1387524266191687685', 'full_text': '@OwenSparks_ @nbcsnl @MileyCyrus Might be something there haha', 'truncated': False, 'display_text_range': [33, 62], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'OwenSparks_', 'name': 'Owen Sparks 🌎', 'id': 829829626180599808, 'id_str': '829829626180599808', 'indices': [0, 12]}, {'screen_name': 'nbcsnl', 'name': 'Saturday Night Live - SNL', 'id': 28221296, 'id_str': '28221296', 'indices': [13, 20]}, {'screen_name': 'MileyCyrus', 'name': 'Miley Ray Cyrus', 'id': 268414482, 'id_str': '268414482', 'indices': [21, 32]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1387524079222206465, 'in_reply_to_status_id_str': '1387524079222206465', 'in_reply_to_user_id': 829829626180599808, 'in_reply_to_user_id_str': '829829626180599808', 'in_reply_to_screen_name': 'OwenSparks_', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imperator of Mars 😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 54288183, 'friends_count': 106, 'listed_count': 70793, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 8721, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 14267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1383184766959120385/MM9DHPWC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 458, 'favorite_count': 7471, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 4, 28, 21, 48, 58), id=1387524266191687685, id_str='1387524266191687685', full_text='@OwenSparks_ @nbcsnl @MileyCyrus Might be something there haha', truncated=False, display_text_range=[33, 62], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'OwenSparks_', 'name': 'Owen Sparks 🌎', 'id': 829829626180599808, 'id_str': '829829626180599808', 'indices': [0, 12]}, {'screen_name': 'nbcsnl', 'name': 'Saturday Night Live - SNL', 'id': 28221296, 'id_str': '28221296', 'indices': [13, 20]}, {'screen_name': 'MileyCyrus', 'name': 'Miley Ray Cyrus', 'id': 268414482, 'id_str': '268414482', 'indices': [21, 32]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1387524079222206465, in_reply_to_status_id_str='1387524079222206465', in_reply_to_user_id=829829626180599808, in_reply_to_user_id_str='829829626180599808', in_reply_to_screen_name='OwenSparks_', author=User(_api=<tweepy.api.API object at 0x104136460>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': 'Technoking of Tesla, Imp ...

# %%
#Print the last 5 twees from the account
print("show the 5 recent tweets: \n")
i = 1 
for tweet in posts[0:5]:
    print(str(i) + ') ' + tweet.full_text + '\n')
    i += 1
# Out:
# show the 5 recent tweets:
#
# 1) Energy usage trend over past few months is insane https://t.co/E6o9s87trw https://t.co/bmv9wotwKe
#
# 2) Tesla &amp; Bitcoin https://t.co/YSswJmVZhP
#
# 3) @WholeMarsBlog Haha
#
# 4) @blockfolio 🤣🤣
#
# 5) @garyblack00 Subscription rolls out in about a month

# %% [markdown]
# >
# >

# %% [markdown]
# >
# >

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
