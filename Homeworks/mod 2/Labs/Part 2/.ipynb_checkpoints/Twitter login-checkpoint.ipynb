# %%
my_consumer_key = 'qt2JyaipwxRRy1BisEs7lpMj7'      # your consumer key (string) goes in here
my_consumer_secret = 'ejVa8YqHvHfeDaVasQSrM8iryz9aiunOXEYpmQYJcom8lrPRhM'   # your consumer secret key (string) goes in here
my_access_token = '545828792-fusTpdnivtY6YojCsSkt4xVnIswvkpXrp95jExM5'      # your access token (string goes in here
my_access_token_secret = '1fCfNzHZqrngYt0hiul0ioT3sUv6shn8sVTcyTpIpghBd'  # your access token secret (string) goes in here
