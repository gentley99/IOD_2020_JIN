# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Data
#
# > The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# > One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this lab, we'll explore this dataset to find insight.
#
# [Titanic Dataset](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# # Data Dictionary
#
# | Variable |                                 Definition | Key                                            |
# |----------|-------------------------------------------:|------------------------------------------------|
# | Survival | Survival                                   | 0 = No, 1 = Yes                                |
# | Pclass   | Ticket class                               | 1 = 1st, 2 = 2nd, 3 = 3rd                      |
# | Sex      | Sex                                        |                                                |
# | Age      | Age in years                               |                                                |
# | SibSp    | # of siblings / spouses aboard the Titanic |                                                |
# | Parch    | # of parents / children aboard the Titanic |                                                |
# | Ticket   | Ticket number                              |                                                |
# | Fare     | Passenger fare                             |                                                |
# | Cabin    | Cabin number                               |                                                |
# | Embarked | Port of Embarkation                        | C = Cherbourg, Q = Queenstown, S = Southampton |

# %% [markdown]
# # Loading Modules

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Loading Dataset
#
# Read titanic dataset.

# %%
# Read Titanic Dataset
titanic_csv = '../../../data/titanic.csv'
titanic = pd.read_csv(titanic_csv)

# %% [markdown]
# # Explore Dataset

# %% [markdown]
# ## Head

# %%
# Check Head
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Tail

# %%
# Check Tail
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Shape
#
# Find shape of dataset.

# %%
# ANSWER
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Check Types of Data
#
# Check types of data you have

# %%
# ANSWER
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Check Null Values
#
# Check whether dataset have any null values.

# %%
# ANSWER
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check titanic data again
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Fill Null Values
#
# Is there any null values in any columns?
#
# - Identify those columns
# - Fill those null values using your own logic
#     - State your logic behind every steps

# %% [markdown]
# ### Age

# %%
# ANSWER
# as there are 177 missing observations which is almost 20% (177/891) of the sample,
# I have chose to keep the observations, 
# so that we can keep valuable informations of other variables. 

# identifying missing 
missing = titanic['Age'].isna()

# replacing with zero 
#titanic.loc[titanic['Age'].isna(), 'Age'] = 0

# replacing with median
titanic.loc[titanic['Age'].isna(), 'Age'] = titanic['Age'].median()

titanic['Age'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Cabin

# %%
# ASNWER
# Missing values for Cabin is 687 which is significant number of missing value. 
# If we drop this missing values, we will only have a small sample size.
# Therefore, I will not use this variable.
#

# %%
titanic['Cabin'].value_counts().sort_values()
# Out:
# B78            1
# A24            1
# A14            1
# D6             1
# B30            1
#               ..
# E101           3
# F33            3
# C23 C25 C27    4
# B96 B98        4
# G6             4
# Name: Cabin, Length: 147, dtype: int64

# %%
titanic['Cabin'].sort_values().unique()
# Out:
# array(['A10', 'A14', 'A16', 'A19', 'A20', 'A23', 'A24', 'A26', 'A31',
#        'A32', 'A34', 'A36', 'A5', 'A6', 'A7', 'B101', 'B102', 'B18',
#        'B19', 'B20', 'B22', 'B28', 'B3', 'B30', 'B35', 'B37', 'B38',
#        'B39', 'B4', 'B41', 'B42', 'B49', 'B5', 'B50', 'B51 B53 B55',
#        'B57 B59 B63 B66', 'B58 B60', 'B69', 'B71', 'B73', 'B77', 'B78',
#        'B79', 'B80', 'B82 B84', 'B86', 'B94', 'B96 B98', 'C101', 'C103',
#        'C104', 'C106', 'C110', 'C111', 'C118', 'C123', 'C124', 'C125',
#        'C126', 'C128', 'C148', 'C2', 'C22 C26', 'C23 C25 C27', 'C30',
#        'C32', 'C45', 'C46', 'C47', 'C49', 'C50', 'C52', 'C54', 'C62 C64',
#        'C65', 'C68', 'C7', 'C70', 'C78', 'C82', 'C83', 'C85', 'C86',
#        'C87', 'C90', 'C91', 'C92', 'C93', 'C95', 'C99', 'D', 'D10 D12',
#        'D11', 'D15', 'D17', 'D19', 'D20', 'D21', 'D26', 'D28', 'D30',
#        'D33', 'D35', 'D36', 'D37', 'D45', 'D46', 'D47', 'D48', 'D49',
# ...

# %% [markdown]
# ### Embarked

# %%
# ANSWER
# there is only 2 missing values
# I will replace with most common value
print(titanic['Embarked'].value_counts())

titanic.loc[titanic['Embarked'].isna(), 'Embarked'] = 'S'
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic['Embarked'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Describe
#
# Describe your dataset.

# %%
# ANSWER
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Relationship between Features and Survival
#
# Find relationship between categorical features and survived.
#
# **Describe your findings.**

# %%
def bar_charts(df, feature):
    '''
    Inputs:
    df: Dataset
    feature: Name of Feature to Check With Survived
    '''
    _agg = {
        'PassengerId': 'count'
    }
    _groupby = ['Survived', feature]

    df_feature = df.groupby(by=_groupby).agg(_agg)
    
    ax = df_feature.unstack().plot(kind='bar', figsize=(15,6))
    plt.legend(list(df_feature.index.levels[1].unique()))
    plt.xlabel('Survived')
    plt.xticks(np.arange(2), ('No', 'Yes'))
    plt.show();

# %% [markdown]
# ## Pclass
#
# Use barchart to find relationship between survived and pclass.  Note your findings.

# %%
# ANSWER
bar_charts(titanic, 'Pclass')
# Findings - Passengers in 3rd passenger class had the highest number of passengers who did not survive.
# For those who survived, passengers in 1st class had the highest number of those who survived.

# %% [markdown]
# ## Sex
#
# Use barchart to find relationship between survived and sex.  Note your findings.

# %%
# ANSWER
bar_charts(titanic, 'Sex')
# Findings - More females survived than males.

# %% [markdown]
# ## Parch
#
# Parch = Number of parents of children travelling with each passenger.

# %%
# ANSWER
bar_charts(titanic, 'Parch')
# Findings - Passengers with no parents/children travelling together were 
# the highest number for both those who survive and did not survive.
# Although they are the highest for those who survived and did not survive, 
# there is more number of passengers with no parents/children for those who did not survive.

# %% [markdown]
# ## SibSp

# %%
bar_charts(titanic, 'SibSp')
# number of siblings/spouses aboard.
# Findings - passengers who were on board with no siblings/spouse, 
# were the highest in both survived and did not survive. 
# Between those two, there were higher number of passengers with no siblings/spouse for those who did not survive.

# %% [markdown]
# ## Embarked

# %%
bar_charts(titanic, 'Embarked')
# Findings - Passengers who embarked from Southampton had the highest number for 
# both those who survived and did not survived. 
# Highest number of passengers embarked from Southampton did not survive.

# %% [markdown]
# # Feature Engineering
#
# Create some new features from existing feature.

# %% [markdown]
# ## Fare Class
#
# Create a new class based on their fare. Is there any relationship between fare and survival?

# %%
def create_fare_class(x):
    if x > 30:
        fare_class = 1
    elif x > 20 and x <= 30:
        fare_class = 2
    elif x > 10 and x <= 20:
        fare_class = 3
    else:
        fare_class = 4
    return fare_class

# %%
# ANSWER
titanic['fare_class'] = 0

for i in range(len(titanic['Fare'])):
    titanic['fare_class'][i] = create_fare_class(titanic['Fare'][i])
# Out:
# <ipython-input-87-34c940073039>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['fare_class'][i] = create_fare_class(titanic['Fare'][i])

# %%
bar_charts(titanic, 'fare_class')

# %% [markdown]
# ## Age Class

# %%
def create_age_class(x):
    if x > 60:
        age_class = 5
    elif x > 35 and x <= 60:
        age_class = 4
    elif x > 25 and x <= 35:
        age_class = 3
    elif x > 16 and x <= 25:
        age_class = 2
    else:
        age_class = 1
    return age_class

# %%
# ANSWER
titanic['age_class'] = 0

for i in range(len(titanic['Age'])):
    titanic['age_class'][i] = create_fare_class(titanic['Age'][i])
# Out:
# <ipython-input-93-5bec3de182af>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['age_class'][i] = create_fare_class(titanic['Age'][i])

# %%
# ANSWER
bar_charts(titanic, 'age_class')

# %% [markdown]
# # Staistical Overview

# %% [markdown]
# ## Correlation
#
# Find correlation between `survived` and other features.

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.034212 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.064910 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.339898  0.083081  0.018443
# Age             0.034212 -0.064910 -0.339898  1.000000 -0.233296 -0.172482
# SibSp          -0.057527 -0.035322  0.083081 -0.233296  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.172482  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096688  0.159651  0.216225
# fare_class      0.003258 -0.307600  0.719670 -0.117248 -0.380692 -0.387100
# age_class      -0.041989  0.052623  0.284850 -0.867703  0.270259  0.214464
#
#                  Fare  fare_class  age_class
# PassengerId  0.012658    0.003258  -0.041989
# Survived     0.257307   -0.307600   0.052623
# Pclass      -0.549500    0.719670   0.284850
# ...

# %% [markdown]
# # [BONUS] Hypothesis Testing
# ---
# Hypothesis testing is the use of statistics to determine the probability that a given hypothesis is true. The usual process of hypothesis testing consists of four steps.
#
# 1. Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
# 2. Identify a test statistic that can be used to assess the truth of the null hypothesis.
#
# 3. Compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.
#
# 4. Compare the p-value to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %% [markdown]
# ### Define Hypothesis
#
# > Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
#     Null Hypothesis (H0): There is no difference in the survival rate between the young and old passengers.
#
#     Alternative Hypothesis (HA): There is a difference in the survival rate between the young and old passengers.

# %% [markdown]
# ### Collect Data
#
# Next step is to collect data for each population group.
#
# Collect two sets of data, one with the passenger greater than 35 years of age and another one with the passenger younger than 35. The sample size should ideally be the same but it can be different. Lets say that the sample sizes is 100.

# %%
from scipy import stats

# %%
# ANSWER
N = 100
titanic_young = titanic[titanic['Age']<35].sample(n=100, random_state=1)
titanic_old = titanic[titanic['Age']>35].sample(n=100, random_state=1)

# %% [markdown]
# ### Set alpha (Let alpha = 0.05)
#
# > Identify a test statistic that can be used to assess the truth of the null hypothesis.

# %%
# ANSWER
alpha = 0.05

# %% [markdown]
# ### Calculate point estimate

# %%
a = titanic_young['Survived']
b = titanic_old['Survived']

# %%
## Calculate the variance to get the standard deviation
var_a = a.var()
var_b = b.var()

## Calculate the Standard Deviation
s = np.sqrt((var_a + var_b)/2)

# %%
s
# Out:
# 0.4877799636406695

# %% [markdown]
# ### Calculate test statistic

# %%
## Calculate the t-statistics
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))

# %%
t
# Out:
# 1.0147500588917464

# %% [markdown]
# ### Find the p-value
#
# > Compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.

# %%
## Compare with the critical t-value
## Degrees of freedom
df = 2*N - 2

#p-value after comparison with the t 
p = 1 - stats.t.cdf(t,df=df)

# %%
print(df)
print(p)
# Out:
# 198
# 0.15573168392571957

# %%
print("t = " + str(t))
print("p = " + str(2*p))
# Out:
# t = 1.0147500588917464
# p = 0.31146336785143913

# %% [markdown]
# ### Interpret results
#
# > Compare the p-value to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %%
def print_sig(p_value, alpha):
    if p_value < alpha:
        print("We reject our null hypothesis.")
    elif p_value > alpha:
        print("We fail to reject our null hypothesis.")
    else:
        print("Our test is inconclusive.")

# %%
## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))

print_sig(p2, alpha)
# Out:
# t = 1.0147500588917464
# p = 0.3114633678514391
# We fail to reject our null hypothesis.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
