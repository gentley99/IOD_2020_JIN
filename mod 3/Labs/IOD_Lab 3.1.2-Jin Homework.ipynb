# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 3.1.2
# # *Exploring Data*

# %% [markdown]
# ## Part 1: Continuous and Categorical Data

# %% [markdown]
# When we explore a dataset we usually produce textual and graphical output together, starting with a high-level overview of the data and gradually drilling down into the individual features and relationships between them.

# %% [markdown]
# Our most important libraries for this task are:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Cause plots to be displayed in the notebook:
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Override default figure sizing:
pylab.rcParams['figure.figsize'] = (10, 6)
sns.set(color_codes = True)

# %% [markdown]
# ## Data Profiling
#
# We actually start profiling the data when we first load it and check for input errors, as in the last lab. Once we have a DataFrame we can work with, however, things start getting more interesting.

# %% [markdown]
# **Load the file "bikeshare.csv" into a DataFrame named `bikes`, and check that it was loaded properly:**

# %%
#ANSWER:
df = pd.read_csv('../../data/bikeshare.csv')

# %%
df.head(2)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# We may want our program to capture particular features of the dataset into variables, but if we just want to get a feel for the data it is easier to use a higher-level Pandas method like `describe()`:
#
# **Use `describe` to get the description of datasets.**

# %%
#ANSWER:
df.describe().T
# Out:
#               count         mean          std   min        25%        50%  \
# instant     17379.0  8690.000000  5017.029500  1.00  4345.5000  8690.0000
# season      17379.0     2.501640     1.106918  1.00     2.0000     3.0000
# yr          17379.0     0.502561     0.500008  0.00     0.0000     1.0000
# mnth        17379.0     6.537775     3.438776  1.00     4.0000     7.0000
# hr          17379.0    11.546752     6.914405  0.00     6.0000    12.0000
# holiday     17379.0     0.028770     0.167165  0.00     0.0000     0.0000
# weekday     17379.0     3.003683     2.005771  0.00     1.0000     3.0000
# workingday  17379.0     0.682721     0.465431  0.00     0.0000     1.0000
# weathersit  17379.0     1.425283     0.639357  1.00     1.0000     1.0000
# temp        17379.0     0.496987     0.192556  0.02     0.3400     0.5000
# atemp       17379.0     0.475775     0.171850  0.00     0.3333     0.4848
# hum         17379.0     0.627229     0.192930  0.00     0.4800     0.6300
# ...

# %% [markdown]
# ### Continuous Data

# %% [markdown]
# We may have to do a lot of work before we can produce presentable graphics, but we can start creating simple visualisations as soon as we have a DataFrame.
#
# We usually start charting variables one-by-one (although when several have the same range it may be preferable to overlay them, using a different colour or symbol for each).

# %% [markdown]
# **Use the `scatter` method of Pandas to create a scatter plot of `windspeed`, `temp`:**

# %%
#ANSWER
plt.figure(figsize=(12,10))

plt.scatter(x=df['windspeed'], y=df['temp'], marker='.', color='r')
plt.xlabel("windspeed", size=20)
plt.ylabel("temp", size=20)
plt.title("Windspeed vs Temp", size=30)
# plt.xlim(0.2,0.6)
plt.show()

# %%
# trying different way
df.plot.scatter('windspeed','temp',color='r')
# Out:
# <AxesSubplot:xlabel='windspeed', ylabel='temp'>

# %%
# using sns this time
sns.lmplot(x='windspeed', y='temp', data=df)

# %%
#Jin - barplot
plt.figure(figsize=(12,10))
sns.barplot(x='hr', y='temp', data=df)
plt.show()

# %%
#Jin - lineplot
plt.figure(figsize=(12,10))
sns.lineplot(x='hr', y='temp', data=df, hue='season')
# Out:
# <AxesSubplot:xlabel='hr', ylabel='temp'>

# %% [markdown]
# **The `scatter` method has various parameters for controlling the appearance of the chart. Experiment with `s` , `linewidths`, and `alpha` below:**

# %%
#ANSWER
plt.figure(figsize=(12,10))

plt.scatter(x=df['windspeed'], y=df['temp'], marker='.', color='r', s=5, linewidths=10, alpha=.2)
plt.xlabel("windspeed", size=20)
plt.ylabel("temp", size=20)
plt.title("Windspeed vs Temp", size=30)
# plt.xlim(0.2,0.6)
plt.show()

# %% [markdown]
# The scatterplot shows us the raw data. Our next step is usually to see how it is distributed, which is what the histogram is for:
#
# > A histogram is used for continuous data, where the bins represent ranges of data, while a bar chart is a plot of categorical variables. <sup>[1](#histfootnote)</sup>
#
# - **Identify continuous varaibles**
# - **Create histogram for those variables**

# %%
plt.hist(df.temp, bins=20)
# Out:
# (array([  49.,   68.,  444.,  509., 1502.,  942., 1927.,  986., 1614.,
#          819., 1125., 1559., 1418., 1732., 1086.,  890.,  351.,  274.,
#           66.,   18.]),
#  array([0.02 , 0.069, 0.118, 0.167, 0.216, 0.265, 0.314, 0.363, 0.412,
#         0.461, 0.51 , 0.559, 0.608, 0.657, 0.706, 0.755, 0.804, 0.853,
#         0.902, 0.951, 1.   ]),
#  <BarContainer object of 20 artists>)

# %%
#ANSWER
plt.figure(figsize=(8,9))
fig, axs = plt.subplots(2,2, gridspec_kw={'hspace': .5})

fig.suptitle("Windspeed and Temp")
axs[0,0].hist(x=df['windspeed'], bins=20)
axs[0,0].set_title("Windspeed")
axs[0,0].set_xlabel('windspeed')

axs[0,1].hist(x=df['temp'], bins=20)
axs[0,1].set_title('Temp')
axs[0,1].set_xlabel('temp')

axs[1,0].hist(x=df['hum'], bins=20)
axs[1,0].set_title('Hum')
axs[1,0].set_xlabel('hum')

axs[1,1].hist(x=df['atemp'], bins=20)
axs[1,1].set_title('atemp')
axs[1,1].set_xlabel('atemp')
# Out:
# Text(0.5, 0, 'atemp')

# %%
#Jin - hist
plt.figure(figsize=(12,10))
sns.displot(df, x='windspeed')
plt.show()

# %%
#Jin - hist
plt.figure(figsize=(12,10))
sns.displot(df, x='temp')
plt.show()

# %% [markdown]
# What do the horizontal and vertical axes represent?

# %% [markdown]
# #### ANSWER:
#     horiz = magnitude of `atemp`, apparently normalised to [0, 1], discretised into bins of width 0.1;
#     vertical = counts of samples in each bin.

# %%
plt.figure(figsize=(8,9))
fig, axs = plt.subplots()

plt.hist(x=df['atemp'], bins=10)
plt.title('atemp', size=20)
plt.xlabel('atemp', size=15)
plt.ylabel('ounts of samples in each bin', size=15)
# Out:
# Text(0, 0.5, 'ounts of samples in each bin')

# %% [markdown]
# *NOTE: Samples in a given bin are greater than the axis value of its left side and less than or equal to the axis value of its right side. (The left-most bin is an exception: it represents greater than or equal to.)*

# %% [markdown]
# The box-and-whisker plot provides a compact view of the major percentiles of the distribution:
#
# **Make a box and whisker plot for the column ``atemp``.**
#
# > The box extends from the lower to
# upper quartile values of the data, with a line at the median. The whiskers extend from the box to show the range of the data.  Flier points are those past the end of the whiskers.

# %%
#ANSWER
plt.boxplot(x='atemp', data=df)
plt.title('Box plot - atemp')
plt.xlabel('atemp')
# Out:
# Text(0.5, 0, 'atemp')

# %% [markdown]
# This kind of plot really shines when we want to show several distributions at once (as long as they have compatible ranges).
#
# **Plot `atemp` and `windspeed` together. Change labels accordingly.**

# %%
plt.boxplot(df[['atemp', 'windspeed']], labels=['atemp', 'windspeed'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff883ed6520>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff883ed6be0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff883ed61f0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7ff883ee32e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff883ee3640>,
# ...
#  'means': []}

# %%
sns.boxplot(x='species', y='sepal_width', data=iris_data)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
#ANSWER

plt.boxplot(x='atemp', data=df, positions=[1])
plt.boxplot(x='windspeed', data=df, positions=[2])
plt.xticks([1,2],['atemp','windspeed'])
plt.title('atemp and windspeed')
# Out:
# Text(0.5, 1.0, 'atemp and windspeed')

# %% [markdown]
# ### Classified Data
#
# Samples may represent different classes according to one or more categorical variables. Sometimes our goal is to discover these classes, or to train a classification model from samples that have been manually classified.

# %% [markdown]
# Here, the famous "Iris" dataset gets loaded from the UCI repository:

# %%
import urllib

# get Iris dataset from UCI Machine Learning Repository:
url = "http://goo.gl/HppjFh" 
raw_data = urllib.request.urlopen(url)

# load the CSV file:
iris_data = pd.read_csv(raw_data, delimiter = ",", 
                        names = ('sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'))

# %% [markdown]
# Note that the column names were overridden by the `names` argument of the Pandas `read.csv` method. This requires prior knowledge of the dataset, which we would normally get from a data dictionary (although sometimes we just have to figure it out for ourselves).

# %% [markdown]
# **Print the first few rows of this DataFrame:**

# %%
#ANSWER
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# In this dataset, `species` has several possible values (representing the classes of the samples).
#
# **Find out distinct number of `species` and number of sample for each `species` in this dataset.**

# %%
#ANSWER
iris_data['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# We often need to capture the number of classes in code. We can do this with a variation on the above. Try this below:

# %%
#ANSWER
len(iris_data['species'].unique())
iris_data['species'].unique().tolist()
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %% [markdown]
# We often need to calculate aggregate values within subgroups of the dataset. The Pandas DataFrame method for this is `groupby`.
#
# **Apply the `groupby` method to get `mean` of `sepal_length` and `sepal_width` for the above dataset.**

# %%
#ANSWER 
iris_data.groupby(by='species').agg({'sepal_length':'mean', 'sepal_width':'mean'})
# Out:
#                  sepal_length  sepal_width
# species
# Iris-setosa             5.006        3.418
# Iris-versicolor         5.936        2.770
# Iris-virginica          6.588        2.974

# %%
iris_data.groupby(by='species')['sepal_length','sepal_width'].agg(['mean','min','max'])
# Out:
# <ipython-input-47-c0a70eddd6ff>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   iris_data.groupby(by='species')['sepal_length','sepal_width'].agg(['mean','min','max'])
#                 sepal_length           sepal_width
#                         mean  min  max        mean  min  max
# species
# Iris-setosa            5.006  4.3  5.8       3.418  2.3  4.4
# Iris-versicolor        5.936  4.9  7.0       2.770  2.0  3.4
# Iris-virginica         6.588  4.9  7.9       2.974  2.2  3.8

# %% [markdown]
# The Pandas `plot` method provides a quick way to produce a scatter plot.
#
# **Draw a Scatterplot showing sepal width and length using the Pandas `plot` method.**

# %%
#ANSWER
iris_data.plot(kind='scatter', x='sepal_length', y='sepal_width', color='blue')
plt.title('Sepal length and width', size=20)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.show()

# %% [markdown]
# **Draw a Barplot showing sepal width and length using the Pandas plot method.**

# %%
#ANSWER
iris_data.plot(kind='bar', x='sepal_length', y='sepal_width')
plt.title("sepal_length and sepal_width")
# Out:
# Text(0.5, 1.0, 'sepal_length and sepal_width')

# %% [markdown]
# Draw a Scatterplot showing sepal width and length using the Pandas plot method.
#
# **[BONUS] Set `title`, `xlabel`, `ylabel` to the plot**

# %%
#ANSWER
iris_data.plot(kind='scatter', x='sepal_length', y='sepal_width', color='blue')
plt.title('sepal_legth and sepal_width', size=30)
plt.xlabel('Sepal Length', size=20)
plt.ylabel('Sepal Width', size=20)

plt.show()

# %% [markdown]
# In this dataset we have also `petal_width`, `petal_length`.
#
# **Try to draw Scatterplot using these variables.**

# %%
#ANSWER
iris_data.plot(kind='scatter', x='petal_width', y='petal_length', color='red')
plt.title('Petal width and length')
plt.xlabel('Petal width')
plt.ylabel('Petal length')
plt.show()

# %% [markdown]
# In this case, we already have different species, so we can colour the points accordingly. This is easy to do using the Seaborn library. Try using `lmplot` of seaborn library and use the parameter `hue` and `fit_reg = False`.
#
# **Draw a Scatterplot showing sepal width and length.**

# %%
# ANSWER
# Draw a Scatterplot showing sepal width and length:
plt.figure(figsize=(15,15))
sns.lmplot(data=iris_data, x='sepal_width', y='sepal_length', hue='species', fit_reg=True)
plt.title('Sepal width and length')
# Out:
# Text(0.5, 1.0, 'Sepal width and length')

# %% [markdown]
# **[BONUS] Draw a Scatterplot showing sepal width and length. Without using seaborn.**

# %%
# ANSWER
iris_setosa = iris_data['species']=='Iris-setosa'
iris_versicolor = iris_data['species']=='Iris-versicolor'
iris_virginica = iris_data['species']=='Iris-virginica'
plt.scatter(x=iris_data['sepal_width'].loc[iris_setosa], y=iris_data['sepal_length'].loc[iris_setosa], 
            color='blue',label='iris setosa')
plt.scatter(x=iris_data['sepal_width'].loc[iris_versicolor], y=iris_data['sepal_length'].loc[iris_versicolor], 
            color='orange', label='iris versicolor')
plt.scatter(x=iris_data['sepal_width'].loc[iris_virginica], y=iris_data['sepal_length'].loc[iris_virginica], 
            color='green', label='iris virginica')
plt.legend()
plt.title('Sepal width and length')
plt.xlabel('Sepal width')
plt.ylabel('Sepal length')
# Out:
# Text(0, 0.5, 'Sepal length')

# %% [markdown]
# To find out why this function is called `lmplot`, try it again with `fit_reg` = True:
#
# **Draw a Scatterplot showing sepal width and length:**

# %%
# ANSWER
# Draw a Scatterplot showing sepal width and length:
sns.lmplot(data=iris_data, x='sepal_width', y='sepal_length', hue='species', fit_reg=True)
plt.title('Sepal width and length')
# Out:
# Text(0.5, 1.0, 'Sepal width and length')

# %% [markdown]
# The Seaborn `jointplot` function charts a correlation along with both distributions:
#
# **Draw a jointplot showing sepal width and length:**

# %%
# ANSWER
sns.jointplot(data=iris_data, x='sepal_width', y='sepal_length', hue='species')

# %% [markdown]
# When we want to see all the correlations at once, we can use `pairplot`:
#
# **Draw a `pairplot` of the dataset:**

# %%
# ANSWER
sns.pairplot(iris_data)

# %% [markdown]
# And, if the classes are known, we can apply colour using the `hue` parameter. Try this below:

# %%
# ANSWER
sns.pairplot(iris_data, hue='species')

# %% [markdown]
# Note that this gave us class-based distributions instead of an overall histogram, as well.

# %% [markdown]
# When we want to see numerical values of the correlations, the Pandas `corr` method provides a table of pair-wise correlations between the features in the DataFrame:

# %%
# ANSWER
iris_data.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ### High-Level Data Profiling Libraries

# %% [markdown]
# We need to master the basic data profiling functions because we will by using them frequently, for exploring data and answering ad hoc questions. In a production solution, we may need to incorporate specific data profiling code into our script so that we can automate data cleaning. However, when we just want to examine the data interactively before we start modelling, it is easier to use a high-level library like the following:
#
# > pip install pandas_profiling

# %%
# ANSWER
import pandas_profiling
df = pd.read_csv("../../data/Meteorite_Landings.csv", parse_dates = ['year'], encoding = 'UTF-8')
df.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong               GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775000, 6.083330)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333    (56.183330, 10.233330)
# ...

# %% [markdown]
# Use `ProfileReport` of `pandas_profiling` to get the overview of the dataset.

# %%
# ANSWER
from pandas_profiling import ProfileReport

profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.10.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-01-07 23:33:05.652505&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# For **HOMEWORK**: check out the `pydqc` library.

# %% [markdown]
# ## Part 2: Time Series and Geospatial Data

# %% [markdown]
# ## Time Series
#
# A time series is basically a series or a data frame with a time-based index column. Working with time series introduces a lot of challenges and possibilities, but most tasks are catered for by the standard libraries in Python.

# %% [markdown]
# Here is a history of air passenger counts by month, loaded into an ordinary DataFrame:

# %%
airpass = pd.read_csv('../../data/AirPassengers.csv')
airpass.head()
# Out:
#   TravelDate  Passengers
# 0   1/1/1949         112
# 1   2/1/1949         118
# 2   3/1/1949         132
# 3   4/1/1949         129
# 4   5/1/1949         121

# %%
airpass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TravelDate  144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# Before going any further, the `TravelDate` column needs to be converted to the `datetime` type.

# %%
# ANSWER
import datetime as dt
airpass['TravelDate'] = pd.to_datetime(airpass['TravelDate'])
airpass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TravelDate  144 non-null    datetime64[ns]
#  1   Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
# airpass['TravelDate'] = airpass['TravelDate'].dt.strftime('%d/%m/%Y')
# airpass.head()
# Out:
#    TravelDate  Passengers
# 0  01/01/1949         112
# 1  01/02/1949         118
# 2  01/03/1949         132
# 3  01/04/1949         129
# 4  01/05/1949         121

# %% [markdown]
# Set `TravelDate` as index

# %%
# ANSWER
airpass = airpass.set_index('TravelDate')

# %% [markdown]
# Now, Pandas knows that the first column of this DataFrame is a datetime index, so it only shows one column of data:
#
# Use `head` to check.

# %%
# ANSWER
airpass.head()
# Out:
#             Passengers
# TravelDate
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# Here's how to see the values of the index:

# %%
airpass.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='TravelDate', length=144, freq=None)

# %% [markdown]
# If we had multiple data columns but we only wanted to work with a time series of one of them, we could pull that column into a 1D time series:

# %%
ts = airpass['Passengers']

# %% [markdown]
# We use the datetime index exactly like a row number index:

# %%
print(ts['1949-01-01'])
# Out:
# 112

# %% [markdown]
# Or, we can refer to the row by its datetime equivalent:

# %%
from datetime import datetime
print(ts[datetime(1949,1,1)])
# Out:
# 112

# %% [markdown]
# Happily, Pandas makes it easy to slice data at a courser grain. We can refer to a whole year of data by omitting the month and day form the index:

# %%
print(ts['1949'])
# Out:
# TravelDate
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# 1949-08-01    148
# 1949-09-01    136
# 1949-10-01    119
# 1949-11-01    104
# 1949-12-01    118
# Name: Passengers, dtype: int64

# %% [markdown]
# The most basic way to plot a time series is to let Pandas apply the default:

# %%
ts.plot();

# %% [markdown]
# ## Geospatial Data
#
# Geospatial data is map-based (although what constitutes a "map" can go beyond the familiar). Ultimately, geographic data  occurs either in bitmap (raster) form or vector (resizeable polygons). It is not unusual for the two kinds of data to be used together.
#
# Because borders are often complex, following river courses, mountain ranges, and so on, the files that describe their geometries can be large. To reduce file sizes and image rendering times, we prefer to work with polygons that are no more detailed than the maximum resolution we need for our task. For this reason, geospatial files are often available at several different resolutions.

# %% [markdown]
# There are several popular options for working with maps in Python. We will use folium for its breadth and its use of open-source data.

# %%
import folium

# %%
# Read SF Incidents data
crime_csv = '../../data/SFPD_Incidents-Current_Year_2015.csv'

# %% [markdown]
# Convert `Date` Column to DateTime and set as index

# %%
# ANSWER
df = pd.read_csv(crime_csv)
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

# %%
df.head()
# Out:
#             IncidntNum      Category                         Descript  \
# Date
# 2015-09-20   150827188  NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED
# 2015-09-20   150827213       ASSAULT      INFLICT INJURY ON COHABITEE
# 2015-09-20   150827213       ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE
# 2015-09-20   150827213       ASSAULT           CHILD ABUSE (PHYSICAL)
# 2015-09-20   150827213       ASSAULT              MAYHEM WITH A KNIFE
#
#            DayOfWeek   Time PdDistrict      Resolution  \
# Date
# 2015-09-20    Sunday  23:54   RICHMOND       UNFOUNDED
# 2015-09-20    Sunday  23:45  INGLESIDE  ARREST, BOOKED
# 2015-09-20    Sunday  23:45  INGLESIDE  ARREST, BOOKED
# 2015-09-20    Sunday  23:45  INGLESIDE  ARREST, BOOKED
# 2015-09-20    Sunday  23:45  INGLESIDE  ARREST, BOOKED
#
#                              Address           X          Y  \
# Date
# 2015-09-20  3000 Block of CLEMENT ST -122.491851  37.781756
# 2015-09-20     100 Block of LOEHR ST -122.413676  37.712617
# ...

# %% [markdown]
# Draw a timeseries plot to visualize number of crimes for each day.

# %%
# ANSWER
num_crimes = df.groupby('Date').count()

# %%
num_crimes
# Out:
#             IncidntNum  Category  Descript  DayOfWeek  Time  PdDistrict  \
# Date
# 2015-01-02         395       395       395        395   395         395
# 2015-01-03         428       428       428        428   428         428
# 2015-01-04         325       325       325        325   325         325
# 2015-01-05         449       449       449        449   449         449
# 2015-01-06         407       407       407        407   407         407
# ...                ...       ...       ...        ...   ...         ...
# 2015-09-16         413       413       413        413   413         413
# 2015-09-17         403       403       403        403   403         403
# 2015-09-18         390       390       390        390   390         390
# 2015-09-19         421       421       421        421   421         421
# 2015-09-20         392       392       392        392   392         392
#
#             Resolution  Address    X    Y  Location
# Date
# ...

# %%
plt.plot(num_crimes.index.values, num_crimes['IncidntNum'])
plt.title('Number of crimes for each day')
plt.xlabel('Dates')
plt.ylabel('Number of crimes')
plt.xticks(rotation=45)
# Out:
# (array([16436., 16467., 16495., 16526., 16556., 16587., 16617., 16648.,
#         16679., 16709.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# Using folium we can easily create a map. As it's SF data, by default we are using SF location.

# %%
def generateBaseMap(default_location=[37.76, -122.45], default_zoom_start=12):
    '''
    Create a base map
    '''
    base_map = folium.Map(
        location = default_location
        , control_scale = True
        , zoom_start = default_zoom_start
    )
    
    return base_map

# %%
base_map = generateBaseMap(default_location=[37.76, -122.45])
display(base_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Add a marker in the map using `Folium.Marker` for first 100 rows of the dataset.

# %%
# ANSWER
for i in range(0,100):
    folium.Marker([df[i]['X'], df.iloc[i]['Y']], popup=df.iloc[i]['PdDistrict']).add_to(base_map)
base_map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/python38/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-328-83de0751627e> in <module>
#       1 # ANSWER
# ...

# %% [markdown]
# Add a cricle in the map using `Folium Circle` for first 100 rows of the dataset.

# %%
# ANSWER

# %% [markdown]
# [BONUS] Create a heatmap of the incident happened in SF.

# %% [markdown]
# **HOMEWORK** Explore Folium as mush as you can.
#
# **HOMEWORK** Explore GeoPandas

# %% [markdown]
# # More Resources
#
# <a name="histfootnote">1</a>: [Histogram](https://en.wikipedia.org/wiki/Histogram)
#
# The matplotlib users' guide is at http://pageperso.lif.univ-mrs.fr/~francois.denis/IAAM1/Matplotlib.pdf.

# %% [markdown]
# For visualisation ideas and code see https://python-graph-gallery.com/:

# %%
# GeoPandas

> The goal of GeoPandas is to make working with geospatial data in python easier. It combines the capabilities of pandas and shapely, providing geospatial operations in pandas and a high-level interface to multiple geometries to shapely. GeoPandas enables you to easily do operations in python that would otherwise require a spatial database such as PostGIS.

[GeoPandas 0.4.0](http://geopandas.org/index.html#)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
