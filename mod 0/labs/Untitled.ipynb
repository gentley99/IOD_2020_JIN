# %%
x = int(1.9)
x
# Out:
# 1

# %%
x = float(3)
x
# Out:
# 3.0

# %%
my_list = ['a', 'b', 'c']

# %%
my_list.append('d')

# %%
my_list.insert(1, 'f')

# %%
my_list
# Out:
# ['a', 'f', 'b', 'c', 'd']

# %%
my_list.pop(1)
# Out:
# 'f'

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
import os
import numpy as np
import pandas as pd

os.chdir('/Users/jinyang/Desktop/Institute_of_Data/IOD_2020_JIN/data/')

df = pd.read_csv('Employee-attrition.csv')

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.groupby('age').size().head()
# Out:
# age
# 19    158
# 20    408
# 21    703
# 22    815
# 23    960
# dtype: int64

# %%
df.groupby('age')['EmployeeID'].size().head()
# Out:
# age
# 19    158
# 20    408
# 21    703
# 22    815
# 23    960
# Name: EmployeeID, dtype: int64

# %%
def division(a,b):
    if b == 0: 
        print("error")
    else:
        c = a/b
        print(c)
    return c
division(20,0)
# Out:
# error
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-40-9217c32d12a6> in <module>
#       6         print(c)
#       7     return c
# ----> 8 division(20,0)
#
# <ipython-input-40-9217c32d12a6> in division(a, b)
#       5         c = a/b
#       6         print(c)
# ----> 7     return c
#       8 division(20,0)
#
# UnboundLocalError: local variable 'c' referenced before assignment
