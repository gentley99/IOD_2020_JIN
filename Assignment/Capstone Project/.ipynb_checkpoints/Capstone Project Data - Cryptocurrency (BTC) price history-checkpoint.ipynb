# %%
Linguistic Inquiry and Word Count (LIWC)

# %%
https://alternative.me/crypto/fear-and-greed-index/

# %% [markdown]
# Apply at https://developer.twitter.com/en/apply-for-access.html
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
https://pypi.org/project/Historic-Crypto/

# %%
# !pip install Historic-Crypto
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /Users/jinyang/miniforge3/envs/test_opencv/include/python3.8/UNKNOWN
# sysconfig: /Users/jinyang/miniforge3/envs/test_opencv/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /Users/jinyang/miniforge3/envs/test_opencv/include/python3.8/UNKNOWN
# sysconfig: /Users/jinyang/miniforge3/envs/test_opencv/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...
# WARNING: You are using pip version 21.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/Users/jinyang/miniforge3/envs/test_opencv/bin/python -m pip install --upgrade pip' command.

# %%
from Historic_Crypto import HistoricalData
from Historic_Crypto import Cryptocurrencies
from Historic_Crypto import LiveCryptoData

# %%
Cryptocurrencies().find_crypto_pairs()
# Out:
# Connected to the CoinBase Pro API.

# %%
from Historic_Crypto import Cryptocurrencies

data = Cryptocurrencies(coin_search = 'XLM', extended_output=False).find_crypto_pairs()
# Out:
# Connected to the CoinBase Pro API.
# Found 3 instances containing the term XLM.

# %%
data
# Out:
#             id display_name  status
# 0     USDT-GBP     USDT/GBP  online
# 1      SNX-GBP      SNX/GBP  online
# 2    MATIC-BTC    MATIC/BTC  online
# 3      ZEC-BTC      ZEC/BTC  online
# 4      BCH-GBP      BCH/GBP  online
# ..         ...          ...     ...
# 198   USDT-USD     USDT/USD  online
# 199  SUSHI-BTC    SUSHI/BTC  online
# 200    NKN-USD      NKN/USD  online
# 201    ICP-GBP      ICP/GBP  online
# 202   CGLD-EUR     CGLD/EUR  online
#
# [203 rows x 3 columns]

# %%
from Historic_Crypto import HistoricalData

new = HistoricalData('BTC-USD',60,'2021-05-23-00-00').retrieve_data()
# Out:
# Checking input parameters are in the correct format...
# Formatting Dates...
# Checking if ticker supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API...
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction...
# Data for chunk 0 of 4 extracted
# Data for chunk 1 of 4 extracted
# Data for chunk 2 of 4 extracted
# Data for chunk 3 of 4 extracted
# Data for chunk 4 of 4 extracted

# %%
new
# Out:
#                           low      high      open     close      volume
# time
# 2021-05-23 00:01:00  36789.00  37383.34  37383.34  37049.95  193.264077
# 2021-05-23 00:02:00  36959.16  37169.27  37036.10  36959.53   75.842189
# 2021-05-23 00:03:00  36882.47  37066.15  36969.03  36971.38   41.787935
# 2021-05-23 00:04:00  36858.15  37017.04  36971.37  36869.51   39.973594
# 2021-05-23 00:05:00  36723.30  36934.50  36869.51  36785.72   80.494039
# ...                       ...       ...       ...       ...         ...
# 2021-05-24 00:56:00  35222.82  35334.26  35223.49  35246.26   19.875332
# 2021-05-24 00:57:00  35165.03  35258.52  35246.31  35196.33   28.918724
# 2021-05-24 00:58:00  35157.07  35239.50  35196.08  35219.01   18.068020
# 2021-05-24 00:59:00  35215.57  35300.00  35223.71  35287.92   42.732159
# 2021-05-24 01:00:00  35275.23  35369.82  35287.92  35340.88   30.102151
#
# [1500 rows x 5 columns]

# %%
plt.plot(new.close)

# %%
# getting hourly bitcoin price.
new1 = HistoricalData('BTC-USD',3600,'2021-05-23-00-00').retrieve_data()
# Out:
# Checking input parameters are in the correct format...
# Formatting Dates...
# Checking if ticker supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API...
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction...
# Data Extracted from API...

# %%
new1
# Out:
#                           low      high      open     close       volume
# time
# 2021-05-23 00:00:00  36723.30  38319.36  37476.84  38223.18  1720.730537
# 2021-05-23 01:00:00  37911.49  38247.90  38223.18  37940.59   640.033844
# 2021-05-23 02:00:00  37404.75  38051.34  37940.60  37499.11   685.052870
# 2021-05-23 03:00:00  37279.26  37700.14  37499.04  37471.29   490.462838
# 2021-05-23 04:00:00  37075.22  37471.28  37471.28  37235.63   633.742258
# 2021-05-23 05:00:00  36675.00  37239.78  37239.78  36927.62   881.219591
# 2021-05-23 06:00:00  36380.00  37346.47  36927.61  36678.76  1026.606613
# 2021-05-23 07:00:00  35579.92  36825.35  36678.76  35947.62  1417.541826
# 2021-05-23 08:00:00  33875.00  35953.53  35953.53  34443.34  3945.479357
# 2021-05-23 09:00:00  34011.45  35254.19  34422.80  34251.75  2663.783703
# 2021-05-23 10:00:00  34164.68  35889.48  34243.94  35031.65  1545.078127
# 2021-05-23 11:00:00  34687.22  35811.06  35045.61  35433.91  1102.610905
# ...

# %%
plt.plot(new1.close)
