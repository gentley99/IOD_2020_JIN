# %% [markdown]
# Liquidy ratio
# current ratio = current assets/ current liabilities
# quick ratio = (cash+S/T investment + acct rec)/current liabilities
#
# receivables turnover ratio = net sales revenue/avg accounts receivable
# inventory turnover ratio = cost of goods sold/average inventory
#
# Solvency ratio
# Debt to asset ratio = total liabilities/total assets
# debt to equity ratio = total liabilities/total equity
# times interest earned ratio = (NPAT + int exp + tax exp)/int exp

# %% [markdown]
# current assets
# cash
# ST investment
# acct receivable
#
# current liabilities
#
# total assets
# total liabilities
# total equity
#
# NPAT
# interest expenses
# tax expenses
#
# EPS
# PE
# market cap (to select the firms)

# %% [markdown]
# Can we predict when ASX listed companies are about to be delisted from the market?

# %%
# Importing libraries & packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_datareader.data as web
from datetime import date
# Winsorising 
from scipy.stats.mstats import winsorize

# for Transformation
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from scipy.stats import skew
from scipy import stats

# sklearn regressions and modelling
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.linear_model import Lasso, LassoCV

from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report

# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Importing Data
df1 = pd.read_excel('Data/finresults listed.xlsx')
df2 = pd.read_excel('Data/finresults listed(1).xlsx')
df3 = pd.read_excel('Data/finresults delisted.xlsx')
df4 = pd.read_excel('Data/finresults delisted(1).xlsx')

# %%
# GICS sector
df5 = pd.read_excel('Data/advanced_listed.xlsx')
df6 = pd.read_excel('Data/advanced_delisted.xlsx')

# %%
# Making a copy
df1a = df1.copy()
df2a = df2.copy()
df3a = df3.copy()
df4a = df4.copy()
df5a = df5.copy()
df6a = df6.copy()

# %%
# writing a function to transform the dataset
def transforming(data, var):
    # Identifying str position
    data['new'] = data[var].str.find('-',start=1)+2
    data['new'] = data['new'].astype('int')
    
    # Creating a new column with boolean which contains str
    data["CF"] = data[var].str.contains("Annual Cash Flow")
    cf = data["CF"].sum()
    data["BS"] = data[var].str.contains("Annual Balance Sheet")
    bs = data["BS"].sum()
    data["PL"] = data[var].str.contains("Annual Profit and Loss")
    pl = data["PL"].sum()
    data["market"] = data[var].str.contains("Annual Ratio Analysis")
    market = data["market"].sum()
    
#     print(cf)
#     print(bs)
#     print(pl)
#     print(market)
    
    # Renaming the values
    if cf>0: 
        word_count_cf = int(data.loc[data["CF"]==1, 'new'].mean())
        data.loc[data['CF']==True, var] = data.Item.str.slice(word_count_cf)
#         print(word_count_cf)
    if bs>0: 
        word_count_bs = int(data.loc[data["BS"]==1, 'new'].mean())
        data.loc[data['BS']==True, var] = data.Item.str.slice(word_count_bs)
#         print(word_count_bs)
    if pl>0:
        word_count_pl = int(data.loc[data["PL"]==1, 'new'].mean())
        data.loc[data['PL']==True, var] = data.Item.str.slice(word_count_pl)
#         print(word_count_pl)
    if market>0:
        word_count_market = int(data.loc[data["market"]==1, 'new'].mean())
        data.loc[data['market']==True, var] = data.Item.str.slice(word_count_market)
#         print(word_count_market)

# %%
# transforming the data including BS, PL, CF, market information
transforming(df1a, 'Item')
transforming(df2a, 'Item')
transforming(df3a, 'Item')
transforming(df4a, 'Item')

# %%
# saving each file under different year
# df1a
for i in range(2010,2021):
    locals()['df1a_{0}'.format(i)] = df1a.pivot(index='ASX Code', columns='Item', values=str(i))
    locals()['df1a_{0}'.format(i)]['year'] = i
# df2a
for i in range(2010,2021):
    locals()['df2a_{0}'.format(i)] = df2a.pivot(index='ASX Code', columns='Item', values=str(i))
    locals()['df2a_{0}'.format(i)]['year'] = i
# df3a
for i in range(2010,2021):
    locals()['df3a_{0}'.format(i)] = df3a.pivot(index='ASX Code', columns='Item', values=str(i))
    locals()['df3a_{0}'.format(i)]['year'] = i    
# df4a
for i in range(2010,2021):
    locals()['df4a_{0}'.format(i)] = df4a.pivot(index='ASX Code', columns='Item', values=str(i))
    locals()['df4a_{0}'.format(i)]['year'] = i

# %%
# df1a listed 
balance_sheet_listed = df1a_2010.append([df1a_2011,
                                  df1a_2012,
                                  df1a_2013,
                                  df1a_2014,
                                  df1a_2015,
                                  df1a_2016,
                                  df1a_2017,
                                  df1a_2018,
                                  df1a_2019,
                                  df1a_2020])
# df2a listed
income_statement_listed = df2a_2010.append([df2a_2011,
                                  df2a_2012,
                                  df2a_2013,
                                  df2a_2014,
                                  df2a_2015,
                                  df2a_2016,
                                  df2a_2017,
                                  df2a_2018,
                                  df2a_2019,
                                  df2a_2020])
# df3a delisted 
balance_sheet_delisted = df3a_2010.append([df3a_2011,
                                  df3a_2012,
                                  df3a_2013,
                                  df3a_2014,
                                  df3a_2015,
                                  df3a_2016,
                                  df3a_2017,
                                  df3a_2018,
                                  df3a_2019,
                                  df3a_2020])
# df4a delisted
income_statement_delisted = df4a_2010.append([df4a_2011,
                                  df4a_2012,
                                  df4a_2013,
                                  df4a_2014,
                                  df4a_2015,
                                  df4a_2016,
                                  df4a_2017,
                                  df4a_2018,
                                  df4a_2019,
                                  df4a_2020])

# %%
balance_sheet_listed.head()
# Out:
# Item     CA Cash CA Investments CA Receivables Total Assets  \
# ASX Code
# 14D
# 1AD
# 1AG       271919          19800        1554750      8940993
# 1ST
# 2BE
#
# Item     Total Curr. Liabilities Total Current Assets Total Equity  \
# ASX Code
# 14D
# 1AD
# 1AG                      3922626              2336530      4958832
# 1ST
# 2BE
#
# Item     Total Liabilities  year
# ASX Code
# 14D                         2010
# 1AD                         2010
# 1AG                3982161  2010
# 1ST                         2010
# 2BE                         2010

# %%
income_statement_listed.head()
# Out:
# Item     EPS After Abnormals (cents/ Interest Expense Market Cap.($)  \
# ASX Code
# 14D
# 1AD
# 1AG                                0           -20620     3453653.96
# 1ST
# 2BE
#
# Item     Reported NPAT After Abnorma Tax Expense Weighted Average Number of  \
# ASX Code
# 14D
# 1AD
# 1AG                           317330       51775                   39741707
# 1ST
# 2BE
#
# Item      year
# ASX Code
# 14D       2010
# 1AD       2010
# 1AG       2010
# 1ST       2010
# 2BE       2010

# %%
balance_sheet_delisted.head()
# Out:
# Item     CA Cash CA Investments CA Receivables Total Assets  \
# ASX Code
# 1AL
# 1PG        47599              0              0      3179514
# 4WD
# A1C
# A40
#
# Item     Total Curr. Liabilities Total Current Assets Total Equity  \
# ASX Code
# 1AL
# 1PG                      1035323                47599      2144191
# 4WD
# A1C
# A40
#
# Item     Total Liabilities  year
# ASX Code
# 1AL                         2010
# 1PG                1035323  2010
# 4WD                         2010
# A1C                         2010
# A40                         2010

# %%
income_statement_delisted.head()
# Out:
# Item     EPS After Abnormals (cents/ Interest Expense Market Cap.($)  \
# ASX Code
# 1AL
# 1PG                                0           -37018      2272522.5
# 4WD
# A1C
# A40
#
# Item     Reported NPAT After Abnorma Tax Expense Weighted Average Number of  \
# ASX Code
# 1AL
# 1PG                          -317107           0                   50500500
# 4WD
# A1C
# A40
#
# Item      year
# ASX Code
# 1AL       2010
# 1PG       2010
# 4WD       2010
# A1C       2010
# A40       2010

# %% [markdown]
# # Merging data

# %%
# combined data for GICs code
df7a = df5a.append(df6a)

# %%
# listed firms
financial_listed = balance_sheet_listed.merge(income_statement_listed, how='left', on=['ASX Code','year'])
financial_listed = financial_listed.merge(df7a, how='left', on=['ASX Code'])

# %%
# delisted firms
financial_delisted = balance_sheet_delisted.merge(income_statement_delisted, how='left', on=['ASX Code','year'])
financial_delisted = financial_delisted.merge(df7a, how='left', on=['ASX Code'])

# %%
financial_delisted['delisted'] = 1

# %%
# Combining both datasets
both_financial = financial_listed.append(financial_delisted)

# %%
# converting to numeric
convert_numeric = ['CA Cash', 'CA Investments', 'CA Receivables', 'Total Assets', 
                  'Total Curr. Liabilities', 'Total Current Assets', 'Total Equity', 
                  'Total Liabilities', 'EPS After Abnormals (cents/', 'Interest Expense',
                  'Market Cap.($)', 'Reported NPAT After Abnorma', 'Tax Expense', 
                  'Weighted Average Number of']
for i in both_financial[convert_numeric]:
    both_financial[i] = pd.to_numeric(both_financial[i], 
                                        errors='coerce',
                                       downcast='float')
both_financial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35090 entries, 0 to 11395
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ASX Code                     35090 non-null  object
#  1   CA Cash                      23426 non-null  float32
#  2   CA Investments               23426 non-null  float32
#  3   CA Receivables               23426 non-null  float32
#  4   Total Assets                 23539 non-null  float32
#  5   Total Curr. Liabilities      23286 non-null  float32
#  6   Total Current Assets         23436 non-null  float32
#  7   Total Equity                 23406 non-null  float32
#  8   Total Liabilities            23455 non-null  float32
#  9   year                         35090 non-null  int64
#  10  EPS After Abnormals (cents/  23578 non-null  float32
#  11  Interest Expense             19154 non-null  float32
#  12  Market Cap.($)               23585 non-null  float32
#  13  Reported NPAT After Abnorma  23595 non-null  float32
#  14  Tax Expense                  23595 non-null  float32
#  15  Weighted Average Number of   23579 non-null  float32
#  16  Company Name                 33946 non-null  object
#  17  Status                       33946 non-null  object
#  18  GICS Sector                  33946 non-null  object
#  19  GICS Industry Group          33946 non-null  object
#  20  GICS Industry                33946 non-null  object
#  21  delisted                     11396 non-null  float64
# dtypes: float32(14), float64(1), int64(1), object(6)
# memory usage: 4.3+ MB

# %%
# sorting the data by code and year
both_financial = both_financial.sort_values(by=['ASX Code','year'])

# %%
both_financial.isna().sum()
# Out:
# ASX Code                           0
# CA Cash                        11664
# CA Investments                 11664
# CA Receivables                 11664
# Total Assets                   11551
# Total Curr. Liabilities        11804
# Total Current Assets           11654
# Total Equity                   11684
# Total Liabilities              11635
# year                               0
# EPS After Abnormals (cents/    11512
# Interest Expense               15936
# Market Cap.($)                 11505
# Reported NPAT After Abnorma    11495
# Tax Expense                    11495
# Weighted Average Number of     11511
# Company Name                    1144
# Status                          1144
# GICS Sector                     1144
# GICS Industry Group             1144
# GICS Industry                   1144
# delisted                       23694
# dtype: int64

# %%
# dealing with missing values
# I will drop observations that is missing
missing_val_1 = both_financial['Total Assets'].isna()

both_financiala = both_financial.loc[missing_val_1==False]

both_financiala.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23539 entries, 15078 to 23693
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ASX Code                     23539 non-null  object
#  1   CA Cash                      23386 non-null  float32
#  2   CA Investments               23386 non-null  float32
#  3   CA Receivables               23386 non-null  float32
#  4   Total Assets                 23539 non-null  float32
#  5   Total Curr. Liabilities      23270 non-null  float32
#  6   Total Current Assets         23391 non-null  float32
#  7   Total Equity                 23372 non-null  float32
#  8   Total Liabilities            23435 non-null  float32
#  9   year                         23539 non-null  int64
#  10  EPS After Abnormals (cents/  23524 non-null  float32
#  11  Interest Expense             19117 non-null  float32
#  12  Market Cap.($)               23539 non-null  float32
#  13  Reported NPAT After Abnorma  23539 non-null  float32
#  14  Tax Expense                  23539 non-null  float32
#  15  Weighted Average Number of   23525 non-null  float32
#  16  Company Name                 23002 non-null  object
#  17  Status                       23002 non-null  object
#  18  GICS Sector                  23002 non-null  object
#  19  GICS Industry Group          23002 non-null  object
#  20  GICS Industry                23002 non-null  object
#  21  delisted                     5360 non-null   float64
# dtypes: float32(14), float64(1), int64(1), object(6)
# memory usage: 2.9+ MB

# %%
# to keep the considerable size 
both_financiala.loc[both_financiala["Market Cap.($)"]>300000000].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3698 entries, 22 to 11347
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ASX Code                     3698 non-null   object
#  1   CA Cash                      3618 non-null   float32
#  2   CA Investments               3618 non-null   float32
#  3   CA Receivables               3618 non-null   float32
#  4   Total Assets                 3698 non-null   float32
#  5   Total Curr. Liabilities      3610 non-null   float32
#  6   Total Current Assets         3618 non-null   float32
#  7   Total Equity                 3687 non-null   float32
#  8   Total Liabilities            3693 non-null   float32
#  9   year                         3698 non-null   int64
#  10  EPS After Abnormals (cents/  3698 non-null   float32
#  11  Interest Expense             2738 non-null   float32
#  12  Market Cap.($)               3698 non-null   float32
#  13  Reported NPAT After Abnorma  3698 non-null   float32
#  14  Tax Expense                  3698 non-null   float32
#  15  Weighted Average Number of   3698 non-null   float32
#  16  Company Name                 3643 non-null   object
#  17  Status                       3643 non-null   object
#  18  GICS Sector                  3643 non-null   object
#  19  GICS Industry Group          3643 non-null   object
#  20  GICS Industry                3643 non-null   object
#  21  delisted                     603 non-null    float64
# dtypes: float32(14), float64(1), int64(1), object(6)
# memory usage: 462.2+ KB

# %%
both_financiala.loc[both_financiala['delisted']==1].describe().T
# Out:
#                               count          mean           std           min  \
# CA Cash                      5340.0  3.694860e+07  2.932096e+08 -2.450000e+06
# CA Investments               5340.0  1.043707e+07  3.477663e+08  0.000000e+00
# CA Receivables               5340.0  3.545043e+07  2.316001e+08 -1.543589e+06
# Total Assets                 5360.0  5.464246e+08  3.283380e+09  4.700000e+01
# Total Curr. Liabilities      5311.0  9.514005e+07  5.015758e+08  0.000000e+00
# Total Current Assets         5342.0  1.124393e+08  7.640790e+08  0.000000e+00
# Total Equity                 5321.0  2.814804e+08  1.910620e+09 -9.753560e+08
# Total Liabilities            5338.0  2.680315e+08  1.668165e+09 -1.986189e+06
# year                         5360.0  2.013590e+03  2.745090e+00  2.010000e+03
# EPS After Abnormals (cents/  5353.0  6.519709e-02  1.180348e+00 -1.700000e+01
# Interest Expense             4425.0 -8.429707e+06  5.008108e+07 -1.162736e+09
# Market Cap.($)               5360.0  4.122910e+08  2.949228e+09  0.000000e+00
# Reported NPAT After Abnorma  5360.0  1.174636e+07  2.836037e+08 -4.024064e+09
# Tax Expense                  5360.0 -4.294274e+06  5.009260e+07 -1.822102e+09
# Weighted Average Number of   5353.0  4.529558e+08  1.011507e+09  0.000000e+00
# delisted                     5360.0  1.000000e+00  0.000000e+00  1.000000e+00
#
#                                       25%          50%           75%  \
# CA Cash                      6.491158e+05    3411500.0  1.595898e+07
# CA Investments               0.000000e+00          0.0  0.000000e+00
# CA Receivables               8.835050e+04     904370.5  8.967856e+06
# Total Assets                 6.876546e+06   34328818.0  1.593258e+08
# Total Curr. Liabilities      7.812515e+05    4538928.0  2.946600e+07
# Total Current Assets         1.913624e+06    9307974.0  4.681050e+07
# Total Equity                 3.271000e+06   21235716.0  9.368800e+07
# Total Liabilities            1.015839e+06    7067847.5  5.640925e+07
# year                         2.011000e+03       2013.0  2.016000e+03
# EPS After Abnormals (cents/  0.000000e+00          0.0  0.000000e+00
# Interest Expense            -1.629000e+06    -108651.0  0.000000e+00
# Market Cap.($)               5.552020e+06   23787140.0  1.169953e+08
# Reported NPAT After Abnorma -5.086373e+06    -796960.5  2.907003e+06
# Tax Expense                 -4.540000e+05          0.0  0.000000e+00
# Weighted Average Number of   7.185730e+07  179500000.0  4.407614e+08
# delisted                     1.000000e+00          1.0  1.000000e+00
#
#                                       max
# CA Cash                      1.180743e+10
# CA Investments               2.357100e+10
# CA Receivables               7.545465e+09
# Total Assets                 6.380852e+10
# Total Curr. Liabilities      1.039775e+10
# Total Current Assets         2.640700e+10
# Total Equity                 5.468832e+10
# Total Liabilities            3.384137e+10
# year                         2.020000e+03
# EPS After Abnormals (cents/  3.600000e+01
# Interest Expense             3.427000e+06
# Market Cap.($)               7.499428e+10
# Reported NPAT After Abnorma  9.260050e+09
# Tax Expense                  1.496441e+09
# Weighted Average Number of   1.593665e+10
# delisted                     1.000000e+00

# %%
both_financial.describe().T
# Out:
#                                count          mean           std  \
# CA Cash                      23426.0  6.840470e+07  5.812073e+08
# CA Investments               23426.0  5.935023e+07  1.294892e+09
# CA Receivables               23426.0  7.847618e+07  9.638292e+08
# Total Assets                 23539.0  2.822462e+09  3.727630e+10
# Total Curr. Liabilities      23286.0  2.371890e+08  2.904201e+09
# Total Current Assets         23436.0  2.683637e+08  2.826884e+09
# Total Equity                 23406.0  7.461983e+08  9.049576e+09
# Total Liabilities            23455.0  2.087809e+09  3.381924e+10
# year                         35090.0  2.015000e+03  3.162323e+00
# EPS After Abnormals (cents/  23578.0  2.113411e-01  8.450241e+00
# Interest Expense             19154.0 -5.501392e+07  8.556721e+08
# Market Cap.($)               23585.0  1.580276e+09  1.497297e+10
# Reported NPAT After Abnorma  23595.0  6.663518e+07  1.627923e+09
# Tax Expense                  23595.0 -1.940755e+07  2.341838e+08
# Weighted Average Number of   23579.0  4.603158e+08  1.107946e+09
# delisted                     11396.0  1.000000e+00  0.000000e+00
#
#                                       min          25%          50%  \
# CA Cash                     -1.148500e+07    863098.25    3541890.5
# CA Investments               0.000000e+00         0.00          0.0
# CA Receivables              -1.231420e+08     75350.25     706928.5
# Total Assets                 0.000000e+00   6679891.50   27552776.0
# Total Curr. Liabilities     -2.798000e+08    510488.75    2849582.5
# Total Current Assets         0.000000e+00   1882505.00    7445519.5
# Total Equity                -9.805860e+08   4435850.00   18424352.0
# Total Liabilities           -2.941000e+08    665895.00    4549018.0
# year                         2.010000e+03      2012.00       2015.0
# EPS After Abnormals (cents/ -1.490000e+02         0.00          0.0
# Interest Expense            -2.610200e+10  -1215536.50     -39781.5
# Market Cap.($)               0.000000e+00   6266171.50   25965176.0
# Reported NPAT After Abnorma -1.224246e+10  -4062650.50    -794639.0
# Tax Expense                 -9.061918e+09   -522000.00          0.0
# Weighted Average Number of   0.000000e+00  76848512.00  184484576.0
# delisted                     1.000000e+00         1.00          1.0
#
#                                      75%           max
# CA Cash                       16183038.0  2.870500e+10
# CA Investments                       0.0  7.283800e+10
# CA Receivables                 8398500.0  6.141500e+10
# Total Assets                 176718496.0  1.042286e+12
# Total Curr. Liabilities       24993404.0  1.447210e+11
# Total Current Assets          47150000.0  1.279160e+11
# Total Equity                 105999248.0  8.976239e+11
# Total Liabilities             52575264.0  9.809890e+11
# year                              2018.0  2.020000e+03
# EPS After Abnormals (cents/          0.0  1.127000e+03
# Interest Expense                     0.0  6.115401e+06
# Market Cap.($)               148170112.0  5.014057e+11
# Reported NPAT After Abnorma    3832346.5  2.101043e+11
# Tax Expense                          0.0  1.902103e+09
# Weighted Average Number of   460805312.0  6.791161e+10
# delisted                             1.0  1.000000e+00

# %%
both_financial["Market Cap.($)"].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
both_financial.to_excel('check.xls')
# Out:
# <ipython-input-181-1fe2246161a9>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   both_financiala.to_excel('check.xls')
