# %% [markdown]
# https://www.youtube.com/watch?v=HXDD7-EnGBY

# %% [markdown]
# Object Detection OpenCV Python | Easy and Fast (2020)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('frame0.jpg')

# %%
cv2.imshow("Output",img)
# cv2.waitKey(0)
# Out:
# -1

# %%
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture("soccer2.mp4")
while True: 
    success, img = cap.read()
    cv2.imshow("Video",img)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-d44cf3857e9d> in <module>
#       2 while True:
#       3     success, img = cap.read()
# ----> 4     cv2.imshow("Video",img)
#       5     if cv2.waitKey(1) & 0xFF ==ord('q'):
#       6         break
#
# error: OpenCV(4.5.0) /Users/jinyang/opencv-4.5.0/modules/highgui/src/window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
