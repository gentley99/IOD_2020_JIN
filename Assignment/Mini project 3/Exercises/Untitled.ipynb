# %% [markdown]
# https://www.analyticsvidhya.com/blog/2016/10/tutorial-optimizing-neural-networks-using-keras-with-image-recognition-case-study/
# Tutorial: Optimizing Neural Networks using Keras (with Image recognition case study)

# %%
# %pylab inline
import os
import numpy as np
import pandas as pd
from scipy.misc import imread
from sklearn.metrics import accuracy_score

import tensorflow as tf
import keras
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ec89af03dd9e> in <module>
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from scipy.misc import imread
#       6 from sklearn.metrics import accuracy_score
#       7
#
# ImportError: cannot import name 'imread' from 'scipy.misc' (/Users/jinyang/opt/anaconda3/lib/python3.8/site-packages/scipy/misc/__init__.py)
