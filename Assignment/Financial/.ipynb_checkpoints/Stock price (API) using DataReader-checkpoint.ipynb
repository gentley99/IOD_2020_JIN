# %%
# based on the below youtube
# https://www.youtube.com/watch?v=57qAxRV577c
# Stock Market Analysis with Pandas Python Programming

# %%
import pandas_datareader.data as web
# from datetime import date
import datetime
import matplotlib.pyplot as plt
import numpy
import pandas as pd
from pandas.plotting import scatter_matrix
from mpl_finance import candlestick_ohlc
from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, DayLocator, MONDAY
# %matplotlib inline

# %%
start = datetime.datetime(2020,1,1)
end = date.today()

# %%
google = web.DataReader("GOOGL", 'yahoo', start, end)

# %%
google
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-12-31  1340.660034  1332.130005  1335.790039  1339.390015   975700
# 2020-01-02  1368.680054  1346.489990  1348.410034  1368.680054  1363900
# 2020-01-03  1373.750000  1347.319946  1348.000000  1361.520020  1170400
# 2020-01-06  1398.319946  1351.000000  1351.630005  1397.810059  2338400
# 2020-01-07  1403.500000  1391.560059  1400.459961  1395.109985  1716500
# ...                 ...          ...          ...          ...      ...
# 2021-01-11  1784.380005  1752.140015  1777.020020  1756.290039  1740600
# 2021-01-12  1767.900024  1716.380005  1745.359985  1737.430054  1476400
# 2021-01-13  1756.390015  1727.319946  1727.319946  1747.250000  1171600
# 2021-01-14  1767.550049  1726.069946  1748.869995  1730.920044  1460600
# 2021-01-15  1747.619995  1711.709961  1729.020020  1727.619995  1570200
#
#               Adj Close
# Date
# 2019-12-31  1339.390015
# 2020-01-02  1368.680054
# 2020-01-03  1361.520020
# 2020-01-06  1397.810059
# 2020-01-07  1395.109985
# ...                 ...
# 2021-01-11  1756.290039
# 2021-01-12  1737.430054
# 2021-01-13  1747.250000
# 2021-01-14  1730.920044
# 2021-01-15  1727.619995
#
# [264 rows x 6 columns]

# %%
google['Open']
# Out:
# Date
# 2019-12-31    1335.790039
# 2020-01-02    1348.410034
# 2020-01-03    1348.000000
# 2020-01-06    1351.630005
# 2020-01-07    1400.459961
#                  ...
# 2021-01-11    1777.020020
# 2021-01-12    1745.359985
# 2021-01-13    1727.319946
# 2021-01-14    1748.869995
# 2021-01-15    1729.020020
# Name: Open, Length: 264, dtype: float64

# %%
google['Open'].plot(label = 'GOOGL Open price', figsize=(15,7))
google['Close'].plot(label = 'GOOGL Close price')
google['High'].plot(label = 'GOOGL High price')
google['Low'].plot(label = 'GOOGL Low price')
plt.legend()
plt.title('Google Stock Prices')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
google['Volume'].plot(figsize=(17,5))
plt.title('Volume ')
# Out:
# Text(0.5, 1.0, 'Volume ')

# %%
# GM, FORD, TESLA

# %%
start = datetime.datetime(2012,1,1)
end = date.today()

# %%
tesla = web.DataReader("TSLA",'yahoo', start, end)
ford = web.DataReader("F", 'yahoo', start, end)
gm = web.DataReader("GM", 'yahoo', start, end)

# %%
cba = web.DataReader("CBA.AX",'yahoo', start, end)
anz = web.DataReader("ANZ.AX", 'yahoo', start, end)
wbc = web.DataReader("WBC.AX", 'yahoo', start, end)
nab = web.DataReader("NAB.AX", 'yahoo', start, end)

# %%
tesla.to_csv('Tesla_stock.csv')
ford.to_csv('Ford_stock.csv')
gm.to_csv('GM_stock.csv')

# %%
tesla.head()
# Out:
#              High    Low   Open  Close     Volume  Adj Close
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500.0      5.616
# 2012-01-04  5.734  5.500  5.642  5.542  3150500.0      5.542
# 2012-01-05  5.586  5.370  5.552  5.424  5027500.0      5.424
# 2012-01-06  5.558  5.282  5.440  5.382  4931500.0      5.382
# 2012-01-09  5.498  5.224  5.400  5.450  4485000.0      5.450

# %%
tesla['Open'].plot(label='Tesla', figsize=(15,7))
gm['Open'].plot(label='GM')
ford['Open'].plot(label='Ford')
plt.ylabel("Stock Price")
plt.title("Stock Prices of Tesla, GM, Ford")
plt.legend()

# %%
tesla['Volume'].plot(label='Tesla', figsize=(15,7))
gm['Volume'].plot(label='GM')
ford['Volume'].plot(label='Ford')
plt.ylabel('Volume traded')
plt.legend()

# %%
ford.iloc[[ford['Volume'].argmax()]]
# Out:
#             High   Low  Open  Close       Volume  Adj Close
# Date
# 2020-03-31  5.19  4.75  5.03   4.83  231800800.0       4.83

# %%
ford.iloc[470:520]['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tesla['Total Traded'] = tesla['Open'] * tesla['Volume']
gm['Total Traded'] = gm['Open'] * gm['Volume']
ford['Total Traded'] = ford['Open'] * ford['Volume']

# %%
tesla.head()
# Out:
#              High    Low   Open  Close     Volume  Adj Close  Total Traded
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500.0      5.616  2.685921e+07
# 2012-01-04  5.734  5.500  5.642  5.542  3150500.0      5.542  1.777512e+07
# 2012-01-05  5.586  5.370  5.552  5.424  5027500.0      5.424  2.791268e+07
# 2012-01-06  5.558  5.282  5.440  5.382  4931500.0      5.382  2.682736e+07
# 2012-01-09  5.498  5.224  5.400  5.450  4485000.0      5.450  2.421900e+07

# %%
tesla['Total Traded'].plot(label='Tesla', figsize=(15,7))
gm['Total Traded'].plot(label='GM')
ford['Total Traded'].plot(label='Ford')
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
tesla['Total Traded'].argmax()
# Out:
# 2256

# %%
tesla.iloc[[tesla['Total Traded'].argmax()]]
# Out:
#              High         Low        Open  Close       Volume  Adj Close  \
# Date
# 2020-12-18  695.0  628.539978  668.900024  695.0  222126200.0      695.0
#
#             Total Traded
# Date
# 2020-12-18  1.485802e+11

# %%
# moving averages

# %%
gm['Open'].iloc[440:500].plot(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
gm['Open'].plot(label='No Moving Average', figsize=(15,7))
gm['MA50'] = gm['Open'].rolling(50).mean()
gm['MA50'].plot(label='MA50')
gm['MA200'] = gm['Open'].rolling(200).mean()
gm['MA200'].plot(label='MA200')
plt.legend()

# %%
car_comp = pd.concat([tesla['Open'], gm['Open'], ford['Open']], axis=1)
car_comp.columns = ['Tesla Open', 'GM Open', 'Ford Open']
car_comp.head()
# Out:
#             Tesla Open    GM Open  Ford Open
# Date
# 2012-01-03       5.788  20.830000      11.00
# 2012-01-04       5.642  21.049999      11.15
# 2012-01-05       5.552  21.100000      11.33
# 2012-01-06       5.440  22.260000      11.74
# 2012-01-09       5.400  23.200001      11.83

# %%
scatter_matrix(car_comp, figsize=(8,8), hist_kwds={'bins':75})
# Out:
# array([[<AxesSubplot:xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Tesla Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='GM Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Ford Open'>]],
#       dtype=object)

# %%
# candle stick chart

# %%
ford_reset = ford.loc['2012-01':'2012-01'].reset_index()
ford_reset.head()
# Out:
#         Date   High    Low   Open  Close      Volume  Adj Close  Total Traded
# 0 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.544740  5.028089e+08
# 1 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.659981  8.889359e+08
# 2 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.856563  7.690521e+08
# 3 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.937905  7.025298e+08
# 4 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.998916  6.386011e+08

# %%
ford_reset['date_ax'] = ford_reset['Date'].apply(lambda date: date2num(date))
ford_reset.head()
# Out:
#         Date   High    Low   Open  Close      Volume  Adj Close  Total Traded  \
# 0 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.544740  5.028089e+08
# 1 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.659981  8.889359e+08
# 2 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.856563  7.690521e+08
# 3 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.937905  7.025298e+08
# 4 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.998916  6.386011e+08
#
#    date_ax
# 0  15342.0
# 1  15343.0
# 2  15344.0
# 3  15345.0
# 4  15348.0

# %%
ford_values = [tuple(vals) for vals in ford_reset[['date_ax','Open','High','Low','Close']].values]
mondays = WeekdayLocator(MONDAY)
alldays = DayLocator()
weekFormatter = DateFormatter('%b %d')
dayFormatter = DateFormatter('%d')

fig, ax = plt.subplots()
candlestick_ohlc(ax, ford_values,width=0.6, colorup='g', colordown='r')
# Out:
# ([<matplotlib.lines.Line2D at 0x7fc929b624c0>,
#   <matplotlib.lines.Line2D at 0x7fc929d33940>,
#   <matplotlib.lines.Line2D at 0x7fc929d339a0>,
#   <matplotlib.lines.Line2D at 0x7fc94beb83d0>,
#   <matplotlib.lines.Line2D at 0x7fc94beb8430>,
#   <matplotlib.lines.Line2D at 0x7fc94beb8fa0>,
#   <matplotlib.lines.Line2D at 0x7fc94bec5610>,
#   <matplotlib.lines.Line2D at 0x7fc94bec5c40>,
#   <matplotlib.lines.Line2D at 0x7fc94bed32b0>,
#   <matplotlib.lines.Line2D at 0x7fc94bed3910>,
#   <matplotlib.lines.Line2D at 0x7fc94bed3f40>,
#   <matplotlib.lines.Line2D at 0x7fc94bee15b0>,
#   <matplotlib.lines.Line2D at 0x7fc94bee1be0>,
#   <matplotlib.lines.Line2D at 0x7fc94beed250>,
#   <matplotlib.lines.Line2D at 0x7fc94beed880>,
#   <matplotlib.lines.Line2D at 0x7fc94beedeb0>,
#   <matplotlib.lines.Line2D at 0x7fc929d43520>,
#   <matplotlib.lines.Line2D at 0x7fc929d43b50>,
#   <matplotlib.lines.Line2D at 0x7fc929d4e1c0>,
#   <matplotlib.lines.Line2D at 0x7fc929d4e7f0>],
#  [<matplotlib.patches.Rectangle at 0x7fc929d11d00>,
#   <matplotlib.patches.Rectangle at 0x7fc929d33a90>,
#   <matplotlib.patches.Rectangle at 0x7fc929d33fd0>,
#   <matplotlib.patches.Rectangle at 0x7fc94beb84c0>,
#   <matplotlib.patches.Rectangle at 0x7fc94beb8ac0>,
#   <matplotlib.patches.Rectangle at 0x7fc94beb8fd0>,
#   <matplotlib.patches.Rectangle at 0x7fc94bec5760>,
#   <matplotlib.patches.Rectangle at 0x7fc94bec5d90>,
#   <matplotlib.patches.Rectangle at 0x7fc94bed3430>,
#   <matplotlib.patches.Rectangle at 0x7fc94bed3a60>,
#   <matplotlib.patches.Rectangle at 0x7fc94bed3fd0>,
#   <matplotlib.patches.Rectangle at 0x7fc94bee1700>,
#   <matplotlib.patches.Rectangle at 0x7fc94bee1d30>,
#   <matplotlib.patches.Rectangle at 0x7fc94beed3a0>,
#   <matplotlib.patches.Rectangle at 0x7fc94beed9d0>,
#   <matplotlib.patches.Rectangle at 0x7fc94beedf40>,
#   <matplotlib.patches.Rectangle at 0x7fc929d43670>,
#   <matplotlib.patches.Rectangle at 0x7fc929d43ca0>,
#   <matplotlib.patches.Rectangle at 0x7fc929d4e310>,
#   <matplotlib.patches.Rectangle at 0x7fc929d4e940>])

# %%
#Daily Percentage change
# r = p/p(t-1) - 1

# %%
tesla['returns'] = (tesla['Close']/tesla['Close'].shift(1)) - 1
tesla.head()
# Out:
#              High    Low   Open  Close     Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500.0      5.616  2.685921e+07
# 2012-01-04  5.734  5.500  5.642  5.542  3150500.0      5.542  1.777512e+07
# 2012-01-05  5.586  5.370  5.552  5.424  5027500.0      5.424  2.791268e+07
# 2012-01-06  5.558  5.282  5.440  5.382  4931500.0      5.382  2.682736e+07
# 2012-01-09  5.498  5.224  5.400  5.450  4485000.0      5.450  2.421900e+07
#
#              returns
# Date
# 2012-01-03       NaN
# 2012-01-04 -0.013177
# 2012-01-05 -0.021292
# 2012-01-06 -0.007743
# 2012-01-09  0.012635

# %%
ford['returns'] = (ford['Close']/ford['Close'].shift(1)) - 1
gm['returns'] = (gm['Close']/gm['Close'].shift(1)) - 1

# %%
ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.544740  5.028089e+08
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.659981  8.889359e+08
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.856563  7.690521e+08
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.937905  7.025298e+08
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.998916  6.386011e+08
#
#              returns
# Date
# 2012-01-03       NaN
# 2012-01-04  0.015274
# 2012-01-05  0.025664
# 2012-01-06  0.010354
# 2012-01-09  0.007686

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269407
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714725
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652889
#
#             Total Traded  MA50  MA200   returns
# Date
# 2012-01-03  1.941627e+08   NaN    NaN       NaN
# 2012-01-04  1.653835e+08   NaN    NaN  0.004751
# 2012-01-05  3.772807e+08   NaN    NaN  0.048227
# 2012-01-06  4.059000e+08   NaN    NaN  0.033829
# 2012-01-09  2.803604e+08   NaN    NaN -0.003490

# %%
tesla['returns'].hist(bins=100, label='Tesla', alpha=0.5, figsize=(13,6))
ford['returns'].hist(bins=100, label='GM', alpha=0.5)
gm['returns'].hist(bins=100, label='Ford', alpha=0.5)
plt.legend()

# %%
tesla['returns'].plot(kind='kde', label='Tesla', figsize=(15,6))
ford['returns'].plot(kind='kde', label='Ford')
gm['returns'].plot(kind='kde', label='GM')
plt.legend()

# %%
box_df = pd.concat([tesla['returns'], gm['returns'], ford['returns']], axis=1)
box_df.columns=['Tesla Returns','GM Returns', 'Ford Returns']
box_df.plot(kind='box', figsize=(16,6))
# Out:
# <AxesSubplot:>

# %%
scatter_matrix(box_df, figsize=(8,8), hist_kwds={'bins':50}, alpha=0.25)
# Out:
# array([[<AxesSubplot:xlabel='Tesla Returns', ylabel='Tesla Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='Tesla Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='Tesla Returns'>],
#        [<AxesSubplot:xlabel='Tesla Returns', ylabel='GM Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='GM Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='GM Returns'>],
#        [<AxesSubplot:xlabel='Tesla Returns', ylabel='Ford Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='Ford Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='Ford Returns'>]],
#       dtype=object)

# %%
# Cumulative return
# i= (1+r)i(t-1)

# %%
tesla['Cumulative Return'] = (1 + tesla['returns']).cumprod()
ford['Cumulative Return'] = (1 + ford['returns']).cumprod()
gm['Cumulative Return'] = (1 + gm['returns']).cumprod()

tesla.head()
# Out:
#              High    Low   Open  Close     Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500.0      5.616  2.685921e+07
# 2012-01-04  5.734  5.500  5.642  5.542  3150500.0      5.542  1.777512e+07
# 2012-01-05  5.586  5.370  5.552  5.424  5027500.0      5.424  2.791268e+07
# 2012-01-06  5.558  5.282  5.440  5.382  4931500.0      5.382  2.682736e+07
# 2012-01-09  5.498  5.224  5.400  5.450  4485000.0      5.450  2.421900e+07
#
#              returns  Cumulative Return
# Date
# 2012-01-03       NaN                NaN
# 2012-01-04 -0.013177           0.986823
# 2012-01-05 -0.021292           0.965812
# 2012-01-06 -0.007743           0.958333
# 2012-01-09  0.012635           0.970442

# %%
tesla['Cumulative Return'].plot(label='Tesla',figsize=(15,7))
ford['Cumulative Return'].plot(label='Ford')
gm['Cumulative Return'].plot(label='GM')
plt.title('Cumulative Return vs time')
plt.legend()

# %% [markdown]
# # another youtube clip

# %%
# based on the below youtube clip
# https://www.youtube.com/watch?v=QIUxPv5PJOY
# Stock Price Prediction Using Python & Machine Learning

# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivetherityeight')

# %%
start = '2012-01-01'
end = '2019-12-17'

# %%
# getting the stock quote
df = web.DataReader('AAPL', data_source='yahoo', start=start, end=end)
