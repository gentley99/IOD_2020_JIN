# %%
# Business questions
# To examine the relationship between annual financial information and share price.
# To investigate whether the relationship persists in the volatile stock market.

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
import xlrd

# Cause plots to be displayed in the notebook:
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Importing xls file
df1 = pd.read_excel('../Financial/finresults (1).xlsx')
df2 = pd.read_excel('../Financial/finresults (2).xlsx')
df3 = pd.read_excel('../Financial/finresults (3).xlsx')

# %%
df4 = pd.read_excel('../Financial/advanced.xlsx')

# %%
# Making a copy
df1a = df1.copy()
df2a = df2.copy()
df3a = df3.copy()
df4a = df4.copy()

# %% [markdown]
# # Balance sheet dataset

# %%
df1a.head()
# Out:
#   ASX Code          Company Name                                         Item  \
# 0      14D  1414 Degrees Limited   Annual Cash Flow - Net Operating Cash Flow
# 1      14D  1414 Degrees Limited               Annual Balance Sheet - CA Cash
# 2      14D  1414 Degrees Limited        Annual Balance Sheet - CA Inventories
# 3      14D  1414 Degrees Limited  Annual Balance Sheet - Total Current Assets
# 4      14D  1414 Degrees Limited          Annual Balance Sheet - Total Assets
#
#   2010 2011 2012 2013 2014 2015 2016      2017 2018      2019      2020
# 0                                           --       -4134023  -2607214
# 1                                     28795000        9721192   4395479
# 2                                            0              0         0
# 3                                     30163000       12385751   5975166
# 4                                     32183000       17630283  17213774

# %%
df1a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21690 entries, 0 to 21689
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ASX Code      21690 non-null  object
#  1   Company Name  21690 non-null  object
#  2   Item          21690 non-null  object
#  3   2010          21690 non-null  object
#  4   2011          21690 non-null  object
#  5   2012          21690 non-null  object
#  6   2013          21690 non-null  object
#  7   2014          21690 non-null  object
#  8   2015          21690 non-null  object
#  9   2016          21690 non-null  object
#  10  2017          21690 non-null  object
#  11  2018          21690 non-null  object
#  12  2019          21690 non-null  object
#  13  2020          21690 non-null  object
# dtypes: object(14)
# memory usage: 2.3+ MB

# %%
df1a['Item'].unique()
# Out:
# array(['Annual Cash Flow - Net Operating Cash Flow',
#        'Annual Balance Sheet - CA Cash',
#        'Annual Balance Sheet - CA Inventories',
#        'Annual Balance Sheet - Total Current Assets',
#        'Annual Balance Sheet - Total Assets',
#        'Annual Balance Sheet - Total Curr. Liabilities',
#        'Annual Balance Sheet - Total Liabilities',
#        'Annual Balance Sheet - CL Short-Term Debt',
#        'Annual Balance Sheet - NCL Long-Term Debt',
#        'Annual Balance Sheet - Total Equity'], dtype=object)

# %%
df1a['Item1'] = df1a['Item'].str.find('-', start=1)+2
df1a['Item1'] = df1a['Item1'].astype('int')
# df1a.info()

# %%
df1a["CF"] = df1a['Item'].str.contains("Annual Cash Flow")
df1a["CF"]
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21685    False
# 21686    False
# 21687    False
# 21688    False
# 21689    False
# Name: CF, Length: 21690, dtype: bool

# %%
# df1a.Item.apply(lambda x: x[19:])
# df1a['Item'].loc[df1a['Item']=="Annual Balance Sheet - CA Cash"].apply(lambda x: x[23:])
df1a.head()
# Out:
#   ASX Code          Company Name                                         Item  \
# 0      14D  1414 Degrees Limited   Annual Cash Flow - Net Operating Cash Flow
# 1      14D  1414 Degrees Limited               Annual Balance Sheet - CA Cash
# 2      14D  1414 Degrees Limited        Annual Balance Sheet - CA Inventories
# 3      14D  1414 Degrees Limited  Annual Balance Sheet - Total Current Assets
# 4      14D  1414 Degrees Limited          Annual Balance Sheet - Total Assets
#
#   2010 2011 2012 2013 2014 2015 2016      2017 2018      2019      2020  \
# 0                                           --       -4134023  -2607214
# 1                                     28795000        9721192   4395479
# 2                                            0              0         0
# 3                                     30163000       12385751   5975166
# 4                                     32183000       17630283  17213774
#
#       CF  Item1
# 0   True     19
# 1  False     23
# 2  False     23
# 3  False     23
# 4  False     23

# %%
# df1a['Item1'].groupby(df1a['Item']).mean()

# %%
word_count_cf = df1a.loc[df1a['Item']=='Annual Cash Flow - Net Operating Cash Flow', 'Item1'].mean()
word_count_bs = df1a.loc[df1a['Item']=='Annual Balance Sheet - CA Cash', 'Item1'].mean()

word_count_cf = int(word_count_cf)
word_count_bs = int(word_count_bs)

print(word_count_cf)
print(word_count_bs)
# Out:
# 19
# 23

# %%
# renaming
df1a.loc[df1a['CF']==True,'Item'] = df1a.Item.str.slice(word_count_cf)
df1a.loc[df1a['CF']==False,'Item'] = df1a.Item.str.slice(word_count_bs)
    
df1a.head()
# Out:
#   ASX Code          Company Name                     Item 2010 2011 2012 2013  \
# 0      14D  1414 Degrees Limited  Net Operating Cash Flow
# 1      14D  1414 Degrees Limited                  CA Cash
# 2      14D  1414 Degrees Limited           CA Inventories
# 3      14D  1414 Degrees Limited     Total Current Assets
# 4      14D  1414 Degrees Limited             Total Assets
#
#   2014 2015 2016      2017 2018      2019      2020     CF  Item1
# 0                       --       -4134023  -2607214   True     19
# 1                 28795000        9721192   4395479  False     23
# 2                        0              0         0  False     23
# 3                 30163000       12385751   5975166  False     23
# 4                 32183000       17630283  17213774  False     23

# %%
df1a.Item.value_counts()
# Out:
# Total Liabilities          2169
# CA Inventories             2169
# CL Short-Term Debt         2169
# Total Curr. Liabilities    2169
# CA Cash                    2169
# Total Equity               2169
# NCL Long-Term Debt         2169
# Total Assets               2169
# Total Current Assets       2169
# Net Operating Cash Flow    2169
# Name: Item, dtype: int64

# %%
df1a.columns
# Out:
# Index(['ASX Code', 'Company Name', 'Item', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'CF', 'Item1'],
#       dtype='object')

# %%
# saving each file under different year
for i in range(2010,2021):
    locals()['df1a_{0}'.format(i)] = df1a.pivot(index='ASX Code', columns='Item', values=str(i))
    locals()['df1a_{0}'.format(i)]['year'] = i
    print('df1a_'+str(i))
#     df1a_[i] = df1a.pivot(index='ASX Code', columns='Item', values='i')
# Out:
# df1a_2010
# df1a_2011
# df1a_2012
# df1a_2013
# df1a_2014
# df1a_2015
# df1a_2016
# df1a_2017
# df1a_2018
# df1a_2019
# df1a_2020

# %%
# df1a_2010 = df1a.pivot(index='ASX Code', columns='Item', values='2011')
# df1a_2010['year'] = 2010
# df1a_2010.head()

# %%
# appending all the files
balance_sheet = df1a_2010.append([df1a_2011,
                                  df1a_2012,
                                  df1a_2013,
                                  df1a_2014,
                                  df1a_2015,
                                  df1a_2016,
                                  df1a_2017,
                                  df1a_2018,
                                  df1a_2019,
                                  df1a_2020])

# %%
balance_sheet.year.value_counts().sort_index()
# Out:
# 2010    2169
# 2011    2169
# 2012    2169
# 2013    2169
# 2014    2169
# 2015    2169
# 2016    2169
# 2017    2169
# 2018    2169
# 2019    2169
# 2020    2169
# Name: year, dtype: int64

# %%
balance_sheet.head()
# Out:
# Item     CA Cash CA Inventories CL Short-Term Debt NCL Long-Term Debt  \
# ASX Code
# 14D
# 1AD
# 1AG       271919         282857            1046419              59535
# 1ST
# 2BE
#
# Item     Net Operating Cash Flow Total Assets Total Curr. Liabilities  \
# ASX Code
# 14D
# 1AD
# 1AG                      -417821      8940993                 3922626
# 1ST
# 2BE
#
# Item     Total Current Assets Total Equity Total Liabilities  year
# ASX Code
# 14D                                                           2010
# 1AD                                                           2010
# 1AG                   2336530      4958832           3982161  2010
# 1ST                                                           2010
# 2BE                                                           2010

# %% [markdown]
# # Profit & Loss Statement data

# %%
df2a.columns
# Out:
# Index(['ASX Code', 'Company Name', 'Item', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
df2a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13014 entries, 0 to 13013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ASX Code      13014 non-null  object
#  1   Company Name  13014 non-null  object
#  2   Item          13014 non-null  object
#  3   2010          13014 non-null  object
#  4   2011          13014 non-null  object
#  5   2012          13014 non-null  object
#  6   2013          13014 non-null  object
#  7   2014          13014 non-null  object
#  8   2015          13014 non-null  object
#  9   2016          13014 non-null  object
#  10  2017          13014 non-null  object
#  11  2018          13014 non-null  object
#  12  2019          13014 non-null  object
#  13  2020          13014 non-null  object
# dtypes: object(14)
# memory usage: 1.4+ MB

# %%
df2a['Item'].unique()
# Out:
# array(['Annual Profit and Loss - Total Revenue Excluding Int',
#        'Annual Profit and Loss - Operating Expenses',
#        'Annual Profit and Loss - Net Profit after Tax Before',
#        'Annual Profit and Loss - Reported NPAT After Abnorma',
#        'Annual Profit and Loss - Shares Outstanding at Perio',
#        'Annual Profit and Loss - Weighted Average Number of'],
#       dtype=object)

# %%
word_count = df2a['Item'].str.find('-', start=1)+2

# %%
word_count.unique()
# Out:
# array([25])

# %%
# df2a['Item2'] = df2a['Item']

# %%
# df2a['Item2'] = df2a['Item2'].str[25:]

# %%
# df2a = df2a.drop(columns=['Item2'])

# %%
df2a['Item'] = df2a['Item'].str[25:]

# %%
df2a['Item'].unique()
# Out:
# array(['Total Revenue Excluding Int', 'Operating Expenses',
#        'Net Profit after Tax Before', 'Reported NPAT After Abnorma',
#        'Shares Outstanding at Perio', 'Weighted Average Number of'],
#       dtype=object)

# %%
# This is similar to balance sheet data
# saving each file under different year
for i in range(2010,2021):
    locals()['df2a_{0}'.format(i)] = df2a.pivot(index='ASX Code', columns='Item', values=str(i))
    locals()['df2a_{0}'.format(i)]['year'] = i
    print('df2a_'+str(i))
# Out:
# df2a_2010
# df2a_2011
# df2a_2012
# df2a_2013
# df2a_2014
# df2a_2015
# df2a_2016
# df2a_2017
# df2a_2018
# df2a_2019
# df2a_2020

# %%
# appending all the files
income_statement = df2a_2010.append([df2a_2011,
                                  df2a_2012,
                                  df2a_2013,
                                  df2a_2014,
                                  df2a_2015,
                                  df2a_2016,
                                  df2a_2017,
                                  df2a_2018,
                                  df2a_2019,
                                  df2a_2020])

# %%
income_statement.year.value_counts().sort_index()
# Out:
# 2010    2169
# 2011    2169
# 2012    2169
# 2013    2169
# 2014    2169
# 2015    2169
# 2016    2169
# 2017    2169
# 2018    2169
# 2019    2169
# 2020    2169
# Name: year, dtype: int64

# %%
income_statement.head()
# Out:
# Item     Net Profit after Tax Before Operating Expenses  \
# ASX Code
# 14D
# 1AD
# 1AG                           317330          -12886912
# 1ST
# 2BE
#
# Item     Reported NPAT After Abnorma Shares Outstanding at Perio  \
# ASX Code
# 14D
# 1AD
# 1AG                           317330                    39697172
# 1ST
# 2BE
#
# Item     Total Revenue Excluding Int Weighted Average Number of  year
# ASX Code
# 14D                                                              2010
# 1AD                                                              2010
# 1AG                         13271768                   39741707  2010
# 1ST                                                              2010
# 2BE                                                              2010

# %% [markdown]
# # Cash flow and market data

# %%
df3a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10845 entries, 0 to 10844
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ASX Code      10845 non-null  object
#  1   Company Name  10845 non-null  object
#  2   Item          10845 non-null  object
#  3   2010          10845 non-null  object
#  4   2011          10845 non-null  object
#  5   2012          10845 non-null  object
#  6   2013          10845 non-null  object
#  7   2014          10845 non-null  object
#  8   2015          10845 non-null  object
#  9   2016          10845 non-null  object
#  10  2017          10845 non-null  object
#  11  2018          10845 non-null  object
#  12  2019          10845 non-null  object
#  13  2020          10845 non-null  object
# dtypes: object(14)
# memory usage: 1.2+ MB

# %%
df3a['Item'].unique()
# Out:
# array(['Annual Cash Flow - Net Operating Cash Flow',
#        'Annual Cash Flow - Net Investing Cash Flow',
#        'Annual Cash Flow - Net Financing Cash Flow',
#        'Annual Ratio Analysis - Year End Share Price ($)',
#        'Annual Ratio Analysis - Market Cap.($)'], dtype=object)

# %%
df3a['Item1'] = df3a['Item'].str.find('-', start=1)+2
df3a['Item1'] = df3a['Item1'].astype('int')
df3a['Item1'].unique()
# Out:
# array([19, 24])

# %%
df3a["CF"] = df3a['Item'].str.contains("Annual Cash Flow")
df3a["CF"]
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 10840     True
# 10841     True
# 10842     True
# 10843    False
# 10844    False
# Name: CF, Length: 10845, dtype: bool

# %%
word_count_cf = df3a.loc[df3a['Item']=='Annual Cash Flow - Net Operating Cash Flow', 'Item1'].mean()
word_count_mkt = df3a.loc[df3a['Item']=='Annual Ratio Analysis - Year End Share Price ($)', 'Item1'].mean()

word_count_cf = int(word_count_cf)
word_count_mkt = int(word_count_mkt)

print(word_count_cf)
print(word_count_mkt)
# Out:
# 19
# 24

# %%
# renaming
df3a.loc[df3a['CF']==True,'Item'] = df3a.Item.str.slice(word_count_cf)
df3a.loc[df3a['CF']==False,'Item'] = df3a.Item.str.slice(word_count_mkt)
    
df3a.head()
# Out:
#   ASX Code          Company Name                      Item 2010 2011 2012  \
# 0      14D  1414 Degrees Limited   Net Operating Cash Flow
# 1      14D  1414 Degrees Limited   Net Investing Cash Flow
# 2      14D  1414 Degrees Limited   Net Financing Cash Flow
# 3      14D  1414 Degrees Limited  Year End Share Price ($)
# 4      14D  1414 Degrees Limited            Market Cap.($)
#
#   2013 2014 2015 2016 2017 2018        2019         2020  Item1     CF
# 0                       --         -4134023     -2607214     19   True
# 1                       --         -3098750     -2335031     19   True
# 2                        0         16022508      -398868     19   True
# 3                       --             0.29         0.09     24  False
# 4                        0       5.0855e+07  1.57343e+07     24  False

# %%
df3a.Item.value_counts()
# Out:
# Market Cap.($)              2169
# Year End Share Price ($)    2169
# Net Investing Cash Flow     2169
# Net Financing Cash Flow     2169
# Net Operating Cash Flow     2169
# Name: Item, dtype: int64

# %%
df3a.columns
# Out:
# Index(['ASX Code', 'Company Name', 'Item', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'Item1', 'CF'],
#       dtype='object')

# %%
# saving each file under different year
for i in range(2010,2021):
    locals()['df3a_{0}'.format(i)] = df3a.pivot(index='ASX Code', columns='Item', values=str(i))
    locals()['df3a_{0}'.format(i)]['year'] = i
    print('df3a_'+str(i))
#     df1a_[i] = df1a.pivot(index='ASX Code', columns='Item', values='i')
# Out:
# df3a_2010
# df3a_2011
# df3a_2012
# df3a_2013
# df3a_2014
# df3a_2015
# df3a_2016
# df3a_2017
# df3a_2018
# df3a_2019
# df3a_2020

# %%
# appending all the files
cash_flow = df3a_2010.append([df3a_2011,
                              df3a_2012,
                              df3a_2013,
                              df3a_2014,
                              df3a_2015,
                              df3a_2016,
                              df3a_2017,
                              df3a_2018,
                              df3a_2019,
                              df3a_2020])

# %%
cash_flow.year.value_counts().sort_index()
# Out:
# 2010    2169
# 2011    2169
# 2012    2169
# 2013    2169
# 2014    2169
# 2015    2169
# 2016    2169
# 2017    2169
# 2018    2169
# 2019    2169
# 2020    2169
# Name: year, dtype: int64

# %%
cash_flow.head()
# Out:
# Item     Market Cap.($) Net Financing Cash Flow Net Investing Cash Flow  \
# ASX Code
# 14D
# 1AD
# 1AG         3.45365e+06                 1206807                -3371176
# 1ST
# 2BE
#
# Item     Net Operating Cash Flow Year End Share Price ($)  year
# ASX Code
# 14D                                                        2010
# 1AD                                                        2010
# 1AG                      -417821                     0.09  2010
# 1ST                                                        2010
# 2BE                                                        2010

# %% [markdown]
# # Merging data

# %%
#data sets are
balance_sheet.head(2)
# Out:
# Item     CA Cash CA Inventories CL Short-Term Debt NCL Long-Term Debt  \
# ASX Code
# 14D
# 1AD
#
# Item     Net Operating Cash Flow Total Assets Total Curr. Liabilities  \
# ASX Code
# 14D
# 1AD
#
# Item     Total Current Assets Total Equity Total Liabilities  year
# ASX Code
# 14D                                                           2010
# 1AD                                                           2010

# %%
income_statement.head(2)
# Out:
# Item     Net Profit after Tax Before Operating Expenses  \
# ASX Code
# 14D
# 1AD
#
# Item     Reported NPAT After Abnorma Shares Outstanding at Perio  \
# ASX Code
# 14D
# 1AD
#
# Item     Total Revenue Excluding Int Weighted Average Number of  year
# ASX Code
# 14D                                                              2010
# 1AD                                                              2010

# %%
cash_flow.head(2)
# Out:
# Item     Market Cap.($) Net Financing Cash Flow Net Investing Cash Flow  \
# ASX Code
# 14D
# 1AD
#
# Item     Net Operating Cash Flow Year End Share Price ($)  year
# ASX Code
# 14D                                                        2010
# 1AD                                                        2010

# %%
balance_sheet.columns
# Out:
# Index(['CA Cash', 'CA Inventories', 'CL Short-Term Debt', 'NCL Long-Term Debt',
#        'Net Operating Cash Flow', 'Total Assets', 'Total Curr. Liabilities',
#        'Total Current Assets', 'Total Equity', 'Total Liabilities', 'year'],
#       dtype='object', name='Item')

# %%
# merging
financial = balance_sheet.merge(income_statement, how='left', on=['ASX Code','year'])
financial = financial.merge(cash_flow, how='left', on=['ASX Code','year'])
financial.head()
# Out:
# Item     CA Cash CA Inventories CL Short-Term Debt NCL Long-Term Debt  \
# ASX Code
# 14D
# 1AD
# 1AG       271919         282857            1046419              59535
# 1ST
# 2BE
#
# Item     Net Operating Cash Flow_x Total Assets Total Curr. Liabilities  \
# ASX Code
# 14D
# 1AD
# 1AG                        -417821      8940993                 3922626
# 1ST
# 2BE
#
# Item     Total Current Assets Total Equity Total Liabilities  ...  \
# ASX Code                                                      ...
# 14D                                                           ...
# 1AD                                                           ...
# 1AG                   2336530      4958832           3982161  ...
# 1ST                                                           ...
# 2BE                                                           ...
#
# Item      Operating Expenses Reported NPAT After Abnorma  \
# ASX Code
# 14D
# 1AD
# 1AG                -12886912                      317330
# 1ST
# 2BE
#
# Item     Shares Outstanding at Perio Total Revenue Excluding Int  \
# ASX Code
# 14D
# 1AD
# 1AG                         39697172                    13271768
# 1ST
# 2BE
#
# Item     Weighted Average Number of Market Cap.($) Net Financing Cash Flow  \
# ASX Code
# 14D
# 1AD
# 1AG                        39741707    3.45365e+06                 1206807
# 1ST
# 2BE
#
# Item     Net Investing Cash Flow Net Operating Cash Flow_y  \
# ASX Code
# 14D
# 1AD
# 1AG                     -3371176                   -417821
# 1ST
# 2BE
#
# Item     Year End Share Price ($)
# ASX Code
# 14D
# 1AD
# 1AG                          0.09
# 1ST
# 2BE
#
# [5 rows x 22 columns]

# %%
financial.columns
# Out:
# Index(['CA Cash', 'CA Inventories', 'CL Short-Term Debt', 'NCL Long-Term Debt',
#        'Net Operating Cash Flow_x', 'Total Assets', 'Total Curr. Liabilities',
#        'Total Current Assets', 'Total Equity', 'Total Liabilities', 'year',
#        'Net Profit after Tax Before', 'Operating Expenses',
#        'Reported NPAT After Abnorma', 'Shares Outstanding at Perio',
#        'Total Revenue Excluding Int', 'Weighted Average Number of',
#        'Market Cap.($)', 'Net Financing Cash Flow', 'Net Investing Cash Flow',
#        'Net Operating Cash Flow_y', 'Year End Share Price ($)'],
#       dtype='object', name='Item')

# %% [markdown]
# # Data cleaning

# %%
financial.head(2)
# Out:
# Item     CA Cash CA Inventories CL Short-Term Debt NCL Long-Term Debt  \
# ASX Code
# 14D
# 1AD
#
# Item     Net Operating Cash Flow_x Total Assets Total Curr. Liabilities  \
# ASX Code
# 14D
# 1AD
#
# Item     Total Current Assets Total Equity Total Liabilities  ...  \
# ASX Code                                                      ...
# 14D                                                           ...
# 1AD                                                           ...
#
# Item      Operating Expenses Reported NPAT After Abnorma  \
# ASX Code
# 14D
# 1AD
#
# Item     Shares Outstanding at Perio Total Revenue Excluding Int  \
# ASX Code
# 14D
# 1AD
#
# Item     Weighted Average Number of Market Cap.($) Net Financing Cash Flow  \
# ASX Code
# 14D
# 1AD
#
# Item     Net Investing Cash Flow Net Operating Cash Flow_y  \
# ASX Code
# 14D
# 1AD
#
# Item     Year End Share Price ($)
# ASX Code
# 14D
# 1AD
#
# [2 rows x 22 columns]

# %%
financial.columns
# Out:
# Index(['CA Cash', 'CA Inventories', 'CL Short-Term Debt', 'NCL Long-Term Debt',
#        'Net Operating Cash Flow_x', 'Total Assets', 'Total Curr. Liabilities',
#        'Total Current Assets', 'Total Equity', 'Total Liabilities', 'year',
#        'Net Profit after Tax Before', 'Operating Expenses',
#        'Reported NPAT After Abnorma', 'Shares Outstanding at Perio',
#        'Total Revenue Excluding Int', 'Weighted Average Number of',
#        'Market Cap.($)', 'Net Financing Cash Flow', 'Net Investing Cash Flow',
#        'Net Operating Cash Flow_y', 'Year End Share Price ($)'],
#       dtype='object', name='Item')

# %%
financial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23859 entries, 14D to ZYUS
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CA Cash                      23859 non-null  object
#  1   CA Inventories               23859 non-null  object
#  2   CL Short-Term Debt           23859 non-null  object
#  3   NCL Long-Term Debt           23859 non-null  object
#  4   Net Operating Cash Flow_x    23859 non-null  object
#  5   Total Assets                 23859 non-null  object
#  6   Total Curr. Liabilities      23859 non-null  object
#  7   Total Current Assets         23859 non-null  object
#  8   Total Equity                 23859 non-null  object
#  9   Total Liabilities            23859 non-null  object
#  10  year                         23859 non-null  int64
#  11  Net Profit after Tax Before  23859 non-null  object
#  12  Operating Expenses           23859 non-null  object
#  13  Reported NPAT After Abnorma  23859 non-null  object
#  14  Shares Outstanding at Perio  23859 non-null  object
#  15  Total Revenue Excluding Int  23859 non-null  object
#  16  Weighted Average Number of   23859 non-null  object
#  17  Market Cap.($)               23859 non-null  object
#  18  Net Financing Cash Flow      23859 non-null  object
#  19  Net Investing Cash Flow      23859 non-null  object
#  20  Net Operating Cash Flow_y    23859 non-null  object
#  21  Year End Share Price ($)     23859 non-null  object
# dtypes: int64(1), object(21)
# memory usage: 4.2+ MB

# %% [markdown]
# # Dealing with dtype and missing values

# %%
# converting all columns to float
for columns in financial:
    financial[columns] = pd.to_numeric(financial[columns], errors='coerce', downcast='float')

# %%
financial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23859 entries, 14D to ZYUS
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CA Cash                      18111 non-null  float32
#  1   CA Inventories               15251 non-null  float32
#  2   CL Short-Term Debt           15309 non-null  float32
#  3   NCL Long-Term Debt           11608 non-null  float32
#  4   Net Operating Cash Flow_x    17442 non-null  float32
#  5   Total Assets                 18221 non-null  float32
#  6   Total Curr. Liabilities      18005 non-null  float32
#  7   Total Current Assets         18119 non-null  float32
#  8   Total Equity                 18108 non-null  float32
#  9   Total Liabilities            18147 non-null  float32
#  10  year                         23859 non-null  float32
#  11  Net Profit after Tax Before  18254 non-null  float32
#  12  Operating Expenses           14653 non-null  float32
#  13  Reported NPAT After Abnorma  18254 non-null  float32
#  14  Shares Outstanding at Perio  18245 non-null  float32
#  15  Total Revenue Excluding Int  12752 non-null  float32
#  16  Weighted Average Number of   18245 non-null  float32
#  17  Market Cap.($)               18249 non-null  float32
#  18  Net Financing Cash Flow      18248 non-null  float32
#  19  Net Investing Cash Flow      15691 non-null  float32
#  20  Net Operating Cash Flow_y    17440 non-null  float32
#  21  Year End Share Price ($)     17530 non-null  float32
# dtypes: float32(22)
# memory usage: 2.2+ MB

# %%
financial.describe()
# Out:
# Item        CA Cash  CA Inventories  CL Short-Term Debt  NCL Long-Term Debt  \
# count  1.811100e+04    1.525100e+04        1.530900e+04        1.160800e+04
# mean   7.497133e+07    4.372224e+07        1.119592e+08        3.513491e+08
# std    6.304915e+08    3.098298e+08        2.077270e+09        2.437895e+09
# min   -1.148500e+07    0.000000e+00       -1.470000e+07       -3.043600e+07
# 25%    9.058570e+05    0.000000e+00        0.000000e+00        0.000000e+00
# 50%    3.495899e+06    0.000000e+00        0.000000e+00        2.881950e+05
# 75%    1.588263e+07    1.550277e+06        1.656000e+06        3.098400e+07
# max    2.870500e+10    6.530000e+09        6.838000e+10        8.906300e+10
#
# Item   Net Operating Cash Flow_x  Total Assets  Total Curr. Liabilities  \
# count               1.744200e+04  1.822100e+04             1.800500e+04
# mean                1.041165e+08  3.451183e+09             2.727123e+08
# std                 1.233999e+09  4.229226e+10             3.277550e+09
# min                -1.309000e+10  0.000000e+00            -2.798000e+08
# 25%                -2.200148e+06  6.481387e+06             4.558030e+05
# 50%                -5.492025e+05  2.478387e+07             2.362582e+06
# 75%                 6.053250e+06  1.783680e+08             2.264367e+07
# max                 5.865100e+10  1.042286e+12             1.447210e+11
#
# Item   Total Current Assets  Total Equity  Total Liabilities  ...  \
# count          1.811900e+04  1.810800e+04       1.814700e+04  ...
# mean           3.077421e+08  8.654507e+08       2.601554e+09  ...
# std            3.174302e+09  1.021292e+10       3.841348e+10  ...
# min            0.000000e+00 -9.805860e+08      -2.941000e+08  ...
# 25%            1.846916e+06  4.646835e+06       5.856810e+05  ...
# 50%            6.874000e+06  1.728392e+07       3.791202e+06  ...
# 75%            4.612750e+07  1.083686e+08       4.859350e+07  ...
# max            1.279160e+11  8.976239e+11       9.809890e+11  ...
#
# Item   Operating Expenses  Reported NPAT After Abnorma  \
# count        1.465300e+04                 1.825400e+04
# mean        -4.261177e+08                 8.292649e+07
# std          2.789733e+09                 1.838357e+09
# min         -6.313000e+10                -8.677771e+09
# 25%         -5.786300e+07                -3.790504e+06
# 50%         -7.011000e+06                -7.987125e+05
# 75%         -2.024125e+06                 4.101864e+06
# max          9.481439e+08                 2.101043e+11
#
# Item   Shares Outstanding at Perio  Total Revenue Excluding Int  \
# count                 1.824500e+04                 1.275200e+04
# mean                  5.140247e+08                 6.177572e+08
# std                   1.364795e+09                 3.856390e+09
# min                   0.000000e+00                -6.316401e+07
# 25%                   9.273900e+07                 2.176392e+05
# 50%                   2.082018e+08                 4.003427e+06
# 75%                   5.142805e+08                 9.891266e+07
# max                   7.703490e+10                 7.557736e+10
#
# Item   Weighted Average Number of  Market Cap.($)  Net Financing Cash Flow  \
# count                1.824500e+04    1.824900e+04             1.824800e+04
# mean                 4.574308e+08    1.821242e+09            -1.831064e+07
# std                  1.123397e+09    1.620643e+10             8.320131e+08
# min                  0.000000e+00    0.000000e+00            -3.223200e+10
# 25%                  7.856000e+07    6.350234e+06            -2.843242e+05
# 50%                  1.857370e+08    2.598462e+07             6.166445e+05
# 75%                  4.644955e+08    1.547034e+08             5.106321e+06
# max                  6.791161e+10    4.726875e+11             4.480900e+10
#
# Item   Net Investing Cash Flow  Net Operating Cash Flow_y  \
# count             1.569100e+04               1.744000e+04
# mean             -8.010092e+07               1.041916e+08
# std               8.184730e+08               1.234093e+09
# min              -3.425800e+10              -1.309000e+10
# 25%              -9.823396e+06              -2.198024e+06
# 50%              -1.228146e+06              -5.478435e+05
# 75%              -5.975900e+04               6.153740e+06
# max               8.148000e+09               5.865100e+10
#
# Item   Year End Share Price ($)
# count              17530.000000
# mean                   4.154193
# std                   17.778593
# min                    0.000000
# 25%                    0.030000
# 50%                    0.170000
# 75%                    1.310000
# max                  465.100006
#
# [8 rows x 22 columns]

# %%
# functions to change missing value to zero or nan
def missing_to_zero(data, column):
    missing = data[column].isna()
    data.loc[missing, column] = 0

# %%
financial.isna().sum()
# Out:
# Item
# CA Cash                         5748
# CA Inventories                  8608
# CL Short-Term Debt              8550
# NCL Long-Term Debt             12251
# Net Operating Cash Flow_x       6417
# Total Assets                    5638
# Total Curr. Liabilities         5854
# Total Current Assets            5740
# Total Equity                    5751
# Total Liabilities               5712
# year                               0
# Net Profit after Tax Before     5605
# Operating Expenses              9206
# Reported NPAT After Abnorma     5605
# Shares Outstanding at Perio     5614
# Total Revenue Excluding Int    11107
# Weighted Average Number of      5614
# Market Cap.($)                  5610
# Net Financing Cash Flow         5611
# Net Investing Cash Flow         8168
# Net Operating Cash Flow_y       6419
# Year End Share Price ($)        6329
# dtype: int64

# %%
financial = financial.drop(columns=['Net Operating Cash Flow_x'])

# %%
financial.rename(columns={'Net Operating Cash Flow_y':'Net Operating Cash Flow'}, inplace=True)

# %%
financial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23859 entries, 14D to ZYUS
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CA Cash                      18111 non-null  float32
#  1   CA Inventories               15251 non-null  float32
#  2   CL Short-Term Debt           15309 non-null  float32
#  3   NCL Long-Term Debt           11608 non-null  float32
#  4   Total Assets                 18221 non-null  float32
#  5   Total Curr. Liabilities      18005 non-null  float32
#  6   Total Current Assets         18119 non-null  float32
#  7   Total Equity                 18108 non-null  float32
#  8   Total Liabilities            18147 non-null  float32
#  9   year                         23859 non-null  float32
#  10  Net Profit after Tax Before  18254 non-null  float32
#  11  Operating Expenses           14653 non-null  float32
#  12  Reported NPAT After Abnorma  18254 non-null  float32
#  13  Shares Outstanding at Perio  18245 non-null  float32
#  14  Total Revenue Excluding Int  12752 non-null  float32
#  15  Weighted Average Number of   18245 non-null  float32
#  16  Market Cap.($)               18249 non-null  float32
#  17  Net Financing Cash Flow      18248 non-null  float32
#  18  Net Investing Cash Flow      15691 non-null  float32
#  19  Net Operating Cash Flow      17440 non-null  float32
#  20  Year End Share Price ($)     17530 non-null  float32
# dtypes: float32(21)
# memory usage: 2.1+ MB

# %%
financial1 = financial[['Total Assets','Total Curr. Liabilities','Total Current Assets','Total Equity',
                        'Total Liabilities','year','Reported NPAT After Abnorma','Weighted Average Number of',
                       'Year End Share Price ($)', 'Market Cap.($)']]

# %%
# only going to keep with positive equity value
financial1 = financial1.loc[financial1['Total Equity']>1]

# %%
# replacing to np.NaN if value is zero or negative for 
# Total Curr. Liabilities, Total Current Assets, Total Liabilities, 
# Weighted Average Number of, Year End Share Price ($)
financial1['Total Liabilities'].loc[financial1['Total Liabilities']<1] = np.NaN
financial1['Total Curr. Liabilities'].loc[financial1['Total Curr. Liabilities']<1] = np.NaN
financial1['Total Current Assets'].loc[financial1['Total Current Assets']<1] = np.NaN
financial1['Weighted Average Number of'].loc[financial1['Weighted Average Number of']<1] = np.NaN
financial1['Year End Share Price ($)'].loc[financial1['Year End Share Price ($)']==0] = np.NaN

# %%
# Replacing those value

# %%
financial1.loc[financial1['Market Cap.($)']<1]
# Out:
# Item      Total Assets  Total Curr. Liabilities  Total Current Assets  \
# ASX Code
# 4DS       6.738505e+06                      NaN          4.916505e+06
# AAJ       4.830740e+06                  60794.0          4.580795e+06
# ACP       3.473894e+06                  10405.0          3.222263e+06
# AEB       7.140816e+06                 300000.0          7.138069e+06
# AFW       3.415586e+06                      NaN          2.700467e+06
# ...                ...                      ...                   ...
# UNI       1.943000e+08               38800000.0          2.760000e+07
# WAK       3.043735e+07                6696353.0          2.483732e+07
# WSR       5.756134e+09                9829000.0          5.203251e+09
# YFZ       6.600000e+07               33400000.0          5.190000e+07
# ZBT       5.433338e+07                5874981.0          5.134052e+07
#
# Item      Total Equity  Total Liabilities    year  \
# ASX Code
# 4DS       6.738505e+06                NaN  2010.0
# AAJ       4.769946e+06            60794.0  2010.0
# ACP       3.463489e+06            10405.0  2010.0
# AEB       6.840816e+06           300000.0  2010.0
# AFW       3.415586e+06                NaN  2010.0
# ...                ...                ...     ...
# UNI       8.540000e+07        108900000.0  2020.0
# WAK       6.030758e+06         24406596.0  2020.0
# WSR       5.746305e+09          9829000.0  2020.0
# YFZ       2.810000e+07         37900000.0  2020.0
# ZBT       4.070377e+07         13629608.0  2020.0
#
# Item      Reported NPAT After Abnorma  Weighted Average Number of  \
# ASX Code
# 4DS                         -124800.0                         NaN
# AAJ                               0.0                         NaN
# ACP                               0.0                         NaN
# AEB                        -3728758.0                         NaN
# AFW                         -534936.0                  31650000.0
# ...                               ...                         ...
# UNI                               0.0                         NaN
# WAK                               0.0                         NaN
# WSR                               0.0                         NaN
# YFZ                               0.0                         NaN
# ZBT                               0.0                         NaN
#
# Item      Year End Share Price ($)  Market Cap.($)
# ASX Code
# 4DS                            NaN             0.0
# AAJ                            NaN             0.0
# ACP                            NaN             0.0
# AEB                            NaN             0.0
# AFW                            NaN             0.0
# ...                            ...             ...
# UNI                            NaN             0.0
# WAK                            NaN             0.0
# WSR                            NaN             0.0
# YFZ                            NaN             0.0
# ZBT                            NaN             0.0
#
# [700 rows x 10 columns]

# %%
financial1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17166 entries, 1AG to ZYUS
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Total Assets                 17166 non-null  float32
#  1   Total Curr. Liabilities      16946 non-null  float32
#  2   Total Current Assets         17018 non-null  float32
#  3   Total Equity                 17166 non-null  float32
#  4   Total Liabilities            17080 non-null  float32
#  5   year                         17166 non-null  float32
#  6   Reported NPAT After Abnorma  17166 non-null  float32
#  7   Weighted Average Number of   16505 non-null  float32
#  8   Year End Share Price ($)     15745 non-null  float32
#  9   Market Cap.($)               17166 non-null  float32
# dtypes: float32(10)
# memory usage: 804.7+ KB

# %%
# merging is done after cleaning the financial data

# %%
# merging company details
financial1 = financial1.merge(df4a, how='left', on=['ASX Code'])
financial1.head()
# Out:
#   ASX Code  Total Assets  Total Curr. Liabilities  Total Current Assets  \
# 0      1AG     8940993.0                3922626.0             2336530.0
# 1      3DP     1717388.0                  30750.0             1467388.0
# 2      4CE     3378904.0                 128776.0             3205770.0
# 3      4DS     6738505.0                      NaN             4916505.0
# 4      88E     3788450.0                 214519.0             2218354.0
#
#    Total Equity  Total Liabilities    year  Reported NPAT After Abnorma  \
# 0     4958832.0          3982161.0  2010.0                     317330.0
# 1     1686638.0            30750.0  2010.0                    5524380.0
# 2     3250128.0           128776.0  2010.0                    -457946.0
# 3     6738505.0                NaN  2010.0                    -124800.0
# 4     3573931.0           214519.0  2010.0                   -1731782.0
#
#    Weighted Average Number of  Year End Share Price ($)  Market Cap.($)  \
# 0                  39741708.0                      0.09      3453654.00
# 1                  91474528.0                      0.01      3679128.75
# 2                  18333332.0                      0.21     15050000.00
# 3                         NaN                       NaN            0.00
# 4                  64559084.0                      0.25     20482148.00
#
#                 Company Name   Status             GICS Sector  \
# 0            Alterra Limited  Trading             Industrials
# 1          Pointerra Limited  Trading  Information Technology
# 2  Force Commodities Limited  Trading               Materials
# 3         4DS Memory Limited  Trading  Information Technology
# 4          88 Energy Limited  Trading                  Energy
#
#                         GICS Industry Group  \
# 0        Commercial & Professional Services
# 1                       Software & Services
# 2                                 Materials
# 3  Semiconductors & Semiconductor Equipment
# 4                                    Energy
#
#                               GICS Industry
# 0            Commercial Services & Supplies
# 1                                  Software
# 2                           Metals & Mining
# 3  Semiconductors & Semiconductor Equipment
# 4               Oil, Gas & Consumable Fuels

# %%
financial1 = financial1.set_index(['ASX Code'])

# %% [markdown]
# # Calculating ratios

# %%
financial1.describe().T
# Out:
#                                count          mean           std  \
# Total Assets                 17166.0  3.656867e+09  4.356663e+10
# Total Curr. Liabilities      16946.0  2.885506e+08  3.377783e+09
# Total Current Assets         17018.0  3.265585e+08  3.274597e+09
# Total Equity                 17166.0  9.137147e+08  1.048739e+10
# Total Liabilities            17080.0  2.756902e+09  3.958780e+10
# year                         17166.0  2.015459e+03  3.113908e+00
# Reported NPAT After Abnorma  17166.0  8.843349e+07  1.895479e+09
# Weighted Average Number of   16505.0  4.733525e+08  1.133318e+09
# Year End Share Price ($)     15745.0  4.380467e+00  1.836966e+01
# Market Cap.($)               17166.0  1.892076e+09  1.636611e+10
#
#                                       min          25%           50%  \
# Total Assets                 1.439000e+03   7510308.00  2.836742e+07
# Total Curr. Liabilities      2.020000e+02    446166.50  2.417152e+06
# Total Current Assets         5.530000e+02   2197327.25  7.928539e+06
# Total Equity                 3.130000e+02   5761510.75  2.027021e+07
# Total Liabilities            2.020000e+02    559668.25  3.781752e+06
# year                         2.010000e+03      2013.00  2.016000e+03
# Reported NPAT After Abnorma -8.677771e+09  -3711057.75 -7.642670e+05
# Weighted Average Number of   1.999000e+03  90338576.00  1.983020e+08
# Year End Share Price ($)     1.000000e-02         0.05  2.100000e-01
# Market Cap.($)               0.000000e+00   7184598.00  2.924352e+07
#
#                                       75%           max
# Total Assets                 1.984020e+08  1.042286e+12
# Total Curr. Liabilities      2.467788e+07  1.447210e+11
# Total Current Assets         5.204240e+07  1.279160e+11
# Total Equity                 1.239338e+08  8.976239e+11
# Total Liabilities            5.283475e+07  9.809890e+11
# year                         2.018000e+03  2.020000e+03
# Reported NPAT After Abnorma  5.147665e+06  2.101043e+11
# Weighted Average Number of   4.832890e+08  6.791161e+10
# Year End Share Price ($)     1.570000e+00  4.651000e+02
# Market Cap.($)               1.734780e+08  4.726875e+11

# %%
# Profitability ratios
# need to work on it more to use average assets and equity
# financial1['PM_before_ab'] = financial1['Net Profit after Tax Before']/financial1['Total Revenue Excluding Int']
# financial1['PM_after_ab'] = financial1['Reported NPAT After Abnorma']/financial1['Total Revenue Excluding Int']
financial1['ROA'] = financial1['Reported NPAT After Abnorma']/financial1['Total Assets']
financial1['ROE'] = financial1['Reported NPAT After Abnorma']/financial1['Total Equity']
financial1['EPS'] = financial1['Reported NPAT After Abnorma']/financial1['Weighted Average Number of']
financial1['PE'] = financial1['Year End Share Price ($)']/financial1['EPS']

# %%
# # keep only those EPS with positive value
# financial1['EPS'].loc[financial1['EPS']<0] = 0
# financial1['PE'].loc[financial1['PE']<0] = 0

# %%
# Liquidity & solvency ratios
financial1['current_ratio'] = financial1['Total Current Assets']/financial1['Total Curr. Liabilities']
financial1['DE'] = financial1['Total Liabilities']/financial1['Total Equity']
financial1['DA'] = financial1['Total Liabilities']/financial1['Total Assets']

# %%
# Horizonal analysis

# %%
financial1.describe().T
# Out:
#                                count          mean           std  \
# Total Assets                 17166.0  3.656867e+09  4.356663e+10
# Total Curr. Liabilities      16946.0  2.885506e+08  3.377783e+09
# Total Current Assets         17018.0  3.265585e+08  3.274597e+09
# Total Equity                 17166.0  9.137147e+08  1.048739e+10
# Total Liabilities            17080.0  2.756902e+09  3.958780e+10
# year                         17166.0  2.015459e+03  3.113908e+00
# Reported NPAT After Abnorma  17166.0  8.843349e+07  1.895479e+09
# Weighted Average Number of   16505.0  4.733525e+08  1.133318e+09
# Year End Share Price ($)     15745.0  4.380467e+00  1.836966e+01
# Market Cap.($)               17166.0  1.892076e+09  1.636611e+10
# ROA                          17166.0 -6.880107e-02  3.199915e+01
# ROE                          17166.0 -9.426401e-01  8.027978e+01
# EPS                          16505.0  2.635521e-01  4.461802e+00
# PE                           15731.0           inf           NaN
# current_ratio                16933.0  2.381662e+01  7.076097e+02
# DE                           17080.0  1.399797e+00  1.915543e+01
# DA                           17080.0  2.729636e-01  2.479439e-01
#
#                                       min           25%           50%  \
# Total Assets                 1.439000e+03  7.510308e+06  2.836742e+07
# Total Curr. Liabilities      2.020000e+02  4.461665e+05  2.417152e+06
# Total Current Assets         5.530000e+02  2.197327e+06  7.928539e+06
# Total Equity                 3.130000e+02  5.761511e+06  2.027021e+07
# Total Liabilities            2.020000e+02  5.596682e+05  3.781752e+06
# year                         2.010000e+03  2.013000e+03  2.016000e+03
# Reported NPAT After Abnorma -8.677771e+09 -3.711058e+06 -7.642670e+05
# Weighted Average Number of   1.999000e+03  9.033858e+07  1.983020e+08
# Year End Share Price ($)     1.000000e-02  5.000000e-02  2.100000e-01
# Market Cap.($)               0.000000e+00  7.184598e+06  2.924352e+07
# ROA                         -3.183714e+02 -2.957632e-01 -5.292079e-02
# ROE                         -8.605090e+03 -3.924610e-01 -6.556910e-02
# EPS                         -2.865118e+01 -2.149560e-02 -3.109960e-03
# PE                          -5.888440e+04 -7.187386e+00 -1.496951e+00
# current_ratio                1.247855e-03  1.235844e+00  2.569330e+00
# DE                           1.901723e-06  5.833236e-02  2.540575e-01
# DA                           1.901719e-06  5.509276e-02  2.025883e-01
#
#                                       75%           max
# Total Assets                 1.984020e+08  1.042286e+12
# Total Curr. Liabilities      2.467788e+07  1.447210e+11
# Total Current Assets         5.204240e+07  1.279160e+11
# Total Equity                 1.239338e+08  8.976239e+11
# Total Liabilities            5.283475e+07  9.809890e+11
# year                         2.018000e+03  2.020000e+03
# Reported NPAT After Abnorma  5.147665e+06  2.101043e+11
# Weighted Average Number of   4.832890e+08  6.791161e+10
# Year End Share Price ($)     1.570000e+00  4.651000e+02
# Market Cap.($)               1.734780e+08  4.726875e+11
# ROA                          4.021877e-02  4.166518e+03
# ROE                          6.916144e-02  5.649982e+03
# EPS                          5.931734e-02  3.629632e+02
# PE                           1.159424e+01           inf
# current_ratio                7.430549e+00  8.788539e+04
# DE                           7.808840e-01  1.532778e+03
# DA                           4.384811e-01  9.993480e-01

# %%
# replacing the infinite value

# %%
financial1.head()
# Out:
#           Total Assets  Total Curr. Liabilities  Total Current Assets  \
# ASX Code
# 1AG          8940993.0                3922626.0             2336530.0
# 3DP          1717388.0                  30750.0             1467388.0
# 4CE          3378904.0                 128776.0             3205770.0
# 4DS          6738505.0                      NaN             4916505.0
# 88E          3788450.0                 214519.0             2218354.0
#
#           Total Equity  Total Liabilities    year  \
# ASX Code
# 1AG          4958832.0          3982161.0  2010.0
# 3DP          1686638.0            30750.0  2010.0
# 4CE          3250128.0           128776.0  2010.0
# 4DS          6738505.0                NaN  2010.0
# 88E          3573931.0           214519.0  2010.0
#
#           Reported NPAT After Abnorma  Weighted Average Number of  \
# ASX Code
# 1AG                          317330.0                  39741708.0
# 3DP                         5524380.0                  91474528.0
# 4CE                         -457946.0                  18333332.0
# 4DS                         -124800.0                         NaN
# 88E                        -1731782.0                  64559084.0
#
#           Year End Share Price ($)  Market Cap.($)  ...  \
# ASX Code                                            ...
# 1AG                           0.09      3453654.00  ...
# 3DP                           0.01      3679128.75  ...
# 4CE                           0.21     15050000.00  ...
# 4DS                            NaN            0.00  ...
# 88E                           0.25     20482148.00  ...
#
#                      GICS Sector                       GICS Industry Group  \
# ASX Code
# 1AG                  Industrials        Commercial & Professional Services
# 3DP       Information Technology                       Software & Services
# 4CE                    Materials                                 Materials
# 4DS       Information Technology  Semiconductors & Semiconductor Equipment
# 88E                       Energy                                    Energy
#
#                                      GICS Industry       ROA       ROE  \
# ASX Code
# 1AG                 Commercial Services & Supplies  0.035492  0.063993
# 3DP                                       Software  3.216734  3.275380
# 4CE                                Metals & Mining -0.135531 -0.140901
# 4DS       Semiconductors & Semiconductor Equipment -0.018520 -0.018520
# 88E                    Oil, Gas & Consumable Fuels -0.457122 -0.484559
#
#                EPS         PE  current_ratio        DE        DA
# ASX Code
# 1AG       0.007985  11.271401       0.595655  0.803044  0.445382
# 3DP       0.060393   0.165583      47.719936  0.018232  0.017905
# 4CE      -0.024979  -8.407104      24.894157  0.039622  0.038112
# 4DS            NaN        NaN            NaN       NaN       NaN
# 88E      -0.026825  -9.319748      10.341061  0.060023  0.056624
#
# [5 rows x 22 columns]

# %%
financial1['GICS Sector'].sort_values().unique()
# Out:
# array(['--', 'Communication Services', 'Consumer Discretionary',
#        'Consumer Staples', 'Energy', 'Financials', 'Health Care',
#        'Industrials', 'Information Technology', 'Materials',
#        'Real Estate', 'Utilities'], dtype=object)

# %%
financial1['year'].sort_values().unique()
# Out:
# array([2010., 2011., 2012., 2013., 2014., 2015., 2016., 2017., 2018.,
#        2019., 2020.], dtype=float32)

# %%
financial1.loc[financial1['GICS Sector']=='--']
# Out:
#           Total Assets  Total Curr. Liabilities  Total Current Assets  \
# ASX Code
# IAA       1.588761e+08                1423482.0             1974183.0
# IJP       4.452612e+09               31475796.0            34630640.0
# IJR       7.084890e+09              487376928.0           494717696.0
# IKO       4.067817e+09              417707424.0           426361824.0
# IOO       2.899468e+09               38978632.0            43829944.0
# ...                ...                      ...                   ...
# YANK      1.244400e+07                  15000.0            12444000.0
# YMAX      2.512980e+08                5409000.0             5824000.0
# ZUSD      1.201740e+07                  12153.0            12017404.0
# ZYAU      1.134370e+08                 406000.0              361000.0
# ZYUS      6.882100e+07                2241000.0             1019000.0
#
#           Total Equity  Total Liabilities    year  \
# ASX Code
# IAA       1.574526e+08          1423482.0  2010.0
# IJP       4.421135e+09         31475796.0  2010.0
# IJR       6.597513e+09        487376928.0  2010.0
# IKO       3.650109e+09        417707424.0  2010.0
# IOO       2.860489e+09         38978632.0  2010.0
# ...                ...                ...     ...
# YANK      1.218800e+07           256000.0  2020.0
# YMAX      2.437410e+08          7557000.0  2020.0
# ZUSD      1.200525e+07            12153.0  2020.0
# ZYAU      1.130310e+08           406000.0  2020.0
# ZYUS      6.658000e+07          2241000.0  2020.0
#
#           Reported NPAT After Abnorma  Weighted Average Number of  \
# ASX Code
# IAA                      3.778994e+07                   3600000.0
# IJP                     -3.992936e+08                 418200000.0
# IJR                      2.306050e+09                 101550000.0
# IKO                      3.768377e+08                  68150000.0
# IOO                      9.230491e+08                  48900000.0
# ...                               ...                         ...
# YANK                    -6.800000e+05                    950000.0
# YMAX                    -3.668300e+07                  34660000.0
# ZUSD                     1.121010e+05                   1081031.0
# ZYAU                    -2.721000e+07                  12551000.0
# ZYUS                    -1.532200e+07                   6538000.0
#
#           Year End Share Price ($)  Market Cap.($)  ... GICS Sector  \
# ASX Code                                            ...
# IAA                      44.230000    1.592280e+08  ...          --
# IJP                      10.560000    4.416192e+09  ...          --
# IJR                      65.650002    6.666758e+09  ...          --
# IKO                      53.700001    3.659655e+09  ...          --
# IOO                      66.290001    3.241581e+09  ...          --
# ...                            ...             ...  ...         ...
# YANK                     12.900000    1.225500e+07  ...          --
# YMAX                      7.160000    2.481656e+08  ...          --
# ZUSD                     11.080000    1.197782e+07  ...          --
# ZYAU                      9.050000    1.135866e+08  ...          --
# ZYUS                     10.020000    6.551076e+07  ...          --
#
#          GICS Industry Group GICS Industry       ROA       ROE        EPS  \
# ASX Code
# IAA                       --            --  0.237858  0.240008  10.497207
# IJP                       --            -- -0.089676 -0.090315  -0.954791
# IJR                       --            --  0.325488  0.349533  22.708519
# IKO                       --            --  0.092639  0.103240   5.529533
# IOO                       --            --  0.318351  0.322689  18.876259
# ...                      ...           ...       ...       ...        ...
# YANK                      --            -- -0.054645 -0.055793  -0.715789
# YMAX                      --            -- -0.145974 -0.150500  -1.058367
# ZUSD                      --            --  0.009328  0.009338   0.103698
# ZYAU                      --            -- -0.239869 -0.240730  -2.167955
# ZYUS                      --            -- -0.222636 -0.230129  -2.343530
#
#                   PE  current_ratio        DE        DA
# ASX Code
# IAA         4.213502       1.386869  0.009041  0.008960
# IJP       -11.060012       1.100231  0.007119  0.007069
# IJR         2.890985       1.015062  0.073873  0.068791
# IKO         9.711489       1.020719  0.114437  0.102686
# IOO         3.511819       1.124461  0.013627  0.013443
# ...              ...            ...       ...       ...
# YANK      -18.022058     829.599976  0.021004  0.020572
# YMAX       -6.765139       1.076724  0.031004  0.030072
# ZUSD      106.848495     988.842590  0.001012  0.001011
# ZYAU       -4.174442       0.889163  0.003592  0.003579
# ZYUS       -4.275601       0.454708  0.033659  0.032563
#
# [770 rows x 22 columns]

# %%
# keeping the actual company, not index
financial1 = financial1.loc[financial1['GICS Sector']!='--']

# %%
financial1['GICS Sector'].sort_values().unique()
# Out:
# array(['Communication Services', 'Consumer Discretionary',
#        'Consumer Staples', 'Energy', 'Financials', 'Health Care',
#        'Industrials', 'Information Technology', 'Materials',
#        'Real Estate', 'Utilities'], dtype=object)

# %%
financial1.loc[financial1['GICS Sector']=='Industrials'].groupby(by=['year'])['ROE'].mean()
# Out:
# year
# 2010.0    -0.330885
# 2011.0     0.275576
# 2012.0    -5.488530
# 2013.0   -12.457072
# 2014.0    -0.544357
# 2015.0    -0.272183
# 2016.0    -0.523959
# 2017.0    -0.419419
# 2018.0    -2.804193
# 2019.0    -0.466345
# 2020.0    -0.514797
# Name: ROE, dtype: float32

# %%
# selecting the largest market cap in 2010 and 2019 in each GICS Sector
max(financial1['Market Cap.($)'])
# Out:
# 407861133312.0

# %%
financial1.loc[financial1['GICS Sector']=='Industrials'].sort_values(by='Market Cap.($)', ascending=False).head(1)
# Out:
#           Total Assets  Total Curr. Liabilities  Total Current Assets  \
# ASX Code
# TCL       3.595700e+10             3.791000e+09          1.925000e+09
#
#           Total Equity  Total Liabilities    year  \
# ASX Code
# TCL       9.902000e+09       2.605500e+10  2019.0
#
#           Reported NPAT After Abnorma  Weighted Average Number of  \
# ASX Code
# TCL                       170000000.0                2.578000e+09
#
#           Year End Share Price ($)  Market Cap.($)  ...  GICS Sector  \
# ASX Code                                            ...
# TCL                          14.74    3.942950e+10  ...  Industrials
#
#          GICS Industry Group                  GICS Industry       ROA  \
# ASX Code
# TCL           Transportation  Transportation Infrastructure  0.004728
#
#                ROE       EPS          PE  current_ratio        DE        DA
# ASX Code
# TCL       0.017168  0.065943  223.527756       0.507782  2.631287  0.724616
#
# [1 rows x 22 columns]

# %%
financial1.loc[financial1['GICS Sector']=='Communication Services'].sort_values(by='Market Cap.($)', ascending=False).head(1)
# Out:
#           Total Assets  Total Curr. Liabilities  Total Current Assets  \
# ASX Code
# TLS       4.044500e+10             8.129000e+09          6.970000e+09
#
#           Total Equity  Total Liabilities    year  \
# ASX Code
# TLS       1.451000e+10       2.593500e+10  2015.0
#
#           Reported NPAT After Abnorma  Weighted Average Number of  \
# ASX Code
# TLS                      4.305000e+09                1.226400e+10
#
#           Year End Share Price ($)  Market Cap.($)  ...  \
# ASX Code                                            ...
# TLS                           6.14    7.506552e+10  ...
#
#                      GICS Sector         GICS Industry Group  \
# ASX Code
# TLS       Communication Services  Telecommunication Services
#
#                                    GICS Industry       ROA       ROE  \
# ASX Code
# TLS       Diversified Telecommunication Services  0.106441  0.296692
#
#                EPS         PE  current_ratio        DE        DA
# ASX Code
# TLS       0.351027  17.491512       0.857424  1.787388  0.641241
#
# [1 rows x 22 columns]

# %%
financial1.loc[financial1['GICS Sector']=='Financials'].sort_values(by='Market Cap.($)', ascending=False).head(1)
# Out:
#           Total Assets  Total Curr. Liabilities  Total Current Assets  \
# ASX Code
# SPY       4.153220e+11             1.768963e+09          1.832859e+09
#
#           Total Equity  Total Liabilities    year  \
# ASX Code
# SPY       4.135530e+11       1.768963e+09  2020.0
#
#           Reported NPAT After Abnorma  Weighted Average Number of  \
# ASX Code
# SPY                      5.669867e+10                 876932096.0
#
#           Year End Share Price ($)  Market Cap.($)  ... GICS Sector  \
# ASX Code                                            ...
# SPY                     465.100006    4.078611e+11  ...  Financials
#
#              GICS Industry Group                   GICS Industry       ROA  \
# ASX Code
# SPY       Diversified Financials  Diversified Financial Services  0.136517
#
#                ROE        EPS        PE  current_ratio        DE        DA
# ASX Code
# SPY       0.137101  64.655708  7.193487        1.03612  0.004277  0.004259
#
# [1 rows x 22 columns]

# %% [markdown]
# # Visualisation

# %%
financial1 = financial1.reset_index()

# %%
financial1 = financial1.set_index(['year'])

# %%
banks = financial1.loc[(financial1['ASX Code']=='CBA') | (financial1['ASX Code']=='ANZ')
              | (financial1['ASX Code']=='WBC') | (financial1['ASX Code']=='NAB')]
banks['ASX Code'].unique()
# Out:
# array(['ANZ', 'CBA', 'NAB', 'WBC'], dtype=object)

# %%
financial1.columns
# Out:
# Index(['ASX Code', 'Total Assets', 'Total Curr. Liabilities',
#        'Total Current Assets', 'Total Equity', 'Total Liabilities',
#        'Reported NPAT After Abnorma', 'Weighted Average Number of',
#        'Year End Share Price ($)', 'Market Cap.($)', 'Company Name', 'Status',
#        'GICS Sector', 'GICS Industry Group', 'GICS Industry', 'ROA', 'ROE',
#        'EPS', 'PE', 'current_ratio', 'DE', 'DA'],
#       dtype='object')

# %%
# heatmap
sns.heatmap(banks.corr())
plt.title("Pearson correlation", size=20)
# Out:
# Text(0.5, 1.0, 'Pearson correlation')

# %%
# financial1.loc[financial1.index == 'ASX']

# %%
plt.plot(banks['ROE'].loc[banks['ASX Code']=='CBA'], label="CBA")
plt.plot(banks['ROE'].loc[banks['ASX Code']=='ANZ'], label="ANZ")
plt.plot(banks['ROE'].loc[banks['ASX Code']=='WBC'], label="WBC")
plt.plot(banks['ROE'].loc[banks['ASX Code']=='NAB'], label="NAB")
plt.legend(loc="lower left")
plt.title("Big 4 Banks - ROE")
plt.ylabel("ROE")
# Out:
# Text(0, 0.5, 'ROE')

# %%
sns.lineplot(x = banks.index, y=banks['ROE'], hue=banks['ASX Code'])
plt.title("Big 4 Banks - ROE (2010-2020)")
plt.ylabel("ROE")
# Out:
# Text(0, 0.5, 'ROE')

# %%
sns.boxplot(x=banks['ASX Code'], y=banks['ROE'])
plt.title("Big 4 banks - ROE (2010-2020)")
# Out:
# Text(0.5, 1.0, 'Big 4 banks - ROE (2010-2020)')

# %%
plt.scatter(x=banks['ROE'].loc[banks['ASX Code']=='CBA'], y=banks['PE'].loc[banks['ASX Code']=='CBA'])
plt.title("CBA - ROE vs PE")
plt.xlabel("ROE")
plt.ylabel("PE")
# Out:
# Text(0, 0.5, 'PE')

# %%
fig, axs = plt.subplots(2,2, sharex=True)

fig.suptitle("ROE vs PE")
axs[0,0].scatter(x=banks['ROE'].loc[banks['ASX Code']=='ANZ'], y=banks['PE'].loc[banks['ASX Code']=='ANZ'])
axs[0,0].set_title("ANZ")
axs[0,1].scatter(x=banks['ROE'].loc[banks['ASX Code']=='CBA'], y=banks['PE'].loc[banks['ASX Code']=='CBA'])
axs[0,1].set_title("CBA")
axs[1,0].scatter(x=banks['ROE'].loc[banks['ASX Code']=='NAB'], y=banks['PE'].loc[banks['ASX Code']=='NAB'])
axs[1,0].set_title("NAB")
axs[1,1].scatter(x=banks['ROE'].loc[banks['ASX Code']=='WBC'], y=banks['PE'].loc[banks['ASX Code']=='WBC'])
axs[1,1].set_title("WBC")

plt.xlabel("ROE")
# Out:
# Text(0.5, 0, 'ROE')

# %%
sns.scatterplot(data=banks, x='ROE', y='PE',hue='ASX Code')
# Out:
# <AxesSubplot:xlabel='ROE', ylabel='PE'>

# %%
financial.head()
# Out:
# Item       CA Cash  CA Inventories  CL Short-Term Debt  NCL Long-Term Debt  \
# ASX Code
# 14D            NaN             NaN                 NaN                 NaN
# 1AD            NaN             NaN                 NaN                 NaN
# 1AG       271919.0        282857.0           1046419.0             59535.0
# 1ST            NaN             NaN                 NaN                 NaN
# 2BE            NaN             NaN                 NaN                 NaN
#
# Item      Net Operating Cash Flow_x  Total Assets  Total Curr. Liabilities  \
# ASX Code
# 14D                             NaN           NaN                      NaN
# 1AD                             NaN           NaN                      NaN
# 1AG                       -417821.0     8940993.0                3922626.0
# 1ST                             NaN           NaN                      NaN
# 2BE                             NaN           NaN                      NaN
#
# Item      Total Current Assets  Total Equity  Total Liabilities  ...  \
# ASX Code                                                         ...
# 14D                        NaN           NaN                NaN  ...
# 1AD                        NaN           NaN                NaN  ...
# 1AG                  2336530.0     4958832.0          3982161.0  ...
# 1ST                        NaN           NaN                NaN  ...
# 2BE                        NaN           NaN                NaN  ...
#
# Item      Operating Expenses  Reported NPAT After Abnorma  \
# ASX Code
# 14D                      NaN                          NaN
# 1AD                      NaN                          NaN
# 1AG              -12886912.0                     317330.0
# 1ST                      NaN                          NaN
# 2BE                      NaN                          NaN
#
# Item      Shares Outstanding at Perio  Total Revenue Excluding Int  \
# ASX Code
# 14D                               NaN                          NaN
# 1AD                               NaN                          NaN
# 1AG                        39697172.0                   13271768.0
# 1ST                               NaN                          NaN
# 2BE                               NaN                          NaN
#
# Item      Weighted Average Number of  Market Cap.($)  Net Financing Cash Flow  \
# ASX Code
# 14D                              NaN             NaN                      NaN
# 1AD                              NaN             NaN                      NaN
# 1AG                       39741708.0       3453654.0                1206807.0
# 1ST                              NaN             NaN                      NaN
# 2BE                              NaN             NaN                      NaN
#
# Item      Net Investing Cash Flow  Net Operating Cash Flow_y  \
# ASX Code
# 14D                           NaN                        NaN
# 1AD                           NaN                        NaN
# 1AG                    -3371176.0                  -417821.0
# 1ST                           NaN                        NaN
# 2BE                           NaN                        NaN
#
# Item      Year End Share Price ($)
# ASX Code
# 14D                            NaN
# 1AD                            NaN
# 1AG                           0.09
# 1ST                            NaN
# 2BE                            NaN
#
# [5 rows x 22 columns]
